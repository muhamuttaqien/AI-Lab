# %% [markdown]
# # Siamese One-Shot-Learning Network, [AT&T](https://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html) Faces Using [ReNom](https://www.renom.jp/)

# %%
import os
import codecs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise
from PIL import Image, ImageOps
import random
import datetime
import time

# %%
import renom as rm
from renom.optimizer import Adam
from renom.utility import *
from renom.cuda import set_cuda_active

# %% [markdown]
# ## Set Configs

# %%
TRAIN_DIR = './datasets/faces/training/'
TEST_DIR = './datasets/faces/testing/'
BATCH_SIZE = 64
N_EPOCHS = 100
LR = 0.0005
N_GPU = 1

# %%
# check cuda availability
# if rm.cuda.has_cuda() and N_GPU > 0: set_cuda_active(activate=True)
# else: set_cuda_active(activate=False)

# %% [markdown]
# ## Set Helpers

# %%
def show_img(img, text=None, figsize=(20,20), should_save=False):
    
    plt.figure(figsize=figsize)
    plt.axis('off')
    if text:
        plt.text(75, 8, text, style='italic', fontweight='bold',
            bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 10 })
    plt.imshow(img, cmap='gray')
    plt.show()

# %% [markdown]
# ## Configure Custom Data Generator

# %%
class SiameseDataGenerator(object):
    
    def __init__(self, datasets, transform=True, shuffle=True, batch_size=64, should_invert=True):
        self.datasets = datasets
        self.transform = transform
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.should_invert = should_invert
    
    def __getitem__(self, train=True):
        
        while True:
            imageA_data = []
            imageB_data = []
            label_data = []
            
            if self.shuffle: random.shuffle(datasets)
            for imageA_tupple in [data for data in datasets]:
                
                should_get_same_class = random.randint(0,1) # make sure approx 50% of images are in the same class
                if should_get_same_class:
                    while True:
                        # keep looping until the same class image is found
                        imageB_tupple = random.choice(self.datasets)
                        if imageA_tupple[1] == imageB_tupple[1]:
                            break
                else:
                    while True:
                        # keep looping until the different class image is found
                        imageB_tupple = random.choice(self.datasets)
                        if imageA_tupple[1] != imageB_tupple[1]:
                            break

                imageA = Image.open(imageA_tupple[0])
                imageB = Image.open(imageB_tupple[0])
                
                # the L means that it is just stores the Luminance
                imageA = imageA.convert('L')
                imageB = imageB.convert('L')

                if self.should_invert:
                    imageA = ImageOps.invert(imageA)
                    imageB = ImageOps.invert(imageB)

                if self.transform is not False:
                    imageA = imageA.resize((100, 100), resample=Image.BILINEAR)                
                    imageB = imageB.resize((100, 100), resample=Image.BILINEAR)

                    imageA = np.array(imageA)
                    imageB = np.array(imageB)
                    
                    imageA = np.expand_dims(imageA, axis=0)
                    imageB = np.expand_dims(imageB, axis=0)
                    
                    imageA = imageA/ 255.
                    imageB = imageB/ 255.

                imageA_data.append(imageA)
                imageB_data.append(imageB)
                label_data.append(np.array([int(imageA_tupple[1] != imageB_tupple[1])], dtype=np.float32))

                # compact data into batch
                if len(imageA_data) == self.batch_size:
                    imageA_batch = np.array(imageA_data)
                    imageB_batch = np.array(imageB_data)
                    label_batch = np.array(label_data)
                    imageA_data = []
                    imageB_data = []
                    label_data = []

                    # return image A, image B and its similarity score (label)
                    yield imageA_batch, imageB_batch, label_batch
                    
    def __len__(self):
        return len(self.datasets)

# %%
def load_datasets(path_dir):
    datasets = list()
    train_list = [label for label in os.listdir(path_dir) if label != 'README']
    for idx_train, train in enumerate(train_list):
        image_list = os.listdir(path_dir + train)
        for image in image_list:
            datasets.append((path_dir + train + '/'  + image, idx_train))
            
    return datasets

# %%
datasets = load_datasets(path_dir=TRAIN_DIR)
siamese_generator = SiameseDataGenerator(datasets=datasets, transform=True, shuffle=True,
                                         batch_size=BATCH_SIZE, should_invert=False)

# %% [markdown]
# ## Visualize Data

# %%
for _ in range(3):
    imageA, imageB, label = siamese_generator.__getitem__(True).__next__()
    
    stacked_image = np.hstack((imageA[0][0], imageB[0][0]))
    show_img(stacked_image, text="Dissimilarity: {}".format(label[0][0]), figsize=(5,5))

# %% [markdown]
# ## Build [Siamese Network](https://www.cs.cmu.edu/~rsalakhu/papers/oneshot1.pdf) Architecture

# %%
class SiameseNet(rm.Model):
    
    def __init__(self):
        super(SiameseNet, self).__init__()
        self.conv_layer = rm.Sequential([
            rm.Conv2d(channel=4, filter=3, padding=1),
            rm.Relu(),
            # rm.BatchNormalize(),
            
            rm.Conv2d(channel=8, filter=3, padding=1),
            rm.Relu(),
            # rm.BatchNormalize(),
            
            rm.Conv2d(channel=8, filter=3, padding=1),
            rm.Relu(),
            # rm.BatchNormalize(),
        ])

        self.fc_layer = rm.Sequential([
            rm.Flatten(),
            rm.Dense(500),
            rm.Relu(),
            rm.Dense(500),
            rm.Relu(),
            rm.Dense(5),
        ])

    def forward_once(self, x):
        x = self.conv_layer(x)
        x = x.reshape(x.shape[0], -1)
        x = self.fc_layer(x)

        return x

    def forward(self, imageA, imageB):
        resultA = self.forward_once(imageA)
        resultB = self.forward_once(imageB)

        return resultA, resultB

# %% [markdown]
# #### Initialize Siamese Network

# %%
siamese = SiameseNet()

# %% [markdown]
# ## Loss Function

# %%
class ContrastiveLoss(rm.Model):
    
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin # used to determine the limit to which examples from different pairs are penalized
    
    def forward(self, resultA, resultB, label):
        euclidean_distance = pairwise.euclidean_distances(resultA, resultB)
        contrastive_loss = rm.mean((1-label) * rm.square(euclidean_distance) +
                                   (label) * rm.square(np.clip(self.margin - euclidean_distance, a_min=0.0, a_max=(self.margin - euclidean_distance).max())))
    
        return contrastive_loss

# %%
contrastive_loss = ContrastiveLoss()

# %% [markdown]
# ## Set Optimizer

# %%
optimizer = rm.Adam(lr=LR)

# %% [markdown]
# ## Train The Network

# %%
loss_avg = []
train_loss_history = []
N = len(datasets)
for epoch in range(N_EPOCHS):
    
    loss = 0
    train_generator = siamese_generator.__getitem__(True)
    for batch_idx in range(N//BATCH_SIZE):
        
        imageA, imageB, label = train_generator.__next__()
        with siamese.train():
            resultA, resultB = siamese(imageA, imageB)
            l = contrastive_loss(resultA, resultB, label)
            
        grad = l.grad()
        grad.update(optimizer)
        loss += l.as_ndarray()
        
        if batch_idx % 10 == 0:
            print('Train Epoch: {} Loss: {:.6f}'.format(epoch+1, loss.item()))
            train_loss_history.append(loss.item())

            if not os.path.exists('./weights/faces/'): os.makedirs('./weights/faces/')
            # torch.save(siamese, './weights/faces/siamese_{:03}.pt'.format(epoch+1))
# Out:
# Train Epoch: 1 Loss: 1.713789
# Train Epoch: 2 Loss: 1.775553
# Train Epoch: 3 Loss: 2.388633
# Train Epoch: 4 Loss: 1.715092
# Train Epoch: 5 Loss: 1.900747
# Train Epoch: 6 Loss: 1.961233
# Train Epoch: 7 Loss: 1.776419
# Train Epoch: 8 Loss: 2.205752
# Train Epoch: 9 Loss: 2.085421
# Train Epoch: 10 Loss: 1.963528
# Train Epoch: 11 Loss: 1.776798
# Train Epoch: 12 Loss: 1.717164
# Train Epoch: 13 Loss: 1.900510
# Train Epoch: 14 Loss: 1.775236
# Train Epoch: 15 Loss: 2.080312
# Train Epoch: 16 Loss: 1.897032
# Train Epoch: 17 Loss: 2.207478
# Train Epoch: 18 Loss: 1.654966
# Train Epoch: 19 Loss: 1.961046
# Train Epoch: 20 Loss: 2.145407
# Train Epoch: 21 Loss: 1.532080
# Train Epoch: 22 Loss: 1.777679
# Train Epoch: 23 Loss: 1.900231
# Train Epoch: 24 Loss: 1.777923
# Train Epoch: 25 Loss: 1.656037
# Train Epoch: 26 Loss: 1.840618
# Train Epoch: 27 Loss: 1.716048
# Train Epoch: 28 Loss: 2.024517
# Train Epoch: 29 Loss: 2.145776
# Train Epoch: 30 Loss: 1.410113
# Train Epoch: 31 Loss: 1.838142
# Train Epoch: 32 Loss: 2.084326
# Train Epoch: 33 Loss: 1.837522
# Train Epoch: 34 Loss: 2.208300
# Train Epoch: 35 Loss: 2.021739
# Train Epoch: 36 Loss: 1.839107
# Train Epoch: 37 Loss: 2.023024
# Train Epoch: 38 Loss: 1.839677
# Train Epoch: 39 Loss: 2.270185
# Train Epoch: 40 Loss: 1.592283
# Train Epoch: 41 Loss: 2.082950
# Train Epoch: 42 Loss: 1.777483
# Train Epoch: 43 Loss: 1.533403
# Train Epoch: 44 Loss: 1.900681
# Train Epoch: 45 Loss: 1.839881
# Train Epoch: 46 Loss: 2.206134
# Train Epoch: 47 Loss: 2.023283
# Train Epoch: 48 Loss: 1.961409
# Train Epoch: 49 Loss: 1.777651
# Train Epoch: 50 Loss: 1.963048
# Train Epoch: 51 Loss: 1.777950
# Train Epoch: 52 Loss: 2.023813
# Train Epoch: 53 Loss: 2.326235
# Train Epoch: 54 Loss: 2.146103
# Train Epoch: 55 Loss: 2.083653
# Train Epoch: 56 Loss: 2.327603
# Train Epoch: 57 Loss: 2.205125
# Train Epoch: 58 Loss: 2.143643
# Train Epoch: 59 Loss: 2.145055
# Train Epoch: 60 Loss: 1.961556
# Train Epoch: 61 Loss: 2.022400
# Train Epoch: 62 Loss: 1.963032
# Train Epoch: 63 Loss: 2.142832
# Train Epoch: 64 Loss: 1.838560
# Train Epoch: 65 Loss: 1.963410
# Train Epoch: 66 Loss: 1.901021
# Train Epoch: 67 Loss: 1.593513
# Train Epoch: 68 Loss: 2.022557
# Train Epoch: 69 Loss: 1.779063
# Train Epoch: 70 Loss: 1.900502
# Train Epoch: 71 Loss: 2.207469
# Train Epoch: 72 Loss: 2.146321
# Train Epoch: 73 Loss: 2.083375
# Train Epoch: 74 Loss: 1.778347
# Train Epoch: 75 Loss: 1.960559
# Train Epoch: 76 Loss: 2.022907
# Train Epoch: 77 Loss: 2.204468
# Train Epoch: 78 Loss: 2.084924
# Train Epoch: 79 Loss: 2.209764
# Train Epoch: 80 Loss: 2.205422
# Train Epoch: 81 Loss: 2.020944
# Train Epoch: 82 Loss: 2.145801
# Train Epoch: 83 Loss: 1.715113
# Train Epoch: 84 Loss: 1.838404
# Train Epoch: 85 Loss: 2.267108
# Train Epoch: 86 Loss: 1.592305
# Train Epoch: 87 Loss: 1.840357
# Train Epoch: 88 Loss: 2.021356
# Train Epoch: 89 Loss: 1.959706
# Train Epoch: 90 Loss: 2.084747
# Train Epoch: 91 Loss: 1.778266
# Train Epoch: 92 Loss: 2.083149
# Train Epoch: 93 Loss: 2.082707
# Train Epoch: 94 Loss: 1.715111
# Train Epoch: 95 Loss: 1.715812
# Train Epoch: 96 Loss: 2.270252
# Train Epoch: 97 Loss: 1.716493
# Train Epoch: 98 Loss: 1.899778
# Train Epoch: 99 Loss: 2.267563
# Train Epoch: 100 Loss: 1.899938

# %% [markdown]
# ## Evaluate The Network

# %%
plt.figure(figsize=(10,5))
plt.title("Train Loss of Siamese Network")
plt.plot(train_loss_history, label="Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

if not os.path.exists('./images/faces/'): os.makedirs('./images/faces/')
plt.savefig('./images/faces/final_train_loss.png')
plt.show()

# %%
datasets = load_datasets(path_dir=TEST_DIR)
siamese_generator = SiameseDataGenerator(datasets=datasets, transform=True, shuffle=True,
                                         batch_size=1, should_invert=False)

# %%
test_generator = siamese_generator.__getitem__(True)
imageA, _, _ = test_generator.__next__()
for i in range(20):
    _, imageB, label = test_generator.__next__()
    resultA, resultB = siamese(imageA, imageB)
    euclidean_distance = pairwise.euclidean_distances(resultA, resultB)

    stacked_image = np.hstack((imageA[0][0], imageB[0][0]))
    show_img(stacked_image, 'Dissimilarity: {:.2f}'.format(euclidean_distance[0][0]), figsize=(5,5))

# %% [markdown]
# ---
