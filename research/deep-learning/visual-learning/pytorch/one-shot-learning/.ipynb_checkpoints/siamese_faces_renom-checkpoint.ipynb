# %% [markdown]
# # Siamese One-Shot-Learning Network, [AT&T](https://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html) Faces Using [ReNom](https://www.renom.jp/)

# %%
import os
import codecs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise
from sklearn.preprocessing import normalize
from PIL import Image, ImageOps
import random
import datetime
import time

# %%
import renom as rm
from renom.optimizer import Adam
from renom.utility import *
from renom.cuda import set_cuda_active

# %% [markdown]
# ## Set Configs

# %%
TRAIN_DIR = './datasets/faces/training/'
TEST_DIR = './datasets/faces/testing/'
BATCH_SIZE = 32
N_EPOCHS = 100
LR = 5e-4
N_GPU = 1

# %%
# check cuda availability
# if rm.cuda.has_cuda() and N_GPU > 0: set_cuda_active(activate=True)
# else: set_cuda_active(activate=False)

# %% [markdown]
# ## Set Helpers

# %%
def show_img(img, text=None, figsize=(20,20), should_save=False):
    
    plt.figure(figsize=figsize)
    plt.axis('off')
    if text:
        plt.text(75, 8, text, style='italic', fontweight='bold',
            bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 10 })
    plt.imshow(img, cmap='gray')
    plt.show()

# %% [markdown]
# ## Configure Custom Data Generator

# %%
class SiameseDataGenerator(object):
    
    def __init__(self, datasets, transform=True, batch_size=64, should_invert=True):
        self.datasets = datasets
        self.transform = transform
        self.batch_size = batch_size
        self.should_invert = should_invert
    
    def __getitem__(self, train=True):
        
        imageA_data = []
        imageB_data = []
        label_data = []
        
        while True:
            imageA_tupple = random.choice(self.datasets)
            should_get_same_class = random.randint(0,1) # make sure approx 50% of images are in the same class
            if should_get_same_class:
                while True:
                    # keep looping until the same class image is found
                    imageB_tupple = random.choice(self.datasets)
                    if imageA_tupple[1] == imageB_tupple[1]:
                        break
            else:
                while True:
                    # keep looping until the different class image is found
                    imageB_tupple = random.choice(self.datasets)
                    if imageA_tupple[1] != imageB_tupple[1]:
                        break

            imageA = Image.open(imageA_tupple[0])
            imageB = Image.open(imageB_tupple[0])
            
            # the L means that it is just stores the Luminance
            imageA = imageA.convert('L')
            imageB = imageB.convert('L')

            if self.should_invert:
                imageA = ImageOps.invert(imageA)
                imageB = ImageOps.invert(imageB)

            if self.transform is not False:
                imageA = imageA.resize((100, 100))                
                imageB = imageB.resize((100, 100))
                
                imageA = normalize(imageA)
                imageB = normalize(imageB)
                
                imageA = np.expand_dims(imageA, axis=0)
                imageB = np.expand_dims(imageB, axis=0)

                imageA = np.array(imageA)
                imageB = np.array(imageB)
                
            imageA_data.append(imageA)
            imageB_data.append(imageB)
            label_data.append(np.array([int(imageA_tupple[1] != imageB_tupple[1])], dtype=np.float32))
            
            # compact data into batch
            if len(imageA_data) == self.batch_size:
                imageA_batch = np.array(imageA_data)
                imageB_batch = np.array(imageB_data)
                label_batch = np.array(label_data)
                imageA_data = []
                imageB_data = []
                label_data = []
                
                # return image A, image B and its similarity score (label)
                yield imageA_batch, imageB_batch, label_batch

# %%
def load_datasets(path_dir):
    datasets = list()
    train_list = [label for label in os.listdir(path_dir) if label != 'README']
    for idx_train, train in enumerate(train_list):
        image_list = os.listdir(path_dir + train)
        for image in image_list:
            datasets.append((path_dir + train + '/'  + image, idx_train))
            
    return datasets

# %%
datasets = load_datasets(path_dir=TRAIN_DIR)
siamese_generator = SiameseDataGenerator(datasets=datasets, transform=True, batch_size=BATCH_SIZE, should_invert=False)

# %% [markdown]
# ## Visualize Data

# %%
for _ in range(3):
    imageA, imageB, label = siamese_generator.__getitem__(True).__next__()
    
    stacked_image = np.hstack((imageA[0][0], imageB[0][0]))
    show_img(stacked_image, text="Dissimilarity: {}".format(label[0][0]), figsize=(5,5))

# %% [markdown]
# ## Build [Siamese Network](https://www.cs.cmu.edu/~rsalakhu/papers/oneshot1.pdf) Architecture

# %%
class SiameseNet(rm.Model):
    def __init__(self):
        super(SiameseNet, self).__init__()
        self.conv_layer = rm.Sequential([
            rm.Conv2d(channel=4, filter=3, padding=1),
            rm.Relu(),
            rm.BatchNormalize(),
            
            rm.Conv2d(channel=8, filter=3, padding=1),
            rm.Relu(),
            rm.BatchNormalize(),
            
            rm.Conv2d(channel=8, filter=3, padding=1),
            rm.Relu(),
            rm.BatchNormalize(),
        ])

        self.fc_layer = rm.Sequential([
            rm.Dense(500),
            rm.Relu(),
            rm.Dense(500),
            rm.Relu(),
            rm.Dense(5)
        ])

    def forward_once(self, x):
        x = self.conv_layer(x)
        x = x.reshape(x.shape[0], -1)
        x = self.fc_layer(x)

        return x

    def forward(self, imageA, imageB):
        resultA = self.forward_once(imageA)
        resultB = self.forward_once(imageB)

        return resultA, resultB

# %% [markdown]
# #### Initialize Siamese Network

# %%
siamese = SiameseNet()

# %% [markdown]
# ## Loss Function

# %%
def contrastive_loss(resultA, resultB, label, margin=2.0):
    euclidean_distance = pairwise.euclidean_distances(resultA, resultB)
    contrastive_loss = rm.mean((1-label) * np.power(euclidean_distance, 2) +
                               (label) * np.power(np.clip(margin - euclidean_distance, a_min=0.0, a_max=(margin - euclidean_distance).max()), 2))
    
    return contrastive_loss

# %% [markdown]
# ## Set Optimizer

# %%
optimizer = rm.Adam(lr=LR)

# %%
counter = []
train_loss_history = []
N = len(datasets)
for epoch in range(N_EPOCHS):
    with siamese.train():
        imageA, imageB, label = siamese_generator.__getitem__(True).__next__()
        resultA, resultB = siamese(imageA, imageB)

        loss = contrastive_loss(resultA, resultB, label)
        loss.grad().update(optimizer)

        print('Train Epoch: {} Loss: {:.6f}'.format(epoch+1, loss.item()))
        train_loss_history.append(loss.item())

        if not os.path.exists('./weights/faces/'): os.makedirs('./weights/faces/')
        # torch.save(siamese, './weights/faces/siamese_{:03}.pt'.format(epoch+1))
# Out:
# Train Epoch: 1 Loss: 2.116871
# Train Epoch: 2 Loss: 2.117272
# Train Epoch: 3 Loss: 1.743052
# Train Epoch: 4 Loss: 1.245214
# Train Epoch: 5 Loss: 1.619339
# Train Epoch: 6 Loss: 1.744018
# Train Epoch: 7 Loss: 2.365354
# Train Epoch: 8 Loss: 1.368819
# Train Epoch: 9 Loss: 1.992818
# Train Epoch: 10 Loss: 1.867579
# Train Epoch: 11 Loss: 1.991801
# Train Epoch: 12 Loss: 1.744067
# Train Epoch: 13 Loss: 2.490827
# Train Epoch: 14 Loss: 1.867556
# Train Epoch: 15 Loss: 2.117055
# Train Epoch: 16 Loss: 2.117304
# Train Epoch: 17 Loss: 1.370027
# Train Epoch: 18 Loss: 2.864327
# Train Epoch: 19 Loss: 1.992595
# Train Epoch: 20 Loss: 1.369481
# Train Epoch: 21 Loss: 2.116773
# Train Epoch: 22 Loss: 1.618944
# Train Epoch: 23 Loss: 1.618525
# Train Epoch: 24 Loss: 1.992142
# Train Epoch: 25 Loss: 1.743409
# Train Epoch: 26 Loss: 2.988917
# Train Epoch: 27 Loss: 1.992157
# Train Epoch: 28 Loss: 1.494175
# Train Epoch: 29 Loss: 1.867916
# Train Epoch: 30 Loss: 1.245285
# Train Epoch: 31 Loss: 2.241140
# Train Epoch: 32 Loss: 1.369926
# Train Epoch: 33 Loss: 2.739473
# Train Epoch: 34 Loss: 2.242105
# Train Epoch: 35 Loss: 1.494661
# Train Epoch: 36 Loss: 2.241287
# Train Epoch: 37 Loss: 1.743543
# Train Epoch: 38 Loss: 2.490824
# Train Epoch: 39 Loss: 2.241624
# Train Epoch: 40 Loss: 1.992141
# Train Epoch: 41 Loss: 1.867983
# Train Epoch: 42 Loss: 1.618939
# Train Epoch: 43 Loss: 2.241558
# Train Epoch: 44 Loss: 1.743592
# Train Epoch: 45 Loss: 2.117401
# Train Epoch: 46 Loss: 1.618294
# Train Epoch: 47 Loss: 2.116714
# Train Epoch: 48 Loss: 2.241823
# Train Epoch: 49 Loss: 2.117953
# Train Epoch: 50 Loss: 1.245676
# Train Epoch: 51 Loss: 1.742932
# Train Epoch: 52 Loss: 2.241849
# Train Epoch: 53 Loss: 2.241429
# Train Epoch: 54 Loss: 2.117193
# Train Epoch: 55 Loss: 2.117129
# Train Epoch: 56 Loss: 2.864147
# Train Epoch: 57 Loss: 2.241565
# Train Epoch: 58 Loss: 2.365556
# Train Epoch: 59 Loss: 1.245767
# Train Epoch: 60 Loss: 2.490377
# Train Epoch: 61 Loss: 2.241589
# Train Epoch: 62 Loss: 2.117048
# Train Epoch: 63 Loss: 1.743546
# Train Epoch: 64 Loss: 1.867516
# Train Epoch: 65 Loss: 2.241637
# Train Epoch: 66 Loss: 1.867725
# Train Epoch: 67 Loss: 1.743911
# Train Epoch: 68 Loss: 2.117210
# Train Epoch: 69 Loss: 2.117167
# Train Epoch: 70 Loss: 1.867710
# Train Epoch: 71 Loss: 2.740005
# Train Epoch: 72 Loss: 2.615320
# Train Epoch: 73 Loss: 1.743840
# Train Epoch: 74 Loss: 1.493595
# Train Epoch: 75 Loss: 1.742871
# Train Epoch: 76 Loss: 2.117263
# Train Epoch: 77 Loss: 1.867594
# Train Epoch: 78 Loss: 2.366699
# Train Epoch: 79 Loss: 1.867736
# Train Epoch: 80 Loss: 1.868083
# Train Epoch: 81 Loss: 1.245303
# Train Epoch: 82 Loss: 1.245081
# Train Epoch: 83 Loss: 1.868380
# Train Epoch: 84 Loss: 1.992021
# Train Epoch: 85 Loss: 1.494375
# Train Epoch: 86 Loss: 1.743539
# Train Epoch: 87 Loss: 2.116426
# Train Epoch: 88 Loss: 2.864458
# Train Epoch: 89 Loss: 1.992088
# Train Epoch: 90 Loss: 2.365958
# Train Epoch: 91 Loss: 1.992153
# Train Epoch: 92 Loss: 1.868379
# Train Epoch: 93 Loss: 2.864558
# Train Epoch: 94 Loss: 1.619037
# Train Epoch: 95 Loss: 2.365770
# Train Epoch: 96 Loss: 2.117578
# Train Epoch: 97 Loss: 2.366187
# Train Epoch: 98 Loss: 2.365211
# Train Epoch: 99 Loss: 2.241515
# Train Epoch: 100 Loss: 1.743516

# %% [markdown]
# ## Evaluate The Network

# %%
plt.figure(figsize=(10,5))
plt.title("Train Loss of Siamese Network")
plt.plot(train_loss_history, label="Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

if not os.path.exists('./images/faces/'): os.makedirs('./images/faces/')
plt.savefig('./images/faces/final_train_loss.png')
plt.show()

# %% [markdown]
# ---
