# %% [markdown]
# # Convolutional Autoencoder Neural Network, Cifar10

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import datetime
import time

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable
from torchvision.utils import save_image

# %% [markdown]
# ## Set Configs

# %%
# number of epochs
num_epochs = 30

# images per batch
batch_size = 32

# number of GPUs availabele
n_gpu = 1

# 10 classes included in cifar10 dataset
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# weight decay for optimizer of autoencoder model
weight_decay = 1e-5

# %% [markdown]
# ## Configure Data Loader

# %%
transform = transforms.Compose([
                            transforms.ToTensor(),
                            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_loader = torch.utils.data.DataLoader(torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform), 
                                           batch_size=32, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified

# %%
test_loader = torch.utils.data.DataLoader(torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform), 
                                           batch_size=4, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
# decide which device we want to run on
device = torch.device('cuda:0' if (torch.cuda.is_available() and n_gpu > 0) else 'cpu')

# %% [markdown]
# ## Build Autoencoder Architecture

# %% [markdown]
# <img src='images/autoencoder-architecture.png' width='75%'/>

# %%
class Autoencoder(nn.Module):

    def __init__(self):
        super(Autoencoder, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 6, kernel_size=5),
            nn.ReLU(True),
            nn.Conv2d(6, 16, kernel_size=5),
            nn.ReLU(True))
        
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(16, 6, kernel_size=5),
            nn.ReLU(True),
            nn.ConvTranspose2d(6, 3, kernel_size=5),
            nn.ReLU(True),
            nn.Sigmoid())
        
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)

        return x

# %% [markdown]
# #### Initialize Autoencoder

# %%
autoencoder = Autoencoder().to(device)

# %% [markdown]
# ## Loss Function

# %%
reconstruction_loss = nn.MSELoss()
if (device.type == 'cuda'): reconstruction_loss.cuda()

# %% [markdown]
# ## Optimizer

# %%
optimizer = torch.optim.Adam(autoencoder.parameters(), weight_decay=weight_decay)

# %% [markdown]
# ## Train The Network

# %%
autoencoder
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(16, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): ConvTranspose2d(6, 3, kernel_size=(5, 5), stride=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Sigmoid()
#   )
# )

# %%
r_loss_to_display = []
prev_time = time.time()
for epoch in range(num_epochs):
    
    r_loss = []
    for i, (images, _) in enumerate(train_loader):
        
        images = Variable(images).to(device)
            
        optimizer.zero_grad()
        
        reconstruction = autoencoder(images)
        loss = reconstruction_loss(reconstruction, images)
        r_loss.append(loss)
        
        loss.backward()
        optimizer.step()
        
        # determine approximate time left
        batches_done = epoch * len(train_loader) + i
        batches_left = num_epochs * len(train_loader) - batches_done
        time_left = datetime.timedelta(seconds=batches_left * (time.time() - prev_time))
        prev_time = time.time()
        
    r_loss_to_display.append(sum(r_loss)/len(r_loss))
    print('epoch [{}/{}], reconstruction loss: {:.4f}, ETA: {}'.format(epoch+1, num_epochs, loss.data.cpu().numpy(), time_left, ))
# Out:
# epoch [1/30], reconstruction loss: 0.3917, ETA: 0:01:28.985146
# epoch [2/30], reconstruction loss: 0.3853, ETA: 0:01:58.399013
# epoch [3/30], reconstruction loss: 0.3848, ETA: 0:01:47.560010
# epoch [4/30], reconstruction loss: 0.3847, ETA: 0:01:24.983032
# epoch [5/30], reconstruction loss: 0.3845, ETA: 0:01:51.322194
# epoch [6/30], reconstruction loss: 0.3845, ETA: 0:02:28.699555
# epoch [7/30], reconstruction loss: 0.3845, ETA: 0:01:39.493885
# epoch [8/30], reconstruction loss: 0.3844, ETA: 0:01:48.630121
# epoch [9/30], reconstruction loss: 0.3844, ETA: 0:01:07.263193
# epoch [10/30], reconstruction loss: 0.3843, ETA: 0:02:04.326883
# epoch [11/30], reconstruction loss: 0.3843, ETA: 0:00:58.612834
# epoch [12/30], reconstruction loss: 0.3843, ETA: 0:00:58.915545
# epoch [13/30], reconstruction loss: 0.3842, ETA: 0:00:53.209836
# epoch [14/30], reconstruction loss: 0.3842, ETA: 0:01:10.054708
# epoch [15/30], reconstruction loss: 0.3842, ETA: 0:01:10.478241
# epoch [16/30], reconstruction loss: 0.3842, ETA: 0:00:45.061939
# epoch [17/30], reconstruction loss: 0.3842, ETA: 0:00:51.377678
# epoch [18/30], reconstruction loss: 0.3842, ETA: 0:00:54.370786
# epoch [19/30], reconstruction loss: 0.3841, ETA: 0:00:36.894321
# epoch [20/30], reconstruction loss: 0.3841, ETA: 0:01:32.336962
# epoch [21/30], reconstruction loss: 0.3841, ETA: 0:00:29.435341
# epoch [22/30], reconstruction loss: 0.3841, ETA: 0:00:36.838479
# epoch [23/30], reconstruction loss: 0.3841, ETA: 0:01:24.537389
# epoch [24/30], reconstruction loss: 0.3840, ETA: 0:00:33.830378
# epoch [25/30], reconstruction loss: 0.3840, ETA: 0:00:22.505243
# epoch [26/30], reconstruction loss: 0.3841, ETA: 0:00:18.243304
# epoch [27/30], reconstruction loss: 0.3841, ETA: 0:00:27.309387
# epoch [28/30], reconstruction loss: 0.3840, ETA: 0:00:07.892232
# epoch [29/30], reconstruction loss: 0.3840, ETA: 0:00:04.501115
# epoch [30/30], reconstruction loss: 0.3840, ETA: 0:00:00.001982

# %% [markdown]
# ## Evaluate The Network

# %%
plt.figure(figsize=(10,5))
plt.title("Reconstruction Loss of Autoencoder During Training")
plt.plot(r_loss_to_display, label="Reconstruction Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

if not os.path.exists('./images/autoencoder'): os.makedirs('./images/autoencoder')
plt.savefig('./images/autoencoder/final_loss.png')
plt.show()

# %%
for i, (images, _) in enumerate(train_loader):
    autoencoder.eval()
    
    images = images.type(torch.cuda.FloatTensor)
    reconstruction = autoencoder.encoder(images)
    results = autoencoder.decoder(reconstruction)
    
    fig, axarr = plt.subplots(1,2)
    fig.suptitle("Real vs Reconstructed Images", fontsize=16)
    
    images_to_show = ((images * 0.5) + 0.5)
    axarr[0].set_title('Real Image')
    axarr[0].imshow(images_to_show.cpu().detach().numpy()[0].transpose(1, 2, 0))
    
    results_to_show = ((results * 0.5) + 0.5)
    axarr[1].set_title('Reconstructed Image')
    axarr[1].imshow(results_to_show.cpu().detach().numpy()[0].transpose(1, 2, 0))
    
    fig.tight_layout()
    plt.savefig('./images/autoencoder/real_vs_recons{}.png'.format(i+1))
    if i+1 == 10: break
        
plt.show()

# %% [markdown]
# ---
