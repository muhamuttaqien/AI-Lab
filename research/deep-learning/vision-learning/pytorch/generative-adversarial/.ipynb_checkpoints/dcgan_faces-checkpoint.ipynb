# %% [markdown]
# # Deep Convolutional Generative Adversarial Network

# %%
from __future__ import print_function
import argparse
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib inline
from IPython.display import HTML

# %%
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.utils.data

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision.utils as vutils

# %%
# set random seed for reproducibility
manual_seed = 1
torch.manual_seed(manual_seed)
random.seed(manual_seed)

# %% [markdown]
# ## Set Arguments

# %%
# root directory for dataset
data_root = 'data/celeba'

# number of workers for data loader
workers = 2

# batch size during training
batch_size = 128

# spatial size of training images
# all images will be resized to this size using a transformer
image_size = 64

# number of channels in the training images
n_channels = 3

# size of Z latent vector (i.e. size of generator input)
n_zlvector = 100

# size of feature maps in generator
n_fgenerator = 64

# size of feature maps in discriminator
n_fdiscriminator = 64

# number of training epochs
n_epochs = 5

# learning rate for optimizers
lr = 0.0002

# beta1 hyper-param for Adam optimizers
beta1 = 0.5
beta2 = 0.999

# number of GPUs availabele
n_gpu = 1

# %% [markdown]
# ## Configure Data Loader

# %%
# we can use an image folder dataset the way we have it setup
data_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(root = data_root,
                         transform = transforms.Compose([
                             transforms.Resize(image_size),
                             transforms.CenterCrop(image_size),
                             transforms.ToTensor(),
                             transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                         ])),
                         batch_size = batch_size,
                         shuffle = True,
                         num_workers = workers
)

# %%
# decide which device we want to run on
device = torch.device('cuda:0' if (torch.cuda.is_available() and n_gpu > 0) else 'cpu')

# %% [markdown]
# real_batch = next(iter(data_loader))
# plt.figure(figsize=(10,10))
# plt.axis('off')
# plt.title('Training Images (Celeb-A Faces Dataset)')
# plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(), (1, 2, 0)))
# plt.show()

# %%
print('Total batches:',len(data_loader))
# Out:
# Total batches: 1254

# %%
real_batch = next(iter(data_loader))
plt.figure(figsize=(10,10))
plt.axis('off')
plt.title('Training Images (Celeb-A Faces Dataset)')
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(), (1, 2, 0)))
plt.show()

# %% [markdown]
# ## Build DCGAN Architecture

# %% [markdown]
# <img src='images/dcgan-architecture.png' width='75%'/>

# %%
# custome weights initialization called on the generator and discriminator
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('conv') != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Generator

# %%
class Generator(nn.Module):
    
    def __init__(self, n_gpu):
        super(Generator, self).__init__()
        
        self.n_gpu = n_gpu
        self.conv_blocks = nn.Sequential(
            nn.ConvTranspose2d(n_zlvector, n_fgenerator * 8, kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(n_fgenerator * 8),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(n_fgenerator * 8, n_fgenerator * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fgenerator * 4),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(n_fgenerator * 4, n_fgenerator * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fgenerator * 2),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(n_fgenerator * 2, n_fgenerator, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fgenerator),
            nn.ReLU(True),
            nn.ConvTranspose2d(n_fgenerator, n_channels, 4, 2, 1, bias=False),
            nn.Tanh(),
        )
    
    def forward(self, z):
        img = self.conv_blocks(z)
        return img

# %% [markdown]
# ## Discriminator

# %%
class Discriminator(nn.Module):
    
    def __init__(self, n_gpu):
        super(Discriminator, self).__init__()
        self.n_gpu = n_gpu
        self.model = nn.Sequential(
            nn.Conv2d(n_channels, n_fdiscriminator, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(n_fdiscriminator, n_fdiscriminator*2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fdiscriminator * 2),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(n_fdiscriminator*2, n_fdiscriminator*4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fdiscriminator*4),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(n_fdiscriminator*4, n_fdiscriminator*8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(n_fdiscriminator*8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(n_fdiscriminator*8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid(),
        )
    
    def forward(self, img):
        validity = self.model(img)
        return validity

# %% [markdown]
# #### Initialize the generator and discriminator

# %%
generator = Generator(n_gpu).to(device)
discriminator = Discriminator(n_gpu).to(device)

# handle multi-gpu if desired
if (device.type == 'cuda') and (n_gpu > 1):
    generator = nn.DataParallel(generator, list(range(n_gpu)))
    discriminator = nn.DataParallel(discriminator, list(range(n_gpu)))

# %%
# create batch of latent vectors to visualize the progression of the generator
fixed_noise = torch.randn(64, n_zlvector, 1, 1, device=device)

# establish convention for real and fake labels during training
real_label = 1
fake_label = 0

# %% [markdown]
# ## Loss Function

# %%
adversarial_loss = nn.BCELoss()
if (device.type == 'cuda'): adversarial_loss.cuda()

# %% [markdown]
# ## Optimizer

# %%
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(beta1, beta2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, beta2))

# %% [markdown]
# ## Training The [Network](https://arxiv.org/pdf/1511.06434)

# %% [markdown]
# #### Initialize weights

# %%
generator.apply(weights_init_normal)
# Out:
# Generator(
#   (conv_blocks): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
discriminator.apply(weights_init_normal)
# Out:
# Discriminator(
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
img_list = []
g_loss_to_display = []
d_loss_to_display = []
iters = 0

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(data_loader):
        
        try:
            # ---------------------
            #  Train Discriminator: maximize log(D(x)) + log(1 - D(G(z)))
            # ---------------------

            # train with all-real batch
            discriminator.zero_grad()
            real_cpu = imgs.to(device)
            batch_size = real_cpu.size(0)
            label = torch.full((batch_size,), real_label, device=device)

            # forward pass real batch through the discriminator
            validity = discriminator(real_cpu).view(-1)
            real_loss = adversarial_loss(validity, label)
            real_loss.backward()
            d_x = validity.mean().item()

            # train with all-fake batch
            # generate batch of latent vectors
            noise = torch.randn(batch_size, n_zlvector, 1, 1, device=device)

            # generate fake image batch with the generator
            fake = generator(noise)
            label.fill_(fake_label)

            # classify all fake batch with descriminator
            validity = discriminator(fake.detach()).view(-1)
            fake_loss = adversarial_loss(validity, label)
            fake_loss.backward()
            d_g_z1 = validity.mean().item()

            # add the gradients from the all-real and all-fake batches
            d_loss = real_loss + fake_loss
            optimizer_D.step()

            # ---------------------
            #  Train Generator: maximize log(D(G(z)))
            # ---------------------

            generator.zero_grad()
            label.fill_(real_label) # fake labels are real for generator cost

            validity = discriminator(fake).view(-1)
            g_loss = adversarial_loss(validity, label)
            g_loss.backward()
            d_g_z2 = validity.mean().item()
            optimizer_G.step()

            # output training stats
            if i % 50 == 0:
                print('[Epoch %d/%d] [Batch %d/%d] [Discriminator loss: %f] [Generator loss: %f] - D(x): %.4f D(G(z)): %.4f / %.4f'
                     % (epoch, n_epochs, i, len(data_loader),
                        d_loss.item(), g_loss.item(), d_x, d_g_z1, d_g_z2))

            # save losses for plotting later
            d_loss_to_display.append(d_loss.item())
            g_loss_to_display.append(g_loss.item())

            # check how the generator is doing by saving the generator's output on fixed noise
            if (iters % 500 == 0) or ((epoch == n_epochs-1) and (i == len(data_loader)-1)):
                with torch.no_grad():
                    fake = generator(fixed_noise).detach().cpu()
                img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

            iters += 1
        except Exception as error: 
            print(error)
            continue
# Out:
# [Epoch 0/5] [Batch 0/1254] [Discriminator loss: 1.413468] [Generator loss: 2.992513] - D(x): 0.4907 D(G(z)): 0.4905 / 0.0526
# [Epoch 0/5] [Batch 50/1254] [Discriminator loss: 0.070148] [Generator loss: 16.761784] - D(x): 0.9455 D(G(z)): 0.0000 / 0.0000
# [Epoch 0/5] [Batch 100/1254] [Discriminator loss: 0.168205] [Generator loss: 6.062648] - D(x): 0.8841 D(G(z)): 0.0202 / 0.0032
# [Epoch 0/5] [Batch 150/1254] [Discriminator loss: 0.980056] [Generator loss: 1.072049] - D(x): 0.4663 D(G(z)): 0.1050 / 0.3906
# [Epoch 0/5] [Batch 200/1254] [Discriminator loss: 0.839519] [Generator loss: 2.561612] - D(x): 0.5202 D(G(z)): 0.0771 / 0.0978
# [Epoch 0/5] [Batch 250/1254] [Discriminator loss: 0.594143] [Generator loss: 3.267243] - D(x): 0.7612 D(G(z)): 0.2296 / 0.0478
# [Epoch 0/5] [Batch 300/1254] [Discriminator loss: 0.764552] [Generator loss: 2.894842] - D(x): 0.6252 D(G(z)): 0.1515 / 0.0776
# [Epoch 0/5] [Batch 350/1254] [Discriminator loss: 1.044397] [Generator loss: 2.869767] - D(x): 0.7259 D(G(z)): 0.4649 / 0.0764
# [Epoch 0/5] [Batch 400/1254] [Discriminator loss: 0.573739] [Generator loss: 2.605967] - D(x): 0.7468 D(G(z)): 0.2054 / 0.0919
# [Epoch 0/5] [Batch 450/1254] [Discriminator loss: 0.689187] [Generator loss: 3.821176] - D(x): 0.9331 D(G(z)): 0.3897 / 0.0393
# [Epoch 0/5] [Batch 500/1254] [Discriminator loss: 0.263709] [Generator loss: 3.401554] - D(x): 0.8966 D(G(z)): 0.1300 / 0.0418
# [Epoch 0/5] [Batch 550/1254] [Discriminator loss: 1.024816] [Generator loss: 5.608205] - D(x): 0.9322 D(G(z)): 0.5620 / 0.0058
# [Epoch 0/5] [Batch 600/1254] [Discriminator loss: 0.578651] [Generator loss: 2.862269] - D(x): 0.7262 D(G(z)): 0.1508 / 0.0743
# [Epoch 0/5] [Batch 650/1254] [Discriminator loss: 0.503161] [Generator loss: 3.351536] - D(x): 0.9099 D(G(z)): 0.2904 / 0.0559
# [Epoch 0/5] [Batch 700/1254] [Discriminator loss: 0.766118] [Generator loss: 4.335955] - D(x): 0.9025 D(G(z)): 0.4557 / 0.0174
# [Epoch 0/5] [Batch 750/1254] [Discriminator loss: 0.735780] [Generator loss: 3.643795] - D(x): 0.8882 D(G(z)): 0.4143 / 0.0353
# [Epoch 0/5] [Batch 800/1254] [Discriminator loss: 0.603679] [Generator loss: 4.176936] - D(x): 0.8637 D(G(z)): 0.3356 / 0.0201
# [Epoch 0/5] [Batch 850/1254] [Discriminator loss: 0.534830] [Generator loss: 1.945551] - D(x): 0.7032 D(G(z)): 0.1084 / 0.1724
# [Epoch 0/5] [Batch 900/1254] [Discriminator loss: 0.659463] [Generator loss: 4.835118] - D(x): 0.9155 D(G(z)): 0.4070 / 0.0104
# [Epoch 0/5] [Batch 950/1254] [Discriminator loss: 0.505351] [Generator loss: 3.403541] - D(x): 0.7947 D(G(z)): 0.2099 / 0.0434
# [Epoch 0/5] [Batch 1000/1254] [Discriminator loss: 0.668387] [Generator loss: 5.400078] - D(x): 0.9342 D(G(z)): 0.4118 / 0.0063
# [Epoch 0/5] [Batch 1050/1254] [Discriminator loss: 0.493874] [Generator loss: 2.571031] - D(x): 0.7743 D(G(z)): 0.1848 / 0.0923
# [Epoch 0/5] [Batch 1100/1254] [Discriminator loss: 0.803373] [Generator loss: 5.064159] - D(x): 0.9153 D(G(z)): 0.4867 / 0.0081
# [Epoch 0/5] [Batch 1150/1254] [Discriminator loss: 0.382461] [Generator loss: 2.852260] - D(x): 0.7879 D(G(z)): 0.1103 / 0.0724
# [Epoch 0/5] [Batch 1200/1254] [Discriminator loss: 1.051403] [Generator loss: 2.724137] - D(x): 0.4134 D(G(z)): 0.0132 / 0.0945
# [Epoch 0/5] [Batch 1250/1254] [Discriminator loss: 0.525723] [Generator loss: 2.414646] - D(x): 0.7055 D(G(z)): 0.1096 / 0.1136
# [Epoch 1/5] [Batch 0/1254] [Discriminator loss: 0.341081] [Generator loss: 3.439434] - D(x): 0.8511 D(G(z)): 0.1503 / 0.0395
# [Epoch 1/5] [Batch 50/1254] [Discriminator loss: 0.466961] [Generator loss: 2.962144] - D(x): 0.8039 D(G(z)): 0.1976 / 0.0662
# [Epoch 1/5] [Batch 100/1254] [Discriminator loss: 0.829382] [Generator loss: 4.749211] - D(x): 0.8332 D(G(z)): 0.4358 / 0.0123
# [Epoch 1/5] [Batch 150/1254] [Discriminator loss: 0.409422] [Generator loss: 2.789061] - D(x): 0.8062 D(G(z)): 0.1558 / 0.0756
# [Epoch 1/5] [Batch 200/1254] [Discriminator loss: 1.309477] [Generator loss: 2.519836] - D(x): 0.3311 D(G(z)): 0.0133 / 0.1193
# [Epoch 1/5] [Batch 250/1254] [Discriminator loss: 0.441846] [Generator loss: 2.292010] - D(x): 0.7354 D(G(z)): 0.0849 / 0.1250
# [Epoch 1/5] [Batch 300/1254] [Discriminator loss: 0.415647] [Generator loss: 4.260076] - D(x): 0.9097 D(G(z)): 0.2567 / 0.0177
# [Epoch 1/5] [Batch 350/1254] [Discriminator loss: 0.574580] [Generator loss: 3.756611] - D(x): 0.8689 D(G(z)): 0.3244 / 0.0294
# [Epoch 1/5] [Batch 400/1254] [Discriminator loss: 0.291918] [Generator loss: 3.981284] - D(x): 0.8981 D(G(z)): 0.1578 / 0.0226
# [Epoch 1/5] [Batch 450/1254] [Discriminator loss: 0.462964] [Generator loss: 3.449304] - D(x): 0.8618 D(G(z)): 0.2437 / 0.0422
# [Epoch 1/5] [Batch 500/1254] [Discriminator loss: 0.367984] [Generator loss: 4.097229] - D(x): 0.9111 D(G(z)): 0.2262 / 0.0218
# [Epoch 1/5] [Batch 550/1254] [Discriminator loss: 0.340345] [Generator loss: 2.720996] - D(x): 0.7869 D(G(z)): 0.0789 / 0.0811
# [Epoch 1/5] [Batch 600/1254] [Discriminator loss: 0.450055] [Generator loss: 2.738426] - D(x): 0.7271 D(G(z)): 0.0892 / 0.0969
# [Epoch 1/5] [Batch 650/1254] [Discriminator loss: 0.639838] [Generator loss: 2.043361] - D(x): 0.6103 D(G(z)): 0.0540 / 0.1693
# [Epoch 1/5] [Batch 750/1254] [Discriminator loss: 0.741891] [Generator loss: 1.833606] - D(x): 0.5670 D(G(z)): 0.0747 / 0.1937
# [Epoch 1/5] [Batch 800/1254] [Discriminator loss: 0.543735] [Generator loss: 1.689937] - D(x): 0.6860 D(G(z)): 0.1084 / 0.2185
# [Epoch 1/5] [Batch 850/1254] [Discriminator loss: 0.804072] [Generator loss: 0.904642] - D(x): 0.5059 D(G(z)): 0.0376 / 0.4501
# [Epoch 1/5] [Batch 900/1254] [Discriminator loss: 0.379067] [Generator loss: 3.910121] - D(x): 0.9196 D(G(z)): 0.2390 / 0.0263
# [Epoch 1/5] [Batch 950/1254] [Discriminator loss: 0.351934] [Generator loss: 3.527955] - D(x): 0.8496 D(G(z)): 0.1508 / 0.0434
# [Epoch 1/5] [Batch 1000/1254] [Discriminator loss: 0.446952] [Generator loss: 3.483269] - D(x): 0.8990 D(G(z)): 0.2669 / 0.0387
# [Epoch 1/5] [Batch 1050/1254] [Discriminator loss: 0.641053] [Generator loss: 3.759573] - D(x): 0.8509 D(G(z)): 0.3547 / 0.0307
# [Epoch 1/5] [Batch 1100/1254] [Discriminator loss: 0.455597] [Generator loss: 2.633446] - D(x): 0.8629 D(G(z)): 0.2359 / 0.0947
# [Epoch 1/5] [Batch 1150/1254] [Discriminator loss: 0.525502] [Generator loss: 2.406988] - D(x): 0.8130 D(G(z)): 0.2475 / 0.1089
# [Epoch 1/5] [Batch 1200/1254] [Discriminator loss: 0.322169] [Generator loss: 3.082844] - D(x): 0.8791 D(G(z)): 0.1598 / 0.0592
# [Epoch 1/5] [Batch 1250/1254] [Discriminator loss: 1.891331] [Generator loss: 7.598307] - D(x): 0.9927 D(G(z)): 0.8104 / 0.0008
# [Epoch 2/5] [Batch 0/1254] [Discriminator loss: 1.268505] [Generator loss: 3.180934] - D(x): 0.9492 D(G(z)): 0.6511 / 0.0590
# [Epoch 2/5] [Batch 50/1254] [Discriminator loss: 0.353221] [Generator loss: 2.778346] - D(x): 0.8228 D(G(z)): 0.1232 / 0.0797
# [Epoch 2/5] [Batch 100/1254] [Discriminator loss: 0.757861] [Generator loss: 6.117634] - D(x): 0.9774 D(G(z)): 0.4720 / 0.0030
# [Epoch 2/5] [Batch 150/1254] [Discriminator loss: 0.459848] [Generator loss: 2.795677] - D(x): 0.7808 D(G(z)): 0.1539 / 0.0833
# [Epoch 2/5] [Batch 200/1254] [Discriminator loss: 1.195879] [Generator loss: 0.822430] - D(x): 0.3784 D(G(z)): 0.0441 / 0.4961
# [Epoch 2/5] [Batch 250/1254] [Discriminator loss: 0.536499] [Generator loss: 3.881124] - D(x): 0.9586 D(G(z)): 0.3548 / 0.0274
# [Epoch 2/5] [Batch 300/1254] [Discriminator loss: 0.388655] [Generator loss: 3.966011] - D(x): 0.8915 D(G(z)): 0.2191 / 0.0248
# [Epoch 2/5] [Batch 350/1254] [Discriminator loss: 0.647986] [Generator loss: 5.253501] - D(x): 0.9231 D(G(z)): 0.4020 / 0.0079
# [Epoch 2/5] [Batch 400/1254] [Discriminator loss: 0.489915] [Generator loss: 1.193353] - D(x): 0.7264 D(G(z)): 0.1127 / 0.3570
# [Epoch 2/5] [Batch 450/1254] [Discriminator loss: 0.684110] [Generator loss: 3.236908] - D(x): 0.8057 D(G(z)): 0.3313 / 0.0515
# [Epoch 2/5] [Batch 500/1254] [Discriminator loss: 0.534487] [Generator loss: 2.098891] - D(x): 0.6521 D(G(z)): 0.0512 / 0.1633
# [Epoch 2/5] [Batch 550/1254] [Discriminator loss: 0.260470] [Generator loss: 2.778930] - D(x): 0.8748 D(G(z)): 0.1086 / 0.0777
# [Epoch 2/5] [Batch 600/1254] [Discriminator loss: 1.574190] [Generator loss: 0.928043] - D(x): 0.2896 D(G(z)): 0.0080 / 0.4392
# [Epoch 2/5] [Batch 650/1254] [Discriminator loss: 0.394616] [Generator loss: 3.221563] - D(x): 0.8216 D(G(z)): 0.1620 / 0.0507
# [Epoch 2/5] [Batch 700/1254] [Discriminator loss: 0.451862] [Generator loss: 3.086072] - D(x): 0.8684 D(G(z)): 0.2430 / 0.0592
# [Epoch 2/5] [Batch 750/1254] [Discriminator loss: 1.760477] [Generator loss: 1.233749] - D(x): 0.2357 D(G(z)): 0.0052 / 0.3573
# [Epoch 2/5] [Batch 800/1254] [Discriminator loss: 0.276581] [Generator loss: 2.219660] - D(x): 0.8353 D(G(z)): 0.0771 / 0.1348
# [Epoch 2/5] [Batch 850/1254] [Discriminator loss: 0.338217] [Generator loss: 3.041497] - D(x): 0.8140 D(G(z)): 0.1009 / 0.0685
# [Epoch 2/5] [Batch 900/1254] [Discriminator loss: 0.427906] [Generator loss: 2.200392] - D(x): 0.7240 D(G(z)): 0.0642 / 0.1327
# [Epoch 2/5] [Batch 950/1254] [Discriminator loss: 0.341019] [Generator loss: 4.189289] - D(x): 0.9273 D(G(z)): 0.2135 / 0.0200
# [Epoch 2/5] [Batch 1000/1254] [Discriminator loss: 0.784012] [Generator loss: 6.387156] - D(x): 0.9776 D(G(z)): 0.4847 / 0.0025
# [Epoch 2/5] [Batch 1050/1254] [Discriminator loss: 0.374494] [Generator loss: 3.338926] - D(x): 0.8058 D(G(z)): 0.1187 / 0.0513
# [Epoch 2/5] [Batch 1100/1254] [Discriminator loss: 0.396426] [Generator loss: 1.864314] - D(x): 0.7885 D(G(z)): 0.1067 / 0.1931
# [Epoch 2/5] [Batch 1150/1254] [Discriminator loss: 0.533467] [Generator loss: 3.662039] - D(x): 0.9500 D(G(z)): 0.3449 / 0.0360
# [Epoch 2/5] [Batch 1200/1254] [Discriminator loss: 0.396668] [Generator loss: 2.094217] - D(x): 0.7664 D(G(z)): 0.0933 / 0.1564
# [Epoch 2/5] [Batch 1250/1254] [Discriminator loss: 0.317412] [Generator loss: 1.961462] - D(x): 0.8140 D(G(z)): 0.0853 / 0.1834
# [Epoch 3/5] [Batch 0/1254] [Discriminator loss: 0.419850] [Generator loss: 2.858757] - D(x): 0.7987 D(G(z)): 0.1466 / 0.0779
# [Epoch 3/5] [Batch 50/1254] [Discriminator loss: 0.157942] [Generator loss: 3.389265] - D(x): 0.9384 D(G(z)): 0.0852 / 0.0438
# [Epoch 3/5] [Batch 100/1254] [Discriminator loss: 0.309826] [Generator loss: 3.170166] - D(x): 0.8216 D(G(z)): 0.0799 / 0.0578
# [Epoch 3/5] [Batch 150/1254] [Discriminator loss: 0.508363] [Generator loss: 4.029644] - D(x): 0.6580 D(G(z)): 0.0228 / 0.0300
# [Epoch 3/5] [Batch 200/1254] [Discriminator loss: 0.257331] [Generator loss: 3.322697] - D(x): 0.9051 D(G(z)): 0.1364 / 0.0503
# [Epoch 3/5] [Batch 250/1254] [Discriminator loss: 0.741485] [Generator loss: 3.710510] - D(x): 0.9534 D(G(z)): 0.4515 / 0.0369
# [Epoch 3/5] [Batch 300/1254] [Discriminator loss: 0.477878] [Generator loss: 2.587901] - D(x): 0.6774 D(G(z)): 0.0422 / 0.1107
# [Epoch 3/5] [Batch 350/1254] [Discriminator loss: 0.393894] [Generator loss: 3.715609] - D(x): 0.8524 D(G(z)): 0.1800 / 0.0369
# [Epoch 3/5] [Batch 400/1254] [Discriminator loss: 0.831928] [Generator loss: 1.760390] - D(x): 0.5030 D(G(z)): 0.0156 / 0.2188
# [Epoch 3/5] [Batch 450/1254] [Discriminator loss: 0.236996] [Generator loss: 2.798039] - D(x): 0.8873 D(G(z)): 0.1026 / 0.0804
# [Epoch 3/5] [Batch 500/1254] [Discriminator loss: 0.406043] [Generator loss: 4.730944] - D(x): 0.9151 D(G(z)): 0.2452 / 0.0131
# [Epoch 3/5] [Batch 550/1254] [Discriminator loss: 0.408903] [Generator loss: 2.872436] - D(x): 0.8654 D(G(z)): 0.2081 / 0.0743
# [Epoch 3/5] [Batch 600/1254] [Discriminator loss: 1.740697] [Generator loss: 2.050946] - D(x): 0.2625 D(G(z)): 0.0061 / 0.1921
# [Epoch 3/5] [Batch 650/1254] [Discriminator loss: 0.472541] [Generator loss: 5.483294] - D(x): 0.9345 D(G(z)): 0.3093 / 0.0060
# [Epoch 3/5] [Batch 700/1254] [Discriminator loss: 0.288593] [Generator loss: 2.352942] - D(x): 0.8061 D(G(z)): 0.0509 / 0.1282
# [Epoch 3/5] [Batch 750/1254] [Discriminator loss: 0.430460] [Generator loss: 3.450295] - D(x): 0.8874 D(G(z)): 0.2405 / 0.0424
# [Epoch 3/5] [Batch 800/1254] [Discriminator loss: 0.342005] [Generator loss: 2.831875] - D(x): 0.8805 D(G(z)): 0.1733 / 0.0757
# [Epoch 3/5] [Batch 850/1254] [Discriminator loss: 0.372506] [Generator loss: 4.532300] - D(x): 0.9239 D(G(z)): 0.2403 / 0.0143
# [Epoch 3/5] [Batch 900/1254] [Discriminator loss: 1.333753] [Generator loss: 0.774614] - D(x): 0.3369 D(G(z)): 0.0036 / 0.5137
# [Epoch 3/5] [Batch 950/1254] [Discriminator loss: 0.223579] [Generator loss: 2.954263] - D(x): 0.9099 D(G(z)): 0.1099 / 0.0711
# [Epoch 3/5] [Batch 1000/1254] [Discriminator loss: 0.275226] [Generator loss: 3.073238] - D(x): 0.8322 D(G(z)): 0.0715 / 0.0696
# [Epoch 3/5] [Batch 1050/1254] [Discriminator loss: 0.530519] [Generator loss: 2.298265] - D(x): 0.6627 D(G(z)): 0.0405 / 0.1379
# [Epoch 3/5] [Batch 1100/1254] [Discriminator loss: 0.221916] [Generator loss: 3.289898] - D(x): 0.8849 D(G(z)): 0.0863 / 0.0561
# [Epoch 3/5] [Batch 1150/1254] [Discriminator loss: 2.511173] [Generator loss: 0.108199] - D(x): 0.1233 D(G(z)): 0.0047 / 0.9057
# [Epoch 3/5] [Batch 1200/1254] [Discriminator loss: 0.447874] [Generator loss: 2.562767] - D(x): 0.8449 D(G(z)): 0.2033 / 0.1215
# [Epoch 3/5] [Batch 1250/1254] [Discriminator loss: 0.346047] [Generator loss: 3.345988] - D(x): 0.7836 D(G(z)): 0.0587 / 0.0576
# [Epoch 4/5] [Batch 0/1254] [Discriminator loss: 0.405291] [Generator loss: 3.965602] - D(x): 0.9231 D(G(z)): 0.2584 / 0.0247
# [Epoch 4/5] [Batch 50/1254] [Discriminator loss: 0.544750] [Generator loss: 4.822537] - D(x): 0.9132 D(G(z)): 0.3300 / 0.0118
# [Epoch 4/5] [Batch 100/1254] [Discriminator loss: 0.316174] [Generator loss: 2.878135] - D(x): 0.8428 D(G(z)): 0.1062 / 0.0831
# [Epoch 4/5] [Batch 150/1254] [Discriminator loss: 0.299828] [Generator loss: 3.659433] - D(x): 0.8509 D(G(z)): 0.1091 / 0.0402
# [Epoch 4/5] [Batch 200/1254] [Discriminator loss: 0.794215] [Generator loss: 6.079536] - D(x): 0.9886 D(G(z)): 0.4831 / 0.0035
# [Epoch 4/5] [Batch 250/1254] [Discriminator loss: 0.498451] [Generator loss: 1.794031] - D(x): 0.6852 D(G(z)): 0.0595 / 0.2047
# [Epoch 4/5] [Batch 300/1254] [Discriminator loss: 0.226570] [Generator loss: 3.816075] - D(x): 0.9149 D(G(z)): 0.1169 / 0.0284
# [Epoch 4/5] [Batch 350/1254] [Discriminator loss: 0.270390] [Generator loss: 2.814687] - D(x): 0.9437 D(G(z)): 0.1788 / 0.0792
# [Epoch 4/5] [Batch 400/1254] [Discriminator loss: 0.439598] [Generator loss: 4.624881] - D(x): 0.8899 D(G(z)): 0.2539 / 0.0130
# [Epoch 4/5] [Batch 450/1254] [Discriminator loss: 0.333197] [Generator loss: 3.614354] - D(x): 0.9306 D(G(z)): 0.2081 / 0.0378
# [Epoch 4/5] [Batch 500/1254] [Discriminator loss: 0.410442] [Generator loss: 1.644887] - D(x): 0.7747 D(G(z)): 0.1115 / 0.2394
# [Epoch 4/5] [Batch 550/1254] [Discriminator loss: 0.176484] [Generator loss: 3.230812] - D(x): 0.9489 D(G(z)): 0.1122 / 0.0500
# [Epoch 4/5] [Batch 600/1254] [Discriminator loss: 1.082231] [Generator loss: 2.829963] - D(x): 0.4049 D(G(z)): 0.0067 / 0.0861
# [Epoch 4/5] [Batch 650/1254] [Discriminator loss: 0.272020] [Generator loss: 3.109149] - D(x): 0.9485 D(G(z)): 0.1752 / 0.0627
# [Epoch 4/5] [Batch 700/1254] [Discriminator loss: 0.272902] [Generator loss: 4.403653] - D(x): 0.9558 D(G(z)): 0.1851 / 0.0180
# [Epoch 4/5] [Batch 750/1254] [Discriminator loss: 0.224231] [Generator loss: 3.416705] - D(x): 0.8825 D(G(z)): 0.0851 / 0.0437
# [Epoch 4/5] [Batch 800/1254] [Discriminator loss: 0.360176] [Generator loss: 3.526418] - D(x): 0.7563 D(G(z)): 0.0410 / 0.0530
# [Epoch 4/5] [Batch 850/1254] [Discriminator loss: 0.142644] [Generator loss: 3.624730] - D(x): 0.9266 D(G(z)): 0.0588 / 0.0401
# [Epoch 4/5] [Batch 900/1254] [Discriminator loss: 0.153823] [Generator loss: 4.226474] - D(x): 0.9738 D(G(z)): 0.1117 / 0.0208
# [Epoch 4/5] [Batch 950/1254] [Discriminator loss: 0.565576] [Generator loss: 2.823438] - D(x): 0.6408 D(G(z)): 0.0169 / 0.1008
# [Epoch 4/5] [Batch 1000/1254] [Discriminator loss: 0.600013] [Generator loss: 4.975441] - D(x): 0.9004 D(G(z)): 0.3422 / 0.0124
# [Epoch 4/5] [Batch 1050/1254] [Discriminator loss: 0.505019] [Generator loss: 5.304254] - D(x): 0.9662 D(G(z)): 0.3477 / 0.0075
# [Epoch 4/5] [Batch 1100/1254] [Discriminator loss: 0.713241] [Generator loss: 2.680111] - D(x): 0.5529 D(G(z)): 0.0064 / 0.1019
# [Epoch 4/5] [Batch 1150/1254] [Discriminator loss: 0.491650] [Generator loss: 4.504478] - D(x): 0.9184 D(G(z)): 0.2936 / 0.0176
# [Epoch 4/5] [Batch 1200/1254] [Discriminator loss: 0.334851] [Generator loss: 2.255152] - D(x): 0.7635 D(G(z)): 0.0325 / 0.1381
# [Epoch 4/5] [Batch 1250/1254] [Discriminator loss: 0.286341] [Generator loss: 2.637150] - D(x): 0.8093 D(G(z)): 0.0438 / 0.1163

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(g_loss_to_display, label="Generator Loss")
plt.plot(d_loss_to_display, label="Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.savefig('./images/dcgan/final_loss_faces.png')
plt.show()

# %% [markdown]
# ## Final GAN Images

# %%
# %%capture
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

HTML(ani.to_jshtml())

# %%
# grab a batch of real images from the data loader
real_batch = next(iter(data_loader))

# plot the real images
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))

plt.savefig('./images/dcgan/final_images_faces.png')
plt.show()

# %% [markdown]
# ---
