# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs

from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils import to_categorical
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# generate 2d classification dataset
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)

# scatter plot for each class value
for class_value in range(3):
    # select indices of points with the class label
    row_ix = np.where(y == class_value)
    # scatter plot for points with a different color
    plt.scatter(X[row_ix, 0], X[row_ix, 1])
# show plot
plt.show()

# one hot encode output variable
y = to_categorical(y)

# %%
# split into train and test
n_train = 500

trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %% [markdown]
# ## 1) Stochastic Gradient Descent (batch_size=2, lr=0.0001)

# %%
# define model
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(3, activation='softmax'))

# %%
# compile model
opt = SGD(lr=0.0001, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=1, batch_size=2)
# Out:
# Epoch 1/200
# 250/250 [==============================] - 0s 1ms/step - loss: 1.1449 - accuracy: 0.5380 - val_loss: 0.7895 - val_accuracy: 0.6280
# Epoch 2/200
# 250/250 [==============================] - 0s 1ms/step - loss: 0.8218 - accuracy: 0.5960 - val_loss: 0.7420 - val_accuracy: 0.6600
# Epoch 3/200
# 250/250 [==============================] - 0s 1ms/step - loss: 0.7683 - accuracy: 0.6140 - val_loss: 0.6983 - val_accuracy: 0.6440
# Epoch 4/200
# 250/250 [==============================] - 0s 1ms/step - loss: 0.7612 - accuracy: 0.6140 - val_loss: 0.6498 - val_accuracy: 0.6800
# Epoch 5/200
# 250/250 [==============================] - 0s 942us/step - loss: 0.7177 - accuracy: 0.6360 - val_loss: 0.6598 - val_accuracy: 0.7340
# Epoch 6/200
# 250/250 [==============================] - 0s 1ms/step - loss: 0.7017 - accuracy: 0.6520 - val_loss: 0.6454 - val_accuracy: 0.7160
# Epoch 7/200
# ...

# %%
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.832, Test: 0.832

# %%
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## 2) Stochastic Gradient Descent (batch_size=8, lr=0.0001)

# %%
# define model
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(3, activation='softmax'))

# %%
# compile model
opt = SGD(lr=0.0001, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=1, batch_size=8)
# Out:
# Epoch 1/200
# 63/63 [==============================] - 0s 3ms/step - loss: 2.2898 - accuracy: 0.4400 - val_loss: 1.1976 - val_accuracy: 0.5840
# Epoch 2/200
# 63/63 [==============================] - 0s 1ms/step - loss: 1.0912 - accuracy: 0.5380 - val_loss: 0.9716 - val_accuracy: 0.6680
# Epoch 3/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.9665 - accuracy: 0.5620 - val_loss: 0.8973 - val_accuracy: 0.6360
# Epoch 4/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.9040 - accuracy: 0.5760 - val_loss: 0.8672 - val_accuracy: 0.6380
# Epoch 5/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.8493 - accuracy: 0.5840 - val_loss: 0.7918 - val_accuracy: 0.6380
# Epoch 6/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.8052 - accuracy: 0.6000 - val_loss: 0.7670 - val_accuracy: 0.6800
# Epoch 7/200
# ...

# %%
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.800, Test: 0.828

# %%
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## 3) Stochastic Gradient Descent (batch_size=16, lr=0.0001)

# %%
# define model
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(3, activation='softmax'))

# %%
# compile model
opt = SGD(lr=0.0001, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=1, batch_size=16)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3624 - accuracy: 0.4740 - val_loss: 1.1453 - val_accuracy: 0.6100
# Epoch 2/200
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1236 - accuracy: 0.5780 - val_loss: 0.9690 - val_accuracy: 0.7000
# Epoch 3/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.9493 - accuracy: 0.6280 - val_loss: 0.8801 - val_accuracy: 0.7020
# Epoch 4/200
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8810 - accuracy: 0.6260 - val_loss: 0.8486 - val_accuracy: 0.6720
# Epoch 5/200
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8503 - accuracy: 0.6420 - val_loss: 0.8297 - val_accuracy: 0.6740
# Epoch 6/200
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8467 - accuracy: 0.6080 - val_loss: 0.8119 - val_accuracy: 0.6640
# Epoch 7/200
# ...

# %%
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Train: 0.766, Test: 0.804

# %%
# plot training history
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ---
