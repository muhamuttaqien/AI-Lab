# %% [markdown]
# # Dueling DQN, Deep Q Learning

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from collections import namedtuple, deque

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3 # for soft update of target parameters
LR = 5e-4
PRINT_EVERY = 100
UPDATE_EVERY = 4

# %% [markdown]
# ## Set Environment

# %%
ENV_NAME = 'CartPole-v0'
env = gym.make(ENV_NAME).unwrapped; env.seed(90);

# %%
print('Environment Display:')
env.reset() # reset environment to a new, random state
env.render()

print('State space {}'.format(env.observation_space))
print('Action space {}'.format(env.action_space))
# Out:
# Environment Display:
# State space Box(4,)
# Action space Discrete(2)

# %% [markdown]
# ## Build DQN Architecture

# %%
class DQN(nn.Module):
    """Define DQN architecture."""
    
    def __init__(self, state_size, action_size, seed, fcl_units=64, fc2_units=64):
        """Initialize parameters and build model."""
        
        super(DQN, self).__init__()
        
        self.seed = torch.manual_seed(seed)
        self.action_size = action_size
        
        self.fc1_layer = nn.Linear(state_size, fcl_units)
        self.fc2_layer = nn.Linear(fcl_units, fc2_units)
        
        # decompose state & action values
        self.state_layer = nn.Linear(fc2_units, 1)
        self.advantage_layer = nn.Linear(fc2_units, action_size)
        
    def forward(self, state):
        """Build a network that maps state into action values."""
        
        state = F.relu(self.fc1_layer(state))
        state = F.relu(self.fc2_layer(state))
        
        state_value = self.state_layer(state).expand(state.size(0), self.action_size)
        advantage_value = self.advantage_layer(state)
        
        Qsa = state_value + advantage_value - advantage_value.mean(1).unsqueeze(1).expand(state.size(0), self.action_size)
        
        return Qsa

# %% [markdown]
# ## Set Replay Buffer

# %%
class ReplayBuffer(object):
    """Fixed-size buffer to store experience tuples."""
    
    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayMemory object."""
        
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to buffer."""
        
        self.memory.append(self.experience(state, action, reward, next_state, done))
        
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)
        
        states = torch.from_numpy(np.vstack([exp.state for exp in experiences if exp is not None])).float()
        states = states.to(device)
        
        actions = torch.from_numpy(np.vstack([exp.action for exp in experiences if exp is not None])).long()
        actions = actions.to(device)
        
        rewards = torch.from_numpy(np.vstack([exp.reward for exp in experiences if exp is not None])).float()
        rewards = rewards.to(device)
        
        next_states = torch.from_numpy(np.vstack([exp.next_state for exp in experiences if exp is not None])).float()
        next_states = next_states.to(device)
        
        dones = torch.from_numpy(np.vstack([exp.done for exp in experiences if exp is not None]).astype(np.uint8)).float()
        dones = dones.to(device)
        
        return (states, actions, rewards, next_states, dones)
        
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Define [Dueling DQN](https://arxiv.org/pdf/1511.06581.pdf) Agent

# %%
class Dueling_DQNAgent():
    """The agent interacting with and learning from the environment."""
    
    def __init__(self, state_size, action_size, seed):
        """Initialize an agent object."""
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        
        # Q-Network
        self.dqn_net = DQN(state_size, action_size, seed).to(device)
        self.target_net = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.dqn_net.parameters(), lr=LR)
        
        # Replay Buffer
        self.buffer = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        self.time_step = 0
        
    def memorize(self, state, action, reward, next_state, done):
        """Save experience in replay buffer."""
        
        self.buffer.add(state, action, reward, next_state, done)
    
        self.time_step = (self.time_step + 1) % UPDATE_EVERY
        if self.time_step == 0:
            # if enough samples are available in memory, get random subset and learn
            if len(self.buffer) > BATCH_SIZE:
                experiences = self.buffer.sample()
                self.learn(experiences, GAMMA)
            
    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.dqn_net.eval()
        with torch.no_grad():
            action_values = self.dqn_net(state)
        self.dqn_net.train()
        
        # epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
    
    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples."""
    
        states, actions, rewards, next_states, dones = experiences
        
        self.optimizer.zero_grad()
        
        # get index of maximum value for next state
        Qsa_next = self.dqn_net(next_states).detach()
        _, action_max = Qsa_next.max(1)

        # get max predicted Q values (for next states) from target network
        Q_target_next = self.target_net(next_states).detach().gather(1, action_max.unsqueeze(1))
        
        # compute Q target
        Q_target = rewards + (gamma * Q_target_next * (1 - dones))
        
        # get expected Q values from dqn network
        Q_expected = self.dqn_net(states).gather(1, actions)
        
        # compute loss
        loss = F.mse_loss(Q_expected, Q_target)
        
        # minimize the loss
        loss.backward()
        self.optimizer.step()
        
        # update target network
        self.soft_update(self.dqn_net, self.target_net, TAU)
        
    def soft_update(self, dqn_net, target_net, tau):
        """Soft update target network parameters."""
        
        for dqn_param, target_param in zip(dqn_net.parameters(), target_net.parameters()):
            target_param.data.copy_(tau*dqn_param.data + (1.0-tau) * target_param.data)

# %%
agent = Dueling_DQNAgent(state_size=env.observation_space.shape[0], action_size=env.action_space.n, seed=90)

# %%
# watch an untrained agent
state = env.reset()
for time_step in range(200):
    
    # select an action
    action = agent.act(state)
    env.render()
    
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes, max_time=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Train DQN agent."""
    
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    
    for i_episode in range(1, num_episodes+1):
        state = env.reset()
        score = 0
        for time_step in range(max_time):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
                
        scores_window.append(score)
        scores.append(score)
        eps = max(eps_end, eps_decay*eps)
        
        print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}', end='')
        
        if i_episode % PRINT_EVERY == 0:
            print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}')
        if np.mean(scores_window) >= 100.0:
            print(f'\nEnvironment solved in {i_episode-100:d} episodes! Average Score: {np.mean(scores_window):.2f}')
            if not os.path.exists('./agents/'): os.makedirs('./agents/')
            torch.save(agent.dqn_net.state_dict(), f'./agents/Dueling_DQN_{ENV_NAME}.pth')
            
    print('Training completed.')
    return scores

# %%
scores = train_agent(num_episodes=1000, max_time=1000)
# Out:
# Episode: 100, Average Score: 17.69
# Episode: 200, Average Score: 13.56
# Episode: 300, Average Score: 11.57
# Episode: 400, Average Score: 12.13
# Episode: 500, Average Score: 15.21
# Episode: 600, Average Score: 55.73
# Episode: 651, Average Score: 100.34
# Environment solved in 551 episodes! Average Score: 100.34
# Episode: 652, Average Score: 101.62
# Environment solved in 552 episodes! Average Score: 101.62
# Episode: 653, Average Score: 102.55
# Environment solved in 553 episodes! Average Score: 102.55
# Episode: 654, Average Score: 103.48
# Environment solved in 554 episodes! Average Score: 103.48
# Episode: 655, Average Score: 104.67
# Environment solved in 555 episodes! Average Score: 104.67
# Episode: 656, Average Score: 105.63
# Environment solved in 556 episodes! Average Score: 105.63
# Episode: 657, Average Score: 106.83
# Environment solved in 557 episodes! Average Score: 106.83
# Episode: 658, Average Score: 107.83
# Environment solved in 558 episodes! Average Score: 107.83
# Episode: 659, Average Score: 108.71
# Environment solved in 559 episodes! Average Score: 108.71
# Episode: 660, Average Score: 108.74
# Environment solved in 560 episodes! Average Score: 108.74
# Episode: 661, Average Score: 110.17
# Environment solved in 561 episodes! Average Score: 110.17
# Episode: 662, Average Score: 111.37
# Environment solved in 562 episodes! Average Score: 111.37
# Episode: 663, Average Score: 112.25
# Environment solved in 563 episodes! Average Score: 112.25
# Episode: 664, Average Score: 113.60
# Environment solved in 564 episodes! Average Score: 113.60
# Episode: 665, Average Score: 114.73
# Environment solved in 565 episodes! Average Score: 114.73
# Episode: 666, Average Score: 115.95
# Environment solved in 566 episodes! Average Score: 115.95
# Episode: 667, Average Score: 117.38
# Environment solved in 567 episodes! Average Score: 117.38
# Episode: 668, Average Score: 118.26
# Environment solved in 568 episodes! Average Score: 118.26
# Episode: 669, Average Score: 119.67
# Environment solved in 569 episodes! Average Score: 119.67
# Episode: 670, Average Score: 119.52
# Environment solved in 570 episodes! Average Score: 119.52
# Episode: 671, Average Score: 119.81
# Environment solved in 571 episodes! Average Score: 119.81
# Episode: 672, Average Score: 121.33
# Environment solved in 572 episodes! Average Score: 121.33
# Episode: 673, Average Score: 122.00
# Environment solved in 573 episodes! Average Score: 122.00
# Episode: 674, Average Score: 122.30
# Environment solved in 574 episodes! Average Score: 122.30
# Episode: 675, Average Score: 122.39
# Environment solved in 575 episodes! Average Score: 122.39
# Episode: 676, Average Score: 123.46
# Environment solved in 576 episodes! Average Score: 123.46
# Episode: 677, Average Score: 123.77
# Environment solved in 577 episodes! Average Score: 123.77
# Episode: 678, Average Score: 122.73
# Environment solved in 578 episodes! Average Score: 122.73
# Episode: 679, Average Score: 123.46
# Environment solved in 579 episodes! Average Score: 123.46
# Episode: 680, Average Score: 123.92
# Environment solved in 580 episodes! Average Score: 123.92
# Episode: 681, Average Score: 123.57
# Environment solved in 581 episodes! Average Score: 123.57
# Episode: 682, Average Score: 124.28
# Environment solved in 582 episodes! Average Score: 124.28
# Episode: 683, Average Score: 124.65
# Environment solved in 583 episodes! Average Score: 124.65
# Episode: 684, Average Score: 124.62
# Environment solved in 584 episodes! Average Score: 124.62
# Episode: 685, Average Score: 125.02
# Environment solved in 585 episodes! Average Score: 125.02
# Episode: 686, Average Score: 125.68
# Environment solved in 586 episodes! Average Score: 125.68
# Episode: 687, Average Score: 124.89
# Environment solved in 587 episodes! Average Score: 124.89
# Episode: 688, Average Score: 125.12
# Environment solved in 588 episodes! Average Score: 125.12
# Episode: 689, Average Score: 125.61
# Environment solved in 589 episodes! Average Score: 125.61
# Episode: 690, Average Score: 125.55
# Environment solved in 590 episodes! Average Score: 125.55
# Episode: 691, Average Score: 126.29
# Environment solved in 591 episodes! Average Score: 126.29
# Episode: 692, Average Score: 127.02
# Environment solved in 592 episodes! Average Score: 127.02
# Episode: 693, Average Score: 127.61
# Environment solved in 593 episodes! Average Score: 127.61
# Episode: 694, Average Score: 128.81
# Environment solved in 594 episodes! Average Score: 128.81
# Episode: 695, Average Score: 130.31
# Environment solved in 595 episodes! Average Score: 130.31
# Episode: 696, Average Score: 129.39
# Environment solved in 596 episodes! Average Score: 129.39
# Episode: 697, Average Score: 130.39
# Environment solved in 597 episodes! Average Score: 130.39
# Episode: 698, Average Score: 130.27
# Environment solved in 598 episodes! Average Score: 130.27
# Episode: 699, Average Score: 130.31
# Environment solved in 599 episodes! Average Score: 130.31
# Episode: 700, Average Score: 130.60
#
# Environment solved in 600 episodes! Average Score: 130.60
# Episode: 701, Average Score: 130.83
# Environment solved in 601 episodes! Average Score: 130.83
# Episode: 702, Average Score: 131.50
# Environment solved in 602 episodes! Average Score: 131.50
# Episode: 703, Average Score: 132.50
# Environment solved in 603 episodes! Average Score: 132.50
# Episode: 704, Average Score: 132.70
# Environment solved in 604 episodes! Average Score: 132.70
# Episode: 705, Average Score: 132.82
# Environment solved in 605 episodes! Average Score: 132.82
# Episode: 706, Average Score: 133.67
# Environment solved in 606 episodes! Average Score: 133.67
# Episode: 707, Average Score: 134.57
# Environment solved in 607 episodes! Average Score: 134.57
# Episode: 708, Average Score: 135.25
# Environment solved in 608 episodes! Average Score: 135.25
# Episode: 709, Average Score: 138.51
# Environment solved in 609 episodes! Average Score: 138.51
# Episode: 710, Average Score: 139.32
# Environment solved in 610 episodes! Average Score: 139.32
# Episode: 711, Average Score: 140.13
# Environment solved in 611 episodes! Average Score: 140.13
# Episode: 712, Average Score: 141.03
# Environment solved in 612 episodes! Average Score: 141.03
# Episode: 713, Average Score: 141.96
# Environment solved in 613 episodes! Average Score: 141.96
# Episode: 714, Average Score: 142.78
# Environment solved in 614 episodes! Average Score: 142.78
# Episode: 715, Average Score: 143.51
# Environment solved in 615 episodes! Average Score: 143.51
# Episode: 716, Average Score: 144.69
# Environment solved in 616 episodes! Average Score: 144.69
# Episode: 717, Average Score: 145.39
# Environment solved in 617 episodes! Average Score: 145.39
# Episode: 718, Average Score: 145.66
# Environment solved in 618 episodes! Average Score: 145.66
# Episode: 719, Average Score: 146.44
# Environment solved in 619 episodes! Average Score: 146.44
# Episode: 720, Average Score: 147.89
# Environment solved in 620 episodes! Average Score: 147.89
# Episode: 721, Average Score: 148.34
# Environment solved in 621 episodes! Average Score: 148.34
# Episode: 722, Average Score: 149.48
# Environment solved in 622 episodes! Average Score: 149.48
# Episode: 723, Average Score: 149.74
# Environment solved in 623 episodes! Average Score: 149.74
# Episode: 724, Average Score: 150.32
# Environment solved in 624 episodes! Average Score: 150.32
# Episode: 725, Average Score: 151.26
# Environment solved in 625 episodes! Average Score: 151.26
# Episode: 726, Average Score: 152.74
# Environment solved in 626 episodes! Average Score: 152.74
# Episode: 727, Average Score: 153.12
# Environment solved in 627 episodes! Average Score: 153.12
# Episode: 728, Average Score: 154.03
# Environment solved in 628 episodes! Average Score: 154.03
# Episode: 729, Average Score: 154.90
# Environment solved in 629 episodes! Average Score: 154.90
# Episode: 730, Average Score: 155.69
# Environment solved in 630 episodes! Average Score: 155.69
# Episode: 731, Average Score: 156.81
# Environment solved in 631 episodes! Average Score: 156.81
# Episode: 732, Average Score: 157.35
# Environment solved in 632 episodes! Average Score: 157.35
# Episode: 733, Average Score: 157.25
# Environment solved in 633 episodes! Average Score: 157.25
# Episode: 734, Average Score: 158.43
# Environment solved in 634 episodes! Average Score: 158.43
# Episode: 735, Average Score: 159.47
# Environment solved in 635 episodes! Average Score: 159.47
# Episode: 736, Average Score: 159.65
# Environment solved in 636 episodes! Average Score: 159.65
# Episode: 737, Average Score: 160.78
# Environment solved in 637 episodes! Average Score: 160.78
# Episode: 738, Average Score: 161.32
# Environment solved in 638 episodes! Average Score: 161.32
# Episode: 739, Average Score: 162.02
# Environment solved in 639 episodes! Average Score: 162.02
# Episode: 740, Average Score: 162.78
# Environment solved in 640 episodes! Average Score: 162.78
# Episode: 741, Average Score: 163.98
# Environment solved in 641 episodes! Average Score: 163.98
# Episode: 742, Average Score: 163.27
# Environment solved in 642 episodes! Average Score: 163.27
# Episode: 743, Average Score: 163.70
# Environment solved in 643 episodes! Average Score: 163.70
# Episode: 744, Average Score: 164.69
# Environment solved in 644 episodes! Average Score: 164.69
# Episode: 745, Average Score: 165.24
# Environment solved in 645 episodes! Average Score: 165.24
# Episode: 746, Average Score: 165.61
# Environment solved in 646 episodes! Average Score: 165.61
# Episode: 747, Average Score: 166.18
# Environment solved in 647 episodes! Average Score: 166.18
# Episode: 748, Average Score: 166.52
# Environment solved in 648 episodes! Average Score: 166.52
# Episode: 749, Average Score: 167.03
# Environment solved in 649 episodes! Average Score: 167.03
# Episode: 750, Average Score: 168.04
# Environment solved in 650 episodes! Average Score: 168.04
# Episode: 751, Average Score: 168.77
# Environment solved in 651 episodes! Average Score: 168.77
# Episode: 752, Average Score: 169.40
# Environment solved in 652 episodes! Average Score: 169.40
# Episode: 753, Average Score: 169.82
# Environment solved in 653 episodes! Average Score: 169.82
# Episode: 754, Average Score: 170.42
# Environment solved in 654 episodes! Average Score: 170.42
# Episode: 755, Average Score: 170.60
# Environment solved in 655 episodes! Average Score: 170.60
# Episode: 756, Average Score: 171.01
# Environment solved in 656 episodes! Average Score: 171.01
# Episode: 757, Average Score: 171.54
# Environment solved in 657 episodes! Average Score: 171.54
# Episode: 758, Average Score: 172.13
# Environment solved in 658 episodes! Average Score: 172.13
# Episode: 759, Average Score: 172.66
# Environment solved in 659 episodes! Average Score: 172.66
# Episode: 760, Average Score: 173.32
# Environment solved in 660 episodes! Average Score: 173.32
# Episode: 761, Average Score: 173.59
# Environment solved in 661 episodes! Average Score: 173.59
# Episode: 762, Average Score: 174.02
# Environment solved in 662 episodes! Average Score: 174.02
# Episode: 763, Average Score: 174.78
# Environment solved in 663 episodes! Average Score: 174.78
# Episode: 764, Average Score: 175.20
# Environment solved in 664 episodes! Average Score: 175.20
# Episode: 765, Average Score: 175.80
# Environment solved in 665 episodes! Average Score: 175.80
# Episode: 766, Average Score: 176.90
# Environment solved in 666 episodes! Average Score: 176.90
# Episode: 767, Average Score: 177.34
# Environment solved in 667 episodes! Average Score: 177.34
# Episode: 768, Average Score: 178.22
# Environment solved in 668 episodes! Average Score: 178.22
# Episode: 769, Average Score: 178.38
# Environment solved in 669 episodes! Average Score: 178.38
# Episode: 770, Average Score: 178.99
# Environment solved in 670 episodes! Average Score: 178.99
# Episode: 771, Average Score: 179.89
# Environment solved in 671 episodes! Average Score: 179.89
# Episode: 772, Average Score: 180.10
# Environment solved in 672 episodes! Average Score: 180.10
# Episode: 773, Average Score: 180.28
# Environment solved in 673 episodes! Average Score: 180.28
# Episode: 774, Average Score: 180.49
# Environment solved in 674 episodes! Average Score: 180.49
# Episode: 775, Average Score: 181.10
# Environment solved in 675 episodes! Average Score: 181.10
# Episode: 776, Average Score: 181.04
# Environment solved in 676 episodes! Average Score: 181.04
# Episode: 777, Average Score: 181.93
# Environment solved in 677 episodes! Average Score: 181.93
# Episode: 778, Average Score: 182.33
# Environment solved in 678 episodes! Average Score: 182.33
# Episode: 779, Average Score: 182.93
# Environment solved in 679 episodes! Average Score: 182.93
# Episode: 780, Average Score: 183.32
# Environment solved in 680 episodes! Average Score: 183.32
# Episode: 781, Average Score: 183.37
# Environment solved in 681 episodes! Average Score: 183.37
# Episode: 782, Average Score: 183.37
# Environment solved in 682 episodes! Average Score: 183.37
# Episode: 783, Average Score: 183.80
# Environment solved in 683 episodes! Average Score: 183.80
# Episode: 784, Average Score: 184.59
# Environment solved in 684 episodes! Average Score: 184.59
# Episode: 785, Average Score: 184.78
# Environment solved in 685 episodes! Average Score: 184.78
# Episode: 786, Average Score: 184.85
# Environment solved in 686 episodes! Average Score: 184.85
# Episode: 787, Average Score: 184.99
# Environment solved in 687 episodes! Average Score: 184.99
# Episode: 788, Average Score: 185.87
# Environment solved in 688 episodes! Average Score: 185.87
# Episode: 789, Average Score: 186.62
# Environment solved in 689 episodes! Average Score: 186.62
# Episode: 790, Average Score: 187.28
# Environment solved in 690 episodes! Average Score: 187.28
# Episode: 791, Average Score: 188.05
# Environment solved in 691 episodes! Average Score: 188.05
# Episode: 792, Average Score: 188.64
# Environment solved in 692 episodes! Average Score: 188.64
# Episode: 793, Average Score: 188.94
# Environment solved in 693 episodes! Average Score: 188.94
# Episode: 794, Average Score: 188.97
# Environment solved in 694 episodes! Average Score: 188.97
# Episode: 795, Average Score: 189.16
# Environment solved in 695 episodes! Average Score: 189.16
# Episode: 796, Average Score: 189.68
# Environment solved in 696 episodes! Average Score: 189.68
# Episode: 797, Average Score: 190.24
# Environment solved in 697 episodes! Average Score: 190.24
# Episode: 798, Average Score: 189.96
# Environment solved in 698 episodes! Average Score: 189.96
# Episode: 799, Average Score: 190.41
# Environment solved in 699 episodes! Average Score: 190.41
# Episode: 800, Average Score: 190.54
#
# Environment solved in 700 episodes! Average Score: 190.54
# Episode: 801, Average Score: 190.97
# Environment solved in 701 episodes! Average Score: 190.97
# Episode: 802, Average Score: 191.20
# Environment solved in 702 episodes! Average Score: 191.20
# Episode: 803, Average Score: 191.04
# Environment solved in 703 episodes! Average Score: 191.04
# Episode: 804, Average Score: 191.11
# Environment solved in 704 episodes! Average Score: 191.11
# Episode: 805, Average Score: 191.67
# Environment solved in 705 episodes! Average Score: 191.67
# Episode: 806, Average Score: 191.40
# Environment solved in 706 episodes! Average Score: 191.40
# Episode: 807, Average Score: 190.76
# Environment solved in 707 episodes! Average Score: 190.76
# Episode: 808, Average Score: 191.26
# Environment solved in 708 episodes! Average Score: 191.26
# Episode: 809, Average Score: 188.76
# Environment solved in 709 episodes! Average Score: 188.76
# Episode: 810, Average Score: 188.56
# Environment solved in 710 episodes! Average Score: 188.56
# Episode: 811, Average Score: 188.59
# Environment solved in 711 episodes! Average Score: 188.59
# Episode: 812, Average Score: 189.25
# Environment solved in 712 episodes! Average Score: 189.25
# Episode: 813, Average Score: 189.18
# Environment solved in 713 episodes! Average Score: 189.18
# Episode: 814, Average Score: 188.97
# Environment solved in 714 episodes! Average Score: 188.97
# Episode: 815, Average Score: 188.64
# Environment solved in 715 episodes! Average Score: 188.64
# Episode: 816, Average Score: 188.09
# Environment solved in 716 episodes! Average Score: 188.09
# Episode: 817, Average Score: 188.37
# Environment solved in 717 episodes! Average Score: 188.37
# Episode: 818, Average Score: 188.62
# Environment solved in 718 episodes! Average Score: 188.62
# Episode: 819, Average Score: 188.61
# Environment solved in 719 episodes! Average Score: 188.61
# Episode: 820, Average Score: 188.14
# Environment solved in 720 episodes! Average Score: 188.14
# Episode: 821, Average Score: 188.10
# Environment solved in 721 episodes! Average Score: 188.10
# Episode: 822, Average Score: 187.96
# Environment solved in 722 episodes! Average Score: 187.96
# Episode: 823, Average Score: 187.84
# Environment solved in 723 episodes! Average Score: 187.84
# Episode: 824, Average Score: 187.33
# Environment solved in 724 episodes! Average Score: 187.33
# Episode: 825, Average Score: 187.12
# Environment solved in 725 episodes! Average Score: 187.12
# Episode: 826, Average Score: 186.31
# Environment solved in 726 episodes! Average Score: 186.31
# Episode: 827, Average Score: 186.49
# Environment solved in 727 episodes! Average Score: 186.49
# Episode: 828, Average Score: 186.10
# Environment solved in 728 episodes! Average Score: 186.10
# Episode: 829, Average Score: 185.77
# Environment solved in 729 episodes! Average Score: 185.77
# Episode: 830, Average Score: 186.10
# Environment solved in 730 episodes! Average Score: 186.10
# Episode: 831, Average Score: 185.73
# Environment solved in 731 episodes! Average Score: 185.73
# Episode: 832, Average Score: 186.00
# Environment solved in 732 episodes! Average Score: 186.00
# Episode: 833, Average Score: 185.84
# Environment solved in 733 episodes! Average Score: 185.84
# Episode: 834, Average Score: 185.34
# Environment solved in 734 episodes! Average Score: 185.34
# Episode: 835, Average Score: 184.90
# Environment solved in 735 episodes! Average Score: 184.90
# Episode: 836, Average Score: 185.22
# Environment solved in 736 episodes! Average Score: 185.22
# Episode: 837, Average Score: 184.93
# Environment solved in 737 episodes! Average Score: 184.93
# Episode: 838, Average Score: 185.01
# Environment solved in 738 episodes! Average Score: 185.01
# Episode: 839, Average Score: 184.43
# Environment solved in 739 episodes! Average Score: 184.43
# Episode: 840, Average Score: 183.96
# Environment solved in 740 episodes! Average Score: 183.96
# Episode: 841, Average Score: 183.70
# Environment solved in 741 episodes! Average Score: 183.70
# Episode: 842, Average Score: 183.99
# Environment solved in 742 episodes! Average Score: 183.99
# Episode: 843, Average Score: 183.92
# Environment solved in 743 episodes! Average Score: 183.92
# Episode: 844, Average Score: 183.39
# Environment solved in 744 episodes! Average Score: 183.39
# Episode: 845, Average Score: 183.53
# Environment solved in 745 episodes! Average Score: 183.53
# Episode: 846, Average Score: 183.67
# Environment solved in 746 episodes! Average Score: 183.67
# Episode: 847, Average Score: 183.61
# Environment solved in 747 episodes! Average Score: 183.61
# Episode: 848, Average Score: 183.82
# Environment solved in 748 episodes! Average Score: 183.82
# Episode: 849, Average Score: 183.84
# Environment solved in 749 episodes! Average Score: 183.84
# Episode: 850, Average Score: 183.26
# Environment solved in 750 episodes! Average Score: 183.26
# Episode: 851, Average Score: 183.35
# Environment solved in 751 episodes! Average Score: 183.35
# Episode: 852, Average Score: 182.83
# Environment solved in 752 episodes! Average Score: 182.83
# Episode: 853, Average Score: 183.14
# Environment solved in 753 episodes! Average Score: 183.14
# Episode: 854, Average Score: 183.13
# Environment solved in 754 episodes! Average Score: 183.13
# Episode: 855, Average Score: 183.40
# Environment solved in 755 episodes! Average Score: 183.40
# Episode: 856, Average Score: 183.29
# Environment solved in 756 episodes! Average Score: 183.29
# Episode: 857, Average Score: 183.34
# Environment solved in 757 episodes! Average Score: 183.34
# Episode: 858, Average Score: 183.55
# Environment solved in 758 episodes! Average Score: 183.55
# Episode: 859, Average Score: 183.22
# Environment solved in 759 episodes! Average Score: 183.22
# Episode: 860, Average Score: 183.30
# Environment solved in 760 episodes! Average Score: 183.30
# Episode: 861, Average Score: 183.16
# Environment solved in 761 episodes! Average Score: 183.16
# Episode: 862, Average Score: 182.82
# Environment solved in 762 episodes! Average Score: 182.82
# Episode: 863, Average Score: 182.45
# Environment solved in 763 episodes! Average Score: 182.45
# Episode: 864, Average Score: 182.16
# Environment solved in 764 episodes! Average Score: 182.16
# Episode: 865, Average Score: 181.96
# Environment solved in 765 episodes! Average Score: 181.96
# Episode: 866, Average Score: 181.18
# Environment solved in 766 episodes! Average Score: 181.18
# Episode: 867, Average Score: 180.85
# Environment solved in 767 episodes! Average Score: 180.85
# Episode: 868, Average Score: 180.62
# Environment solved in 768 episodes! Average Score: 180.62
# Episode: 869, Average Score: 180.27
# Environment solved in 769 episodes! Average Score: 180.27
# Episode: 870, Average Score: 180.18
# Environment solved in 770 episodes! Average Score: 180.18
# Episode: 871, Average Score: 179.84
# Environment solved in 771 episodes! Average Score: 179.84
# Episode: 872, Average Score: 179.41
# Environment solved in 772 episodes! Average Score: 179.41
# Episode: 873, Average Score: 179.48
# Environment solved in 773 episodes! Average Score: 179.48
# Episode: 874, Average Score: 179.35
# Environment solved in 774 episodes! Average Score: 179.35
# Episode: 875, Average Score: 179.09
# Environment solved in 775 episodes! Average Score: 179.09
# Episode: 876, Average Score: 178.90
# Environment solved in 776 episodes! Average Score: 178.90
# Episode: 877, Average Score: 178.83
# Environment solved in 777 episodes! Average Score: 178.83
# Episode: 878, Average Score: 178.73
# Environment solved in 778 episodes! Average Score: 178.73
# Episode: 879, Average Score: 178.40
# Environment solved in 779 episodes! Average Score: 178.40
# Episode: 880, Average Score: 178.07
# Environment solved in 780 episodes! Average Score: 178.07
# Episode: 881, Average Score: 178.01
# Environment solved in 781 episodes! Average Score: 178.01
# Episode: 882, Average Score: 177.99
# Environment solved in 782 episodes! Average Score: 177.99
# Episode: 883, Average Score: 177.87
# Environment solved in 783 episodes! Average Score: 177.87
# Episode: 884, Average Score: 177.46
# Environment solved in 784 episodes! Average Score: 177.46
# Episode: 885, Average Score: 177.33
# Environment solved in 785 episodes! Average Score: 177.33
# Episode: 886, Average Score: 177.40
# Environment solved in 786 episodes! Average Score: 177.40
# Episode: 887, Average Score: 177.35
# Environment solved in 787 episodes! Average Score: 177.35
# Episode: 888, Average Score: 176.69
# Environment solved in 788 episodes! Average Score: 176.69
# Episode: 889, Average Score: 176.57
# Environment solved in 789 episodes! Average Score: 176.57
# Episode: 890, Average Score: 176.79
# Environment solved in 790 episodes! Average Score: 176.79
# Episode: 891, Average Score: 176.14
# Environment solved in 791 episodes! Average Score: 176.14
# Episode: 892, Average Score: 176.04
# Environment solved in 792 episodes! Average Score: 176.04
# Episode: 893, Average Score: 176.02
# Environment solved in 793 episodes! Average Score: 176.02
# Episode: 894, Average Score: 175.74
# Environment solved in 794 episodes! Average Score: 175.74
# Episode: 895, Average Score: 175.68
# Environment solved in 795 episodes! Average Score: 175.68
# Episode: 896, Average Score: 175.58
# Environment solved in 796 episodes! Average Score: 175.58
# Episode: 897, Average Score: 175.43
# Environment solved in 797 episodes! Average Score: 175.43
# Episode: 898, Average Score: 175.55
# Environment solved in 798 episodes! Average Score: 175.55
# Episode: 899, Average Score: 175.61
# Environment solved in 799 episodes! Average Score: 175.61
# Episode: 900, Average Score: 175.51
#
# Environment solved in 800 episodes! Average Score: 175.51
# Episode: 901, Average Score: 175.37
# Environment solved in 801 episodes! Average Score: 175.37
# Episode: 902, Average Score: 175.08
# Environment solved in 802 episodes! Average Score: 175.08
# Episode: 903, Average Score: 175.22
# Environment solved in 803 episodes! Average Score: 175.22
# Episode: 904, Average Score: 175.34
# Environment solved in 804 episodes! Average Score: 175.34
# Episode: 905, Average Score: 174.90
# Environment solved in 805 episodes! Average Score: 174.90
# Episode: 906, Average Score: 175.11
# Environment solved in 806 episodes! Average Score: 175.11
# Episode: 907, Average Score: 174.96
# Environment solved in 807 episodes! Average Score: 174.96
# Episode: 908, Average Score: 174.43
# Environment solved in 808 episodes! Average Score: 174.43
# Episode: 909, Average Score: 174.75
# Environment solved in 809 episodes! Average Score: 174.75
# Episode: 910, Average Score: 174.83
# Environment solved in 810 episodes! Average Score: 174.83
# Episode: 911, Average Score: 174.75
# Environment solved in 811 episodes! Average Score: 174.75
# Episode: 912, Average Score: 174.04
# Environment solved in 812 episodes! Average Score: 174.04
# Episode: 913, Average Score: 173.87
# Environment solved in 813 episodes! Average Score: 173.87
# Episode: 914, Average Score: 174.12
# Environment solved in 814 episodes! Average Score: 174.12
# Episode: 915, Average Score: 174.12
# Environment solved in 815 episodes! Average Score: 174.12
# Episode: 916, Average Score: 174.23
# Environment solved in 816 episodes! Average Score: 174.23
# Episode: 917, Average Score: 174.29
# Environment solved in 817 episodes! Average Score: 174.29
# Episode: 918, Average Score: 173.71
# Environment solved in 818 episodes! Average Score: 173.71
# Episode: 919, Average Score: 173.34
# Environment solved in 819 episodes! Average Score: 173.34
# Episode: 920, Average Score: 173.45
# Environment solved in 820 episodes! Average Score: 173.45
# Episode: 921, Average Score: 173.52
# Environment solved in 821 episodes! Average Score: 173.52
# Episode: 922, Average Score: 173.35
# Environment solved in 822 episodes! Average Score: 173.35
# Episode: 923, Average Score: 173.68
# Environment solved in 823 episodes! Average Score: 173.68
# Episode: 924, Average Score: 173.51
# Environment solved in 824 episodes! Average Score: 173.51
# Episode: 925, Average Score: 173.58
# Environment solved in 825 episodes! Average Score: 173.58
# Episode: 926, Average Score: 173.60
# Environment solved in 826 episodes! Average Score: 173.60
# Episode: 927, Average Score: 173.71
# Environment solved in 827 episodes! Average Score: 173.71
# Episode: 928, Average Score: 173.86
# Environment solved in 828 episodes! Average Score: 173.86
# Episode: 929, Average Score: 173.83
# Environment solved in 829 episodes! Average Score: 173.83
# Episode: 930, Average Score: 172.90
# Environment solved in 830 episodes! Average Score: 172.90
# Episode: 931, Average Score: 172.71
# Environment solved in 831 episodes! Average Score: 172.71
# Episode: 932, Average Score: 172.45
# Environment solved in 832 episodes! Average Score: 172.45
# Episode: 933, Average Score: 172.27
# Environment solved in 833 episodes! Average Score: 172.27
# Episode: 934, Average Score: 172.68
# Environment solved in 834 episodes! Average Score: 172.68
# Episode: 935, Average Score: 172.76
# Environment solved in 835 episodes! Average Score: 172.76
# Episode: 936, Average Score: 173.09
# Environment solved in 836 episodes! Average Score: 173.09
# Episode: 937, Average Score: 173.00
# Environment solved in 837 episodes! Average Score: 173.00
# Episode: 938, Average Score: 172.88
# Environment solved in 838 episodes! Average Score: 172.88
# Episode: 939, Average Score: 173.41
# Environment solved in 839 episodes! Average Score: 173.41
# Episode: 940, Average Score: 173.66
# Environment solved in 840 episodes! Average Score: 173.66
# Episode: 941, Average Score: 173.42
# Environment solved in 841 episodes! Average Score: 173.42
# Episode: 942, Average Score: 173.40
# Environment solved in 842 episodes! Average Score: 173.40
# Episode: 943, Average Score: 173.60
# Environment solved in 843 episodes! Average Score: 173.60
# Episode: 944, Average Score: 173.57
# Environment solved in 844 episodes! Average Score: 173.57
# Episode: 945, Average Score: 173.66
# Environment solved in 845 episodes! Average Score: 173.66
# Episode: 946, Average Score: 173.76
# Environment solved in 846 episodes! Average Score: 173.76
# Episode: 947, Average Score: 173.90
# Environment solved in 847 episodes! Average Score: 173.90
# Episode: 948, Average Score: 173.48
# Environment solved in 848 episodes! Average Score: 173.48
# Episode: 949, Average Score: 173.60
# Environment solved in 849 episodes! Average Score: 173.60
# Episode: 950, Average Score: 173.68
# Environment solved in 850 episodes! Average Score: 173.68
# Episode: 951, Average Score: 173.82
# Environment solved in 851 episodes! Average Score: 173.82
# Episode: 952, Average Score: 174.03
# Environment solved in 852 episodes! Average Score: 174.03
# Episode: 953, Average Score: 173.70
# Environment solved in 853 episodes! Average Score: 173.70
# Episode: 954, Average Score: 173.63
# Environment solved in 854 episodes! Average Score: 173.63
# Episode: 955, Average Score: 173.46
# Environment solved in 855 episodes! Average Score: 173.46
# Episode: 956, Average Score: 173.31
# Environment solved in 856 episodes! Average Score: 173.31
# Episode: 957, Average Score: 173.02
# Environment solved in 857 episodes! Average Score: 173.02
# Episode: 958, Average Score: 172.77
# Environment solved in 858 episodes! Average Score: 172.77
# Episode: 959, Average Score: 172.65
# Environment solved in 859 episodes! Average Score: 172.65
# Episode: 960, Average Score: 172.36
# Environment solved in 860 episodes! Average Score: 172.36
# Episode: 961, Average Score: 172.36
# Environment solved in 861 episodes! Average Score: 172.36
# Episode: 962, Average Score: 172.09
# Environment solved in 862 episodes! Average Score: 172.09
# Episode: 963, Average Score: 172.13
# Environment solved in 863 episodes! Average Score: 172.13
# Episode: 964, Average Score: 172.46
# Environment solved in 864 episodes! Average Score: 172.46
# Episode: 965, Average Score: 172.53
# Environment solved in 865 episodes! Average Score: 172.53
# Episode: 966, Average Score: 172.58
# Environment solved in 866 episodes! Average Score: 172.58
# Episode: 967, Average Score: 172.48
# Environment solved in 867 episodes! Average Score: 172.48
# Episode: 968, Average Score: 172.59
# Environment solved in 868 episodes! Average Score: 172.59
# Episode: 969, Average Score: 172.92
# Environment solved in 869 episodes! Average Score: 172.92
# Episode: 970, Average Score: 172.85
# Environment solved in 870 episodes! Average Score: 172.85
# Episode: 971, Average Score: 172.93
# Environment solved in 871 episodes! Average Score: 172.93
# Episode: 972, Average Score: 173.16
# Environment solved in 872 episodes! Average Score: 173.16
# Episode: 973, Average Score: 173.06
# Environment solved in 873 episodes! Average Score: 173.06
# Episode: 974, Average Score: 173.16
# Environment solved in 874 episodes! Average Score: 173.16
# Episode: 975, Average Score: 173.31
# Environment solved in 875 episodes! Average Score: 173.31
# Episode: 976, Average Score: 173.40
# Environment solved in 876 episodes! Average Score: 173.40
# Episode: 977, Average Score: 173.11
# Environment solved in 877 episodes! Average Score: 173.11
# Episode: 978, Average Score: 173.02
# Environment solved in 878 episodes! Average Score: 173.02
# Episode: 979, Average Score: 172.97
# Environment solved in 879 episodes! Average Score: 172.97
# Episode: 980, Average Score: 172.82
# Environment solved in 880 episodes! Average Score: 172.82
# Episode: 981, Average Score: 172.69
# Environment solved in 881 episodes! Average Score: 172.69
# Episode: 982, Average Score: 172.43
# Environment solved in 882 episodes! Average Score: 172.43
# Episode: 983, Average Score: 172.24
# Environment solved in 883 episodes! Average Score: 172.24
# Episode: 984, Average Score: 172.42
# Environment solved in 884 episodes! Average Score: 172.42
# Episode: 985, Average Score: 172.43
# Environment solved in 885 episodes! Average Score: 172.43
# Episode: 986, Average Score: 172.32
# Environment solved in 886 episodes! Average Score: 172.32
# Episode: 987, Average Score: 172.55
# Environment solved in 887 episodes! Average Score: 172.55
# Episode: 988, Average Score: 172.56
# Environment solved in 888 episodes! Average Score: 172.56
# Episode: 989, Average Score: 172.46
# Environment solved in 889 episodes! Average Score: 172.46
# Episode: 990, Average Score: 172.00
# Environment solved in 890 episodes! Average Score: 172.00
# Episode: 991, Average Score: 172.02
# Environment solved in 891 episodes! Average Score: 172.02
# Episode: 992, Average Score: 172.07
# Environment solved in 892 episodes! Average Score: 172.07
# Episode: 993, Average Score: 171.91
# Environment solved in 893 episodes! Average Score: 171.91
# Episode: 994, Average Score: 171.73
# Environment solved in 894 episodes! Average Score: 171.73
# Episode: 995, Average Score: 171.48
# Environment solved in 895 episodes! Average Score: 171.48
# Episode: 996, Average Score: 171.56
# Environment solved in 896 episodes! Average Score: 171.56
# Episode: 997, Average Score: 171.86
# Environment solved in 897 episodes! Average Score: 171.86
# Episode: 998, Average Score: 171.80
# Environment solved in 898 episodes! Average Score: 171.80
# Episode: 999, Average Score: 171.78
# Environment solved in 899 episodes! Average Score: 171.78
# Episode: 1000, Average Score: 171.83
#
# Environment solved in 900 episodes! Average Score: 171.83
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_agent_evaluation.png')
plt.show()

# %% [markdown]
# ## 🎬 Watch The Smart Agent

# %%
# load the weights of smart agent
agent.dqn_net.load_state_dict(torch.load(f'./agents/Dueling_DQN_{ENV_NAME}.pth'));

# %%
num_episodes = 5

for i_episode in range(1, num_episodes+1):
    
    state = env.reset()
    rewards = []
    for time_step in range(200):
        
        env.render() # render the screen
        
        action = policy.act(state) # select an action
        next_state, reward, done, _ = env.step(action)
        
        state = next_state
        rewards.append(reward)
        if done:
            break
            
    print(f'\rEpisode: {i_episode}, Average Score: {sum(rewards):.2f}')

env.close()

# %% [markdown]
# ---
