# %% [markdown]
# # Double DQN, Deep Q Learning

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from collections import namedtuple, deque

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3 # for soft update of target parameters
LR = 5e-4
PRINT_EVERY = 100
UPDATE_EVERY = 4

# %% [markdown]
# ## Set Environment

# %%
ENV_NAME = 'MountainCar-v0'
env = gym.make(ENV_NAME).unwrapped; env.seed(90);
# Out:
# [2020-02-06 11:06:47,871] Making new env: MountainCar-v0
# /Users/angga.muhammad/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py:17: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
print('Environment Display:')
env.reset() # reset environment to a new, random state
env.render()

print('State space {}'.format(env.observation_space))
print('Action space {}'.format(env.action_space))
# Out:
# Environment Display:
# State space Box(2,)
# Action space Discrete(3)

# %% [markdown]
# ## Build DQN Architecture

# %%
class DQN(nn.Module):
    """Define DQN architecture."""
    
    def __init__(self, state_size, action_size, seed, fcl_units=64, fc2_units=64):
        """Initialize parameters and build model."""
        
        super(DQN, self).__init__()
        
        self.seed = torch.manual_seed(seed)
        
        self.fc1_layer = nn.Linear(state_size, fcl_units)
        self.fc2_layer = nn.Linear(fcl_units, fc2_units)
        self.fc3_layer = nn.Linear(fc2_units, action_size)
        
    def forward(self, state):
        """Build a network that maps state into action values."""
        
        state = F.relu(self.fc1_layer(state))
        state = F.relu(self.fc2_layer(state))
        Qsa = self.fc3_layer(state)
        
        return Qsa

# %% [markdown]
# ## Set Replay Buffer

# %%
class ReplayBuffer(object):
    """Fixed-size buffer to store experience tuples."""
    
    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayMemory object."""
        
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to buffer."""
        
        self.memory.append(self.experience(state, action, reward, next_state, done))
        
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)
        
        states = torch.from_numpy(np.vstack([exp.state for exp in experiences if exp is not None])).float()
        states = states.to(device)
        
        actions = torch.from_numpy(np.vstack([exp.action for exp in experiences if exp is not None])).long()
        actions = actions.to(device)
        
        rewards = torch.from_numpy(np.vstack([exp.reward for exp in experiences if exp is not None])).float()
        rewards = rewards.to(device)
        
        next_states = torch.from_numpy(np.vstack([exp.next_state for exp in experiences if exp is not None])).float()
        next_states = next_states.to(device)
        
        dones = torch.from_numpy(np.vstack([exp.done for exp in experiences if exp is not None]).astype(np.uint8)).float()
        dones = dones.to(device)
        
        return (states, actions, rewards, next_states, dones)
        
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Define [Double DQN](https://arxiv.org/abs/1509.06461) Agent

# %%
class Double_DQNAgent():
    """The agent interacting with and learning from the environment."""
    
    def __init__(self, state_size, action_size, seed):
        """Initialize an agent object."""
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        
        # Q-Network
        self.dqn_net = DQN(state_size, action_size, seed).to(device)
        self.target_net = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.dqn_net.parameters(), lr=LR)
        
        # Replay Buffer
        self.buffer = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        self.time_step = 0
        
    def memorize(self, state, action, reward, next_state, done):
        """Save experience in replay buffer."""
        
        self.buffer.add(state, action, reward, next_state, done)
    
        self.time_step = (self.time_step + 1) % UPDATE_EVERY
        if self.time_step == 0:
            # if enough samples are available in memory, get random subset and learn
            if len(self.buffer) > BATCH_SIZE:
                experiences = self.buffer.sample()
                self.learn(experiences, GAMMA)
            
    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.dqn_net.eval()
        with torch.no_grad():
            action_values = self.dqn_net(state)
        self.dqn_net.train()
        
        # epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
    
    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples."""
    
        states, actions, rewards, next_states, dones = experiences
        
        self.optimizer.zero_grad()
        
        # get index of maximum value for next state
        Qsa_next = self.dqn_net(next_states).detach()
        _, action_max = Qsa_next.max(1)

        # get max predicted Q values (for next states) from target network
        Q_target_next = self.target_net(next_states).detach().gather(1, action_max.unsqueeze(1))
        
        # compute Q target
        Q_target = rewards + (gamma * Q_target_next * (1 - dones))
        
        # get expected Q values from dqn network
        Q_expected = self.dqn_net(states).gather(1, actions)
        
        # compute loss
        loss = F.mse_loss(Q_expected, Q_target)
        
        # minimize the loss
        loss.backward()
        self.optimizer.step()
        
        # update target network
        self.soft_update(self.dqn_net, self.target_net, TAU)
        
    def soft_update(self, dqn_net, target_net, tau):
        """Soft update target network parameters."""
        
        for dqn_param, target_param in zip(dqn_net.parameters(), target_net.parameters()):
            target_param.data.copy_(tau*dqn_param.data + (1.0-tau) * target_param.data)

# %%
agent = Double_DQNAgent(state_size=env.observation_space.shape[0], action_size=env.action_space.n, seed=90)

# %%
# watch an untrained agent
state = env.reset()
for time_step in range(200):
    
    # select an action
    action = agent.act(state)
    env.render()
    
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes, max_time=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Train DQN agent."""
    
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    
    for i_episode in range(1, num_episodes+1):
        state = env.reset()
        score = 0
        for time_step in range(max_time):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
                
        scores_window.append(score)
        scores.append(score)
        eps = max(eps_end, eps_decay*eps)
        
        print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}', end='')
        
        if i_episode % PRINT_EVERY == 0:
            print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}')
        if np.mean(scores_window) >= -200.0:
            print(f'\nEnvironment solved in {i_episode-100:d} episodes! Average Score: {np.mean(scores_window):.2f}')
            if not os.path.exists('./agents/'): os.makedirs('./agents/')
            torch.save(agent.dqn_net.state_dict(), f'./agents/Double_DQN_{ENV_NAME}.pth')
            
    print('Training completed.')
    return scores

# %%
scores = train_agent(num_episodes=800, max_time=1000)
# Out:
# Episode: 100, Average Score: -1000.00
# Episode: 200, Average Score: -1000.00
# Episode: 300, Average Score: -819.600
# Episode: 400, Average Score: -662.65
# Episode: 500, Average Score: -398.60
# Episode: 600, Average Score: -203.26
# Episode: 604, Average Score: -198.46
# Environment solved in 504 episodes! Average Score: -198.46
# Episode: 605, Average Score: -198.35
# Environment solved in 505 episodes! Average Score: -198.35
# Episode: 606, Average Score: -197.49
# Environment solved in 506 episodes! Average Score: -197.49
# Episode: 607, Average Score: -194.87
# Environment solved in 507 episodes! Average Score: -194.87
# Episode: 608, Average Score: -193.58
# Environment solved in 508 episodes! Average Score: -193.58
# Episode: 609, Average Score: -192.58
# Environment solved in 509 episodes! Average Score: -192.58
# Episode: 610, Average Score: -192.68
# Environment solved in 510 episodes! Average Score: -192.68
# Episode: 611, Average Score: -192.45
# Environment solved in 511 episodes! Average Score: -192.45
# Episode: 612, Average Score: -191.17
# Environment solved in 512 episodes! Average Score: -191.17
# Episode: 613, Average Score: -191.68
# Environment solved in 513 episodes! Average Score: -191.68
# Episode: 614, Average Score: -191.19
# Environment solved in 514 episodes! Average Score: -191.19
# Episode: 615, Average Score: -190.30
# Environment solved in 515 episodes! Average Score: -190.30
# Episode: 616, Average Score: -190.33
# Environment solved in 516 episodes! Average Score: -190.33
# Episode: 617, Average Score: -189.29
# Environment solved in 517 episodes! Average Score: -189.29
# Episode: 618, Average Score: -189.25
# Environment solved in 518 episodes! Average Score: -189.25
# Episode: 619, Average Score: -190.14
# Environment solved in 519 episodes! Average Score: -190.14
# Episode: 620, Average Score: -191.93
# Environment solved in 520 episodes! Average Score: -191.93
# Episode: 621, Average Score: -191.01
# Environment solved in 521 episodes! Average Score: -191.01
# Episode: 622, Average Score: -190.77
# Environment solved in 522 episodes! Average Score: -190.77
# Episode: 623, Average Score: -191.11
# Environment solved in 523 episodes! Average Score: -191.11
# Episode: 624, Average Score: -190.34
# Environment solved in 524 episodes! Average Score: -190.34
# Episode: 625, Average Score: -189.20
# Environment solved in 525 episodes! Average Score: -189.20
# Episode: 626, Average Score: -187.78
# Environment solved in 526 episodes! Average Score: -187.78
# Episode: 627, Average Score: -188.76
# Environment solved in 527 episodes! Average Score: -188.76
# Episode: 628, Average Score: -188.04
# Environment solved in 528 episodes! Average Score: -188.04
# Episode: 629, Average Score: -186.07
# Environment solved in 529 episodes! Average Score: -186.07
# Episode: 630, Average Score: -184.84
# Environment solved in 530 episodes! Average Score: -184.84
# Episode: 631, Average Score: -183.80
# Environment solved in 531 episodes! Average Score: -183.80
# Episode: 632, Average Score: -183.04
# Environment solved in 532 episodes! Average Score: -183.04
# Episode: 633, Average Score: -181.29
# Environment solved in 533 episodes! Average Score: -181.29
# Episode: 634, Average Score: -180.09
# Environment solved in 534 episodes! Average Score: -180.09
# Episode: 635, Average Score: -178.89
# Environment solved in 535 episodes! Average Score: -178.89
# Episode: 636, Average Score: -179.01
# Environment solved in 536 episodes! Average Score: -179.01
# Episode: 637, Average Score: -178.65
# Environment solved in 537 episodes! Average Score: -178.65
# Episode: 638, Average Score: -178.91
# Environment solved in 538 episodes! Average Score: -178.91
# Episode: 639, Average Score: -178.09
# Environment solved in 539 episodes! Average Score: -178.09
# Episode: 640, Average Score: -176.29
# Environment solved in 540 episodes! Average Score: -176.29
# Episode: 641, Average Score: -173.96
# Environment solved in 541 episodes! Average Score: -173.96
# Episode: 642, Average Score: -172.42
# Environment solved in 542 episodes! Average Score: -172.42
# Episode: 643, Average Score: -172.15
# Environment solved in 543 episodes! Average Score: -172.15
# Episode: 644, Average Score: -171.18
# Environment solved in 544 episodes! Average Score: -171.18
# Episode: 645, Average Score: -169.72
# Environment solved in 545 episodes! Average Score: -169.72
# Episode: 646, Average Score: -169.83
# Environment solved in 546 episodes! Average Score: -169.83
# Episode: 647, Average Score: -169.28
# Environment solved in 547 episodes! Average Score: -169.28
# Episode: 648, Average Score: -168.12
# Environment solved in 548 episodes! Average Score: -168.12
# Episode: 649, Average Score: -167.25
# Environment solved in 549 episodes! Average Score: -167.25
# Episode: 650, Average Score: -167.65
# Environment solved in 550 episodes! Average Score: -167.65
# Episode: 651, Average Score: -167.60
# Environment solved in 551 episodes! Average Score: -167.60
# Episode: 652, Average Score: -166.84
# Environment solved in 552 episodes! Average Score: -166.84
# Episode: 653, Average Score: -167.59
# Environment solved in 553 episodes! Average Score: -167.59
# Episode: 654, Average Score: -168.17
# Environment solved in 554 episodes! Average Score: -168.17
# Episode: 655, Average Score: -168.18
# Environment solved in 555 episodes! Average Score: -168.18
# Episode: 656, Average Score: -167.42
# Environment solved in 556 episodes! Average Score: -167.42
# Episode: 657, Average Score: -166.61
# Environment solved in 557 episodes! Average Score: -166.61
# Episode: 658, Average Score: -166.70
# Environment solved in 558 episodes! Average Score: -166.70
# Episode: 659, Average Score: -166.51
# Environment solved in 559 episodes! Average Score: -166.51
# Episode: 660, Average Score: -165.51
# Environment solved in 560 episodes! Average Score: -165.51
# Episode: 661, Average Score: -165.52
# Environment solved in 561 episodes! Average Score: -165.52
# Episode: 662, Average Score: -166.34
# Environment solved in 562 episodes! Average Score: -166.34
# Episode: 663, Average Score: -165.53
# Environment solved in 563 episodes! Average Score: -165.53
# Episode: 664, Average Score: -164.09
# Environment solved in 564 episodes! Average Score: -164.09
# Episode: 665, Average Score: -164.29
# Environment solved in 565 episodes! Average Score: -164.29
# Episode: 666, Average Score: -163.68
# Environment solved in 566 episodes! Average Score: -163.68
# Episode: 667, Average Score: -164.54
# Environment solved in 567 episodes! Average Score: -164.54
# Episode: 668, Average Score: -165.38
# Environment solved in 568 episodes! Average Score: -165.38
# Episode: 669, Average Score: -165.42
# Environment solved in 569 episodes! Average Score: -165.42
# Episode: 670, Average Score: -165.85
# Environment solved in 570 episodes! Average Score: -165.85
# Episode: 671, Average Score: -166.36
# Environment solved in 571 episodes! Average Score: -166.36
# Episode: 672, Average Score: -165.02
# Environment solved in 572 episodes! Average Score: -165.02
# Episode: 673, Average Score: -166.45
# Environment solved in 573 episodes! Average Score: -166.45
# Episode: 674, Average Score: -165.77
# Environment solved in 574 episodes! Average Score: -165.77
# Episode: 675, Average Score: -166.18
# Environment solved in 575 episodes! Average Score: -166.18
# Episode: 676, Average Score: -166.71
# Environment solved in 576 episodes! Average Score: -166.71
# Episode: 677, Average Score: -167.29
# Environment solved in 577 episodes! Average Score: -167.29
# Episode: 678, Average Score: -168.22
# Environment solved in 578 episodes! Average Score: -168.22
# Episode: 679, Average Score: -167.06
# Environment solved in 579 episodes! Average Score: -167.06
# Episode: 680, Average Score: -167.63
# Environment solved in 580 episodes! Average Score: -167.63
# Episode: 681, Average Score: -165.84
# Environment solved in 581 episodes! Average Score: -165.84
# Episode: 682, Average Score: -165.92
# Environment solved in 582 episodes! Average Score: -165.92
# Episode: 683, Average Score: -165.83
# Environment solved in 583 episodes! Average Score: -165.83
# Episode: 684, Average Score: -166.53
# Environment solved in 584 episodes! Average Score: -166.53
# Episode: 685, Average Score: -166.80
# Environment solved in 585 episodes! Average Score: -166.80
# Episode: 686, Average Score: -166.19
# Environment solved in 586 episodes! Average Score: -166.19
# Episode: 687, Average Score: -166.76
# Environment solved in 587 episodes! Average Score: -166.76
# Episode: 688, Average Score: -167.87
# Environment solved in 588 episodes! Average Score: -167.87
# Episode: 689, Average Score: -167.60
# Environment solved in 589 episodes! Average Score: -167.60
# Episode: 690, Average Score: -167.15
# Environment solved in 590 episodes! Average Score: -167.15
# Episode: 691, Average Score: -166.91
# Environment solved in 591 episodes! Average Score: -166.91
# Episode: 692, Average Score: -167.07
# Environment solved in 592 episodes! Average Score: -167.07
# Episode: 693, Average Score: -167.45
# Environment solved in 593 episodes! Average Score: -167.45
# Episode: 694, Average Score: -166.80
# Environment solved in 594 episodes! Average Score: -166.80
# Episode: 695, Average Score: -165.50
# Environment solved in 595 episodes! Average Score: -165.50
# Episode: 696, Average Score: -165.14
# Environment solved in 596 episodes! Average Score: -165.14
# Episode: 697, Average Score: -164.36
# Environment solved in 597 episodes! Average Score: -164.36
# Episode: 698, Average Score: -163.77
# Environment solved in 598 episodes! Average Score: -163.77
# Episode: 699, Average Score: -163.54
# Environment solved in 599 episodes! Average Score: -163.54
# Episode: 700, Average Score: -163.39
#
# Environment solved in 600 episodes! Average Score: -163.39
# Episode: 701, Average Score: -163.38
# Environment solved in 601 episodes! Average Score: -163.38
# Episode: 702, Average Score: -163.38
# Environment solved in 602 episodes! Average Score: -163.38
# Episode: 703, Average Score: -163.35
# Environment solved in 603 episodes! Average Score: -163.35
# Episode: 704, Average Score: -163.35
# Environment solved in 604 episodes! Average Score: -163.35
# Episode: 705, Average Score: -163.92
# Environment solved in 605 episodes! Average Score: -163.92
# Episode: 706, Average Score: -164.57
# Environment solved in 606 episodes! Average Score: -164.57
# Episode: 707, Average Score: -164.36
# Environment solved in 607 episodes! Average Score: -164.36
# Episode: 708, Average Score: -164.80
# Environment solved in 608 episodes! Average Score: -164.80
# Episode: 709, Average Score: -166.88
# Environment solved in 609 episodes! Average Score: -166.88
# Episode: 710, Average Score: -166.61
# Environment solved in 610 episodes! Average Score: -166.61
# Episode: 711, Average Score: -167.26
# Environment solved in 611 episodes! Average Score: -167.26
# Episode: 712, Average Score: -167.43
# Environment solved in 612 episodes! Average Score: -167.43
# Episode: 713, Average Score: -167.06
# Environment solved in 613 episodes! Average Score: -167.06
# Episode: 714, Average Score: -166.34
# Environment solved in 614 episodes! Average Score: -166.34
# Episode: 715, Average Score: -167.02
# Environment solved in 615 episodes! Average Score: -167.02
# Episode: 716, Average Score: -166.47
# Environment solved in 616 episodes! Average Score: -166.47
# Episode: 717, Average Score: -167.57
# Environment solved in 617 episodes! Average Score: -167.57
# Episode: 718, Average Score: -167.87
# Environment solved in 618 episodes! Average Score: -167.87
# Episode: 719, Average Score: -168.19
# Environment solved in 619 episodes! Average Score: -168.19
# Episode: 720, Average Score: -166.58
# Environment solved in 620 episodes! Average Score: -166.58
# Episode: 721, Average Score: -166.49
# Environment solved in 621 episodes! Average Score: -166.49
# Episode: 722, Average Score: -166.68
# Environment solved in 622 episodes! Average Score: -166.68
# Episode: 723, Average Score: -165.84
# Environment solved in 623 episodes! Average Score: -165.84
# Episode: 724, Average Score: -165.67
# Environment solved in 624 episodes! Average Score: -165.67
# Episode: 725, Average Score: -165.41
# Environment solved in 625 episodes! Average Score: -165.41
# Episode: 726, Average Score: -165.71
# Environment solved in 626 episodes! Average Score: -165.71
# Episode: 727, Average Score: -165.11
# Environment solved in 627 episodes! Average Score: -165.11
# Episode: 728, Average Score: -164.97
# Environment solved in 628 episodes! Average Score: -164.97
# Episode: 729, Average Score: -165.58
# Environment solved in 629 episodes! Average Score: -165.58
# Episode: 730, Average Score: -165.93
# Environment solved in 630 episodes! Average Score: -165.93
# Episode: 731, Average Score: -166.97
# Environment solved in 631 episodes! Average Score: -166.97
# Episode: 732, Average Score: -166.67
# Environment solved in 632 episodes! Average Score: -166.67
# Episode: 733, Average Score: -166.65
# Environment solved in 633 episodes! Average Score: -166.65
# Episode: 734, Average Score: -167.61
# Environment solved in 634 episodes! Average Score: -167.61
# Episode: 735, Average Score: -168.33
# Environment solved in 635 episodes! Average Score: -168.33
# Episode: 736, Average Score: -169.09
# Environment solved in 636 episodes! Average Score: -169.09
# Episode: 737, Average Score: -167.98
# Environment solved in 637 episodes! Average Score: -167.98
# Episode: 738, Average Score: -168.33
# Environment solved in 638 episodes! Average Score: -168.33
# Episode: 739, Average Score: -168.95
# Environment solved in 639 episodes! Average Score: -168.95
# Episode: 740, Average Score: -169.45
# Environment solved in 640 episodes! Average Score: -169.45
# Episode: 741, Average Score: -169.14
# Environment solved in 641 episodes! Average Score: -169.14
# Episode: 742, Average Score: -169.30
# Environment solved in 642 episodes! Average Score: -169.30
# Episode: 743, Average Score: -168.60
# Environment solved in 643 episodes! Average Score: -168.60
# Episode: 744, Average Score: -169.07
# Environment solved in 644 episodes! Average Score: -169.07
# Episode: 745, Average Score: -169.44
# Environment solved in 645 episodes! Average Score: -169.44
# Episode: 746, Average Score: -169.42
# Environment solved in 646 episodes! Average Score: -169.42
# Episode: 747, Average Score: -169.06
# Environment solved in 647 episodes! Average Score: -169.06
# Episode: 748, Average Score: -169.05
# Environment solved in 648 episodes! Average Score: -169.05
# Episode: 749, Average Score: -169.08
# Environment solved in 649 episodes! Average Score: -169.08
# Episode: 750, Average Score: -168.88
# Environment solved in 650 episodes! Average Score: -168.88
# Episode: 751, Average Score: -168.91
# Environment solved in 651 episodes! Average Score: -168.91
# Episode: 752, Average Score: -169.42
# Environment solved in 652 episodes! Average Score: -169.42
# Episode: 753, Average Score: -168.52
# Environment solved in 653 episodes! Average Score: -168.52
# Episode: 754, Average Score: -168.28
# Environment solved in 654 episodes! Average Score: -168.28
# Episode: 755, Average Score: -169.95
# Environment solved in 655 episodes! Average Score: -169.95
# Episode: 756, Average Score: -170.62
# Environment solved in 656 episodes! Average Score: -170.62
# Episode: 757, Average Score: -170.50
# Environment solved in 657 episodes! Average Score: -170.50
# Episode: 758, Average Score: -170.29
# Environment solved in 658 episodes! Average Score: -170.29
# Episode: 759, Average Score: -170.31
# Environment solved in 659 episodes! Average Score: -170.31
# Episode: 760, Average Score: -170.49
# Environment solved in 660 episodes! Average Score: -170.49
# Episode: 761, Average Score: -170.76
# Environment solved in 661 episodes! Average Score: -170.76
# Episode: 762, Average Score: -170.71
# Environment solved in 662 episodes! Average Score: -170.71
# Episode: 763, Average Score: -170.57
# Environment solved in 663 episodes! Average Score: -170.57
# Episode: 764, Average Score: -170.48
# Environment solved in 664 episodes! Average Score: -170.48
# Episode: 765, Average Score: -169.63
# Environment solved in 665 episodes! Average Score: -169.63
# Episode: 766, Average Score: -169.09
# Environment solved in 666 episodes! Average Score: -169.09
# Episode: 767, Average Score: -168.41
# Environment solved in 667 episodes! Average Score: -168.41
# Episode: 768, Average Score: -167.96
# Environment solved in 668 episodes! Average Score: -167.96
# Episode: 769, Average Score: -167.15
# Environment solved in 669 episodes! Average Score: -167.15
# Episode: 770, Average Score: -166.55
# Environment solved in 670 episodes! Average Score: -166.55
# Episode: 771, Average Score: -165.03
# Environment solved in 671 episodes! Average Score: -165.03
# Episode: 772, Average Score: -166.14
# Environment solved in 672 episodes! Average Score: -166.14
# Episode: 773, Average Score: -164.96
# Environment solved in 673 episodes! Average Score: -164.96
# Episode: 774, Average Score: -164.99
# Environment solved in 674 episodes! Average Score: -164.99
# Episode: 775, Average Score: -165.33
# Environment solved in 675 episodes! Average Score: -165.33
# Episode: 776, Average Score: -164.88
# Environment solved in 676 episodes! Average Score: -164.88
# Episode: 777, Average Score: -164.54
# Environment solved in 677 episodes! Average Score: -164.54
# Episode: 778, Average Score: -163.51
# Environment solved in 678 episodes! Average Score: -163.51
# Episode: 779, Average Score: -163.49
# Environment solved in 679 episodes! Average Score: -163.49
# Episode: 780, Average Score: -163.54
# Environment solved in 680 episodes! Average Score: -163.54
# Episode: 781, Average Score: -163.87
# Environment solved in 681 episodes! Average Score: -163.87
# Episode: 782, Average Score: -163.74
# Environment solved in 682 episodes! Average Score: -163.74
# Episode: 783, Average Score: -163.44
# Environment solved in 683 episodes! Average Score: -163.44
# Episode: 784, Average Score: -162.29
# Environment solved in 684 episodes! Average Score: -162.29
# Episode: 785, Average Score: -161.44
# Environment solved in 685 episodes! Average Score: -161.44
# Episode: 786, Average Score: -161.82
# Environment solved in 686 episodes! Average Score: -161.82
# Episode: 787, Average Score: -161.24
# Environment solved in 687 episodes! Average Score: -161.24
# Episode: 788, Average Score: -160.52
# Environment solved in 688 episodes! Average Score: -160.52
# Episode: 789, Average Score: -159.71
# Environment solved in 689 episodes! Average Score: -159.71
# Episode: 790, Average Score: -159.70
# Environment solved in 690 episodes! Average Score: -159.70
# Episode: 791, Average Score: -159.17
# Environment solved in 691 episodes! Average Score: -159.17
# Episode: 792, Average Score: -158.97
# Environment solved in 692 episodes! Average Score: -158.97
# Episode: 793, Average Score: -158.51
# Environment solved in 693 episodes! Average Score: -158.51
# Episode: 794, Average Score: -158.38
# Environment solved in 694 episodes! Average Score: -158.38
# Episode: 795, Average Score: -159.01
# Environment solved in 695 episodes! Average Score: -159.01
# Episode: 796, Average Score: -160.04
# Environment solved in 696 episodes! Average Score: -160.04
# Episode: 797, Average Score: -159.33
# Environment solved in 697 episodes! Average Score: -159.33
# Episode: 798, Average Score: -158.59
# Environment solved in 698 episodes! Average Score: -158.59
# Episode: 799, Average Score: -158.61
# Environment solved in 699 episodes! Average Score: -158.61
# Episode: 800, Average Score: -157.73
#
# Environment solved in 700 episodes! Average Score: -157.73
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_agent_evaluation.png')
plt.show()

# %% [markdown]
# ## 🎬 Watch The Smart Agent

# %%
# load the weights of smart agent
agent.dqn_net.load_state_dict(torch.load(f'./agents/Double_DQN_{ENV_NAME}.pth'));

# %%
num_episodes = 5

for i_episode in range(1, num_episodes+1):
    
    state = env.reset()
    rewards = []
    for time_step in range(200):
        
        env.render() # render the screen
        action = agent.act(state) # select an action
        next_state, reward, done, _ = env.step(action)
        
        state = next_state
        rewards.append(reward)
        if done:
            break
            
    print(f'\rEpisode: {i_episode}, Average Score: {sum(rewards):.2f}')

env.close()

# %% [markdown]
# ---
