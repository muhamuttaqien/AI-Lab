# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from IPython.display import clear_output
from collections import namedtuple, deque

from unityagents import UnityEnvironment

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler

# %%
from buffer import ReplayBuffer
from model import ActorNetwork, CriticNetwork

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BATCH_SIZE = 32
GAMMA = 0.995
ENTROPY_WEIGHT = 0.001
EPS_CLIP = 1e-1
GRAD_CLIP = 5e-1
DEQUE_SIZE = 100

GOALIE_LR = 8e-5
STRIKER_LR = 1e-4

# %%
TRAINED_AGENT_KEY = 0
RANDOM_AGENT_KEY = 1

# %% [markdown]
# ## Set Environment

# %%
env = UnityEnvironment(file_name='./Soccer.app', no_graphics=True)

env_info = env.reset(train_mode=True)

goalie_brain_name = env.brain_names[0]
goalie_state_size = env_info[goalie_brain_name].vector_observations.shape[1]
goalie_action_size = env.brains[goalie_brain_name].vector_action_space_size

striker_brain_name = env.brain_names[1]
striker_state_size = env_info[striker_brain_name].vector_observations.shape[1]
striker_action_size = env.brains[striker_brain_name].vector_action_space_size
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 2
#         Number of External Brains : 2
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: GoalieBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 112
#         Number of stacked Vector Observation: 3
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Unity brain name: StrikerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 112
#         Number of stacked Vector Observation: 3
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 6
#         Vector Action descriptions: , , , , ,

# %% [markdown]
# ## Define [A2C](https://arxiv.org/pdf/1602.01783.pdf) Agent

# %%
class PPOAgent():
    """The Agent that will interacts with and learns from the environment."""
    
    def __init__(self, env, mode='Goalie', seed=90):
        """Initialize an Agent object."""
        
        self.env_info = env.reset(train_mode=True)
                
        if mode == 'Goalie': brain_name = env.brain_names[0] # brain name for Goalie
        elif mode == 'Striker': brain_name = env.brain_names[1] # brain name for Striker
            
        self.state_size = self.env_info[brain_name].vector_observations.shape[1]
        self.action_size = env.brains[brain_name].vector_action_space_size
        
        self.batch_size = BATCH_SIZE
        self.gamma = GAMMA
        self.entropy_weight = ENTROPY_WEIGHT
        self.eps_clip = EPS_CLIP       
        self.grad_clip = GRAD_CLIP
        
        if mode == 'Goalie': self.lr = GOALIE_LR
        elif mode == 'Striker':  self.lr = STRIKER_LR
            
        self.actor = ActorNetwork(self.state_size, self.action_size, seed).to(device)
        self.critic = CriticNetwork(2 * len(env_info[goalie_brain_name].agents) * self.state_size, seed).to(device)
        self.optimizer = torch.optim.Adam(list(self.actor.parameters()) + list(self.critic.parameters()), lr=self.lr)
        
        self.buffer = ReplayBuffer(self.batch_size, seed)
        
    def act(self, states):
        
        states = torch.FloatTensor(states).unsqueeze(0).to(device)
        
        self.actor.eval()
        
        with torch.no_grad():
            actions, action_log_probs, _ = self.actor(states)
            
        actions = actions.cpu().detach().numpy().item()
        action_log_probs = action_log_probs.cpu().detach().numpy().item()
        
        self.actor.train()
        
        return actions, action_log_probs
    
    def memorize(self, actor_state, critic_state, action, log_prob, reward):
        
        self.buffer.add(actor_state, critic_state, action, log_prob, reward)
    
    def learn(self):
        
        actor_states, critic_states, actions, old_log_probs, rewards, num_experiences = self.buffer.get_experiences()
        
        discount = self.gamma**np.arange(num_experiences)
        rewards = rewards.squeeze(1) * discount
        next_rewards = rewards[::-1].cumsum(axis=0)[::-1]
        
        actor_states = torch.FloatTensor(actor_states).to(device)
        critic_states = torch.FloatTensor(critic_states).to(device)
        actions = torch.LongTensor(actions).squeeze(1).to(device)
        old_log_probs = torch.FloatTensor(old_log_probs).squeeze(1).to(device)
        rewards = torch.FloatTensor(next_rewards.copy()).to(device)

        self.critic.eval()
        with torch.no_grad():
            state_values = self.critic(critic_states)
        
        self.critic.train()
        
        advantages = (rewards - state_values.detach().squeeze())
        advantages = advantages.detach()
        advantages_normalized = (advantages - advantages.mean()) / (advantages.std() + 1e-10)
        advantages_normalized = torch.FloatTensor(advantages_normalized).to(device)
        
        batches = BatchSampler(SubsetRandomSampler(range(0, num_experiences)), self.batch_size, drop_last=False)
        losses = []
        
        for batch_indices in batches:
            
            batch_indices = torch.LongTensor(batch_indices).to(device)
            
            sampled_actor_states = actor_states[batch_indices]
            sampled_critic_states = critic_states[batch_indices]
            sampled_actions = actions[batch_indices]
            sampled_old_log_probs = old_log_probs[batch_indices]
            sampled_rewards = rewards[batch_indices]
            sampled_advantages_normalized = advantages_normalized[batch_indices]
        
            _, log_probs, dist_entropies = self.actor(sampled_actor_states, sampled_actions)
            state_values = self.critic(sampled_critic_states)
            state_values = state_values.squeeze()
            
            ratios = torch.exp(log_probs - sampled_old_log_probs.detach())
            
            surrogate1 = ratios * sampled_advantages_normalized
            surrogate2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * sampled_advantages_normalized
                
            policy_loss = -torch.min(surrogate1, surrogate2).mean() - self.entropy_weight * dist_entropies.mean()
            value_loss = 0.5 * (sampled_rewards - state_values).pow(2).mean()
            
            total_loss = policy_loss + value_loss

            self.optimizer.zero_grad()
            total_loss.backward()
            nn.utils.clip_grad_norm_(self.actor.parameters(), self.grad_clip)
            nn.utils.clip_grad_norm_(self.critic.parameters(), self.grad_clip)
            self.optimizer.step()
            
            losses.append(total_loss.item())
            
        self.buffer.reset()
            
        self.eps_clip *= 1.
        self.entropy_weight *= 0.995
        
        return np.average(losses)
    
    def save(self, actor_path, critic_path):
        
        if not os.path.exists('./agents/'): os.makedirs('./agents/')
        torch.save(self.actor.state_dict(), actor_path); torch.save(self.critic.state_dict(), critic_path);
        
    def load(self, actor_path, critic_path):
        
        self.actor.load_state_dict(torch.load(actor_path)); self.critic.load_state_dict(torch.load(critic_path));

# %%
goalie = PPOAgent(env, mode='Goalie', seed=90); striker = PPOAgent(env, mode='Striker', seed=90);

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes=10000):
    
    all_scores = []
    scores_target = 95.0
    
    trained_agent_scores_window = deque(maxlen=DEQUE_SIZE)
    trained_agent_scores_window_wins = deque(maxlen=DEQUE_SIZE)

    random_agent_scores_window = deque(maxlen=DEQUE_SIZE)
    random_agent_scores_window_wins = deque(maxlen=DEQUE_SIZE)
    
    draws = deque(maxlen=DEQUE_SIZE)
    
    # training loop
    for i_episode in range(1, num_episodes+1):

        env_info = env.reset(train_mode=True)
        
        goalie_states = env_info[goalie_brain_name].vector_observations
        striker_states = env_info[striker_brain_name].vector_observations
        
        goalie_scores = np.zeros(len(env_info[goalie_brain_name].agents))
        striker_scores = np.zeros(len(env_info[striker_brain_name].agents))
        
        while True:
            
            trained_goalie_action, trained_goalie_log_prob = goalie.act(goalie_states[TRAINED_AGENT_KEY])
            trained_striker_action, trained_striker_log_prob = striker.act(striker_states[TRAINED_AGENT_KEY])
            
            random_goalie_action = np.asarray([np.random.choice(goalie_action_size)])
            random_striker_action = np.asarray([np.random.choice(striker_action_size)])
            
            goalie_actions = np.array((trained_goalie_action, random_goalie_action))
            striker_actions = np.array((trained_striker_action, random_striker_action))
            
            actions = dict(zip([goalie_brain_name, striker_brain_name], [goalie_actions, striker_actions]))
            
            env_info = env.step(actions)
            
            # agents get next states
            goalie_next_states = env_info[goalie_brain_name].vector_observations
            striker_next_states = env_info[striker_brain_name].vector_observations
            
            # agents get rewards
            goalie_rewards = env_info[goalie_brain_name].rewards
            striker_rewards = env_info[striker_brain_name].rewards
            
            # agents update scores
            goalie_scores += goalie_rewards
            striker_scores += striker_rewards
            
            # agents memorize experiences
            trained_goalie_reward = goalie_rewards[TRAINED_AGENT_KEY]
            goalie.memorize(goalie_states[TRAINED_AGENT_KEY], 
                            np.concatenate((goalie_states[TRAINED_AGENT_KEY], 
                                            striker_states[TRAINED_AGENT_KEY], 
                                            goalie_states[RANDOM_AGENT_KEY], 
                                            striker_states[RANDOM_AGENT_KEY]), axis=0), trained_goalie_action, trained_goalie_log_prob, trained_goalie_reward)
            
            trained_striker_reward = striker_rewards[TRAINED_AGENT_KEY]
            striker.memorize(striker_states[TRAINED_AGENT_KEY], 
                             np.concatenate((striker_states[TRAINED_AGENT_KEY], 
                                             goalie_states[TRAINED_AGENT_KEY], 
                                             striker_states[RANDOM_AGENT_KEY], 
                                             goalie_states[RANDOM_AGENT_KEY]), axis=0), trained_striker_action, trained_striker_log_prob, trained_striker_reward)
            
            # agents roll over states to next states
            goalie_states = goalie_next_states
            striker_states = striker_next_states
            
            # check if episode finished
            done = np.any(env_info[goalie_brain_name].local_done)
            if done: break  

        # agents learn from collected experiences
        goalie_loss = goalie.learn()
        striker_loss = striker.learn()

        # agents record scores
        trained_agent_score = goalie_scores[TRAINED_AGENT_KEY] + striker_scores[TRAINED_AGENT_KEY]
        trained_agent_scores_window.append(trained_agent_score)
        trained_agent_scores_window_wins.append(1 if trained_agent_score > 0 else 0)

        random_agent_score = goalie_scores[RANDOM_AGENT_KEY] + striker_scores[RANDOM_AGENT_KEY]
        random_agent_scores_window.append(random_agent_score)
        random_agent_scores_window_wins.append(1 if random_agent_score > 0 else 0)

        draws.append(trained_agent_score == random_agent_score)

        print(f'\rEpisode: {i_episode}, Goalie Loss: {goalie_loss:.4f}, Striker Loss: {striker_loss:.4f}')
        print(f'Red Wins: {np.count_nonzero(trained_agent_scores_window_wins)}, Score: {trained_agent_score:.4f}, Average Score: {np.sum(trained_agent_scores_window):.4f}')
        print(f'Blue Wins: {np.count_nonzero(random_agent_scores_window_wins)}, Score: {random_agent_score:.4f}, Average Score: {np.sum(random_agent_scores_window):.4f}')
        print(f'Draws: {np.count_nonzero(draws)}\n')

        all_scores.append(np.sum(trained_agent_scores_window))
        
        if i_episode == 1 or i_episode == 50 or i_episode == 100 or i_episode == 1000 or i_episode == 2000 or i_episode == 4000:
            goalie.save(f'./agents/Actor_{goalie_brain_name}_episode{i_episode}.pth', f'./agents/Critic_{goalie_brain_name}_episode{i_episode}.pth')
            striker.save(f'./agents/Actor_{striker_brain_name}_episode{i_episode}.pth', f'./agents/Critic_{striker_brain_name}_episode{i_episode}.pth')
            
        if np.count_nonzero(trained_agent_scores_window_wins) >= scores_target:
            print(f'\rEnvironment solved in {i_episode-100:d} episodes!')
            print(f'Red Wins: {np.count_nonzero(trained_agent_scores_window_wins)}, Score: {trained_agent_score:.4f}, Average Score: {np.sum(trained_agent_scores_window):.4f}')
            print(f'Blue Wins: {np.count_nonzero(random_agent_scores_window_wins)}, Score: {random_agent_score:.4f}, Average Score: {np.sum(random_agent_scores_window):.4f}')
            print(f'Draws: {np.count_nonzero(draws)}\n')
            break
    
    goalie.save(f'./agents/Actor_{goalie_brain_name}.pth', f'./agents/Critic_{goalie_brain_name}.pth')
    striker.save(f'./agents/Actor_{striker_brain_name}.pth', f'./agents/Critic_{striker_brain_name}.pth')
    print('Training completed.')
     
    return all_scores

# %%
scores = train_agent(num_episodes=10000)
# Out:
# Episode: 1, Goalie Loss: 0.0001, Striker Loss: 0.0106
# Red Wins: 0, Score: 0.0000, Average Score: 0.0000
# Blue Wins: 0, Score: 0.0000, Average Score: 0.0000
# Draws: 1
#
# Episode: 2, Goalie Loss: 0.0018, Striker Loss: 0.0053
# Red Wins: 0, Score: 0.0000, Average Score: 0.0000
# Blue Wins: 0, Score: 0.0000, Average Score: 0.0000
# Draws: 2
#
# Episode: 3, Goalie Loss: 0.0162, Striker Loss: 0.0014
# Red Wins: 0, Score: -1.1000, Average Score: -1.1000
# Blue Wins: 1, Score: 1.1000, Average Score: 1.1000
# Draws: 2
#
# Episode: 4, Goalie Loss: 0.0930, Striker Loss: 0.3445
# Red Wins: 1, Score: 1.1000, Average Score: 0.0000
# Blue Wins: 1, Score: -1.1000, Average Score: 0.0000
# Draws: 2
#
# Episode: 5, Goalie Loss: 0.0071, Striker Loss: 0.0036
# Red Wins: 1, Score: 0.0000, Average Score: 0.0000
# Blue Wins: 1, Score: 0.0000, Average Score: 0.0000
# Draws: 3
#
# Episode: 6, Goalie Loss: 0.0034, Striker Loss: 0.2382
# Red Wins: 2, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 1, Score: -1.1000, Average Score: -1.1000
# Draws: 3
#
# Episode: 7, Goalie Loss: 0.0097, Striker Loss: 0.0017
# Red Wins: 3, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 1, Score: -1.1000, Average Score: -2.2000
# Draws: 3
#
# Episode: 8, Goalie Loss: 0.0029, Striker Loss: 0.0035
# Red Wins: 4, Score: 1.1000, Average Score: 3.3000
# Blue Wins: 1, Score: -1.1000, Average Score: -3.3000
# Draws: 3
#
# Episode: 9, Goalie Loss: 0.0062, Striker Loss: 0.0013
# Red Wins: 4, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 1, Score: 0.0000, Average Score: -3.3000
# Draws: 4
#
# Episode: 10, Goalie Loss: 0.0387, Striker Loss: -0.0051
# Red Wins: 5, Score: 1.1000, Average Score: 4.4000
# Blue Wins: 1, Score: -1.1000, Average Score: -4.4000
# Draws: 4
#
# Episode: 11, Goalie Loss: 0.2784, Striker Loss: -0.2306
# Red Wins: 6, Score: 1.1000, Average Score: 5.5000
# Blue Wins: 1, Score: -1.1000, Average Score: -5.5000
# Draws: 4
#
# Episode: 12, Goalie Loss: 0.2754, Striker Loss: 0.1947
# Red Wins: 6, Score: -1.1000, Average Score: 4.4000
# Blue Wins: 2, Score: 1.1000, Average Score: -4.4000
# Draws: 4
#
# Episode: 13, Goalie Loss: 0.0098, Striker Loss: 0.0072
# Red Wins: 6, Score: 0.0000, Average Score: 4.4000
# Blue Wins: 2, Score: 0.0000, Average Score: -4.4000
# Draws: 5
#
# Episode: 14, Goalie Loss: -0.0040, Striker Loss: 0.0022
# Red Wins: 6, Score: 0.0000, Average Score: 4.4000
# Blue Wins: 2, Score: 0.0000, Average Score: -4.4000
# Draws: 6
#
# Episode: 15, Goalie Loss: 0.0053, Striker Loss: 0.0003
# Red Wins: 6, Score: 0.0000, Average Score: 4.4000
# Blue Wins: 2, Score: 0.0000, Average Score: -4.4000
# Draws: 7
#
# Episode: 16, Goalie Loss: 0.0001, Striker Loss: -0.0004
# Red Wins: 6, Score: 0.0000, Average Score: 4.4000
# Blue Wins: 2, Score: 0.0000, Average Score: -4.4000
# Draws: 8
#
# Episode: 17, Goalie Loss: 0.0712, Striker Loss: 0.2409
# Red Wins: 7, Score: 1.1000, Average Score: 5.5000
# Blue Wins: 2, Score: -1.1000, Average Score: -5.5000
# Draws: 8
#
# Episode: 18, Goalie Loss: 0.0021, Striker Loss: 0.0031
# Red Wins: 7, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 2, Score: 0.0000, Average Score: -5.5000
# Draws: 9
#
# Episode: 19, Goalie Loss: -0.0017, Striker Loss: 0.0004
# Red Wins: 7, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 2, Score: 0.0000, Average Score: -5.5000
# Draws: 10
#
# Episode: 20, Goalie Loss: 0.0017, Striker Loss: 0.0048
# Red Wins: 7, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 2, Score: 0.0000, Average Score: -5.5000
# Draws: 11
#
# Episode: 21, Goalie Loss: -0.0009, Striker Loss: 0.0022
# Red Wins: 7, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 2, Score: 0.0000, Average Score: -5.5000
# Draws: 12
#
# Episode: 22, Goalie Loss: 0.0006, Striker Loss: 0.0043
# Red Wins: 7, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 2, Score: 0.0000, Average Score: -5.5000
# Draws: 13
#
# Episode: 23, Goalie Loss: 0.0188, Striker Loss: 0.0002
# Red Wins: 7, Score: -1.1000, Average Score: 4.4000
# Blue Wins: 3, Score: 1.1000, Average Score: -4.4000
# Draws: 13
#
# Episode: 24, Goalie Loss: 0.0123, Striker Loss: 0.0327
# Red Wins: 7, Score: -1.1000, Average Score: 3.3000
# Blue Wins: 4, Score: 1.1000, Average Score: -3.3000
# Draws: 13
#
# Episode: 25, Goalie Loss: 0.0153, Striker Loss: 0.0002
# Red Wins: 7, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 4, Score: 0.0000, Average Score: -3.3000
# Draws: 14
#
# Episode: 26, Goalie Loss: 0.0028, Striker Loss: 0.0005
# Red Wins: 7, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 4, Score: 0.0000, Average Score: -3.3000
# Draws: 15
#
# Episode: 27, Goalie Loss: 0.0041, Striker Loss: 0.0032
# Red Wins: 7, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 4, Score: 0.0000, Average Score: -3.3000
# Draws: 16
#
# Episode: 28, Goalie Loss: 0.0027, Striker Loss: -0.0013
# Red Wins: 7, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 4, Score: 0.0000, Average Score: -3.3000
# Draws: 17
#
# Episode: 29, Goalie Loss: -0.0753, Striker Loss: 0.2037
# Red Wins: 8, Score: 1.1000, Average Score: 4.4000
# Blue Wins: 4, Score: -1.1000, Average Score: -4.4000
# Draws: 17
#
# Episode: 30, Goalie Loss: 0.0218, Striker Loss: 0.0225
# Red Wins: 9, Score: 1.1000, Average Score: 5.5000
# Blue Wins: 4, Score: -1.1000, Average Score: -5.5000
# Draws: 17
#
# Episode: 31, Goalie Loss: -0.0027, Striker Loss: 0.0431
# Red Wins: 9, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 4, Score: 0.0000, Average Score: -5.5000
# Draws: 18
#
# Episode: 32, Goalie Loss: 0.0006, Striker Loss: 0.0038
# Red Wins: 9, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 4, Score: 0.0000, Average Score: -5.5000
# Draws: 19
#
# Episode: 33, Goalie Loss: -0.0080, Striker Loss: 0.0321
# Red Wins: 10, Score: 1.1000, Average Score: 6.6000
# Blue Wins: 4, Score: -1.1000, Average Score: -6.6000
# Draws: 19
#
# Episode: 34, Goalie Loss: -0.0039, Striker Loss: 0.0070
# Red Wins: 10, Score: 0.0000, Average Score: 6.6000
# Blue Wins: 4, Score: 0.0000, Average Score: -6.6000
# Draws: 20
#
# Episode: 35, Goalie Loss: 0.0005, Striker Loss: 0.0749
# Red Wins: 11, Score: 1.1000, Average Score: 7.7000
# Blue Wins: 4, Score: -1.1000, Average Score: -7.7000
# Draws: 20
#
# Episode: 36, Goalie Loss: 0.0265, Striker Loss: -0.0083
# Red Wins: 12, Score: 1.1000, Average Score: 8.8000
# Blue Wins: 4, Score: -1.1000, Average Score: -8.8000
# Draws: 20
#
# Episode: 37, Goalie Loss: 0.0030, Striker Loss: 0.0074
# Red Wins: 12, Score: 0.0000, Average Score: 8.8000
# Blue Wins: 4, Score: 0.0000, Average Score: -8.8000
# Draws: 21
#
# Episode: 38, Goalie Loss: -0.0182, Striker Loss: 0.1207
# Red Wins: 13, Score: 1.1000, Average Score: 9.9000
# Blue Wins: 4, Score: -1.1000, Average Score: -9.9000
# Draws: 21
#
# Episode: 39, Goalie Loss: 0.0053, Striker Loss: 0.0062
# Red Wins: 13, Score: -1.1000, Average Score: 8.8000
# Blue Wins: 5, Score: 1.1000, Average Score: -8.8000
# Draws: 21
#
# Episode: 40, Goalie Loss: 0.0078, Striker Loss: -0.0090
# Red Wins: 14, Score: 1.1000, Average Score: 9.9000
# Blue Wins: 5, Score: -1.1000, Average Score: -9.9000
# Draws: 21
#
# Episode: 41, Goalie Loss: 0.0459, Striker Loss: 0.0598
# Red Wins: 15, Score: 1.1000, Average Score: 11.0000
# Blue Wins: 5, Score: -1.1000, Average Score: -11.0000
# Draws: 21
#
# Episode: 42, Goalie Loss: -0.0059, Striker Loss: 0.0223
# Red Wins: 16, Score: 1.1000, Average Score: 12.1000
# Blue Wins: 5, Score: -1.1000, Average Score: -12.1000
# Draws: 21
#
# Episode: 43, Goalie Loss: -0.0028, Striker Loss: 0.0153
# Red Wins: 17, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 5, Score: -1.1000, Average Score: -13.2000
# Draws: 21
#
# Episode: 44, Goalie Loss: 0.3258, Striker Loss: 0.0729
# Red Wins: 17, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 6, Score: 1.1000, Average Score: -12.1000
# Draws: 21
#
# Episode: 45, Goalie Loss: 0.0076, Striker Loss: 0.0071
# Red Wins: 18, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 6, Score: -1.1000, Average Score: -13.2000
# Draws: 21
#
# Episode: 46, Goalie Loss: -0.0008, Striker Loss: -0.0026
# Red Wins: 18, Score: 0.0000, Average Score: 13.2000
# Blue Wins: 6, Score: 0.0000, Average Score: -13.2000
# Draws: 22
#
# Episode: 47, Goalie Loss: -0.0000, Striker Loss: 0.1400
# Red Wins: 19, Score: 1.1000, Average Score: 14.3000
# Blue Wins: 6, Score: -1.1000, Average Score: -14.3000
# Draws: 22
#
# Episode: 48, Goalie Loss: -0.0000, Striker Loss: 0.0013
# Red Wins: 19, Score: 0.0000, Average Score: 14.3000
# Blue Wins: 6, Score: 0.0000, Average Score: -14.3000
# Draws: 23
#
# Episode: 49, Goalie Loss: -0.0115, Striker Loss: -0.0051
# Red Wins: 19, Score: -1.1000, Average Score: 13.2000
# Blue Wins: 7, Score: 1.1000, Average Score: -13.2000
# Draws: 23
# Episode: 50, Goalie Loss: 0.0062, Striker Loss: 0.0061
# Red Wins: 19, Score: 0.0000, Average Score: 13.2000
# Blue Wins: 7, Score: 0.0000, Average Score: -13.2000
# Draws: 24
#
# Episode: 51, Goalie Loss: -0.0135, Striker Loss: 0.1611
# Red Wins: 20, Score: 1.1000, Average Score: 14.3000
# Blue Wins: 7, Score: -1.1000, Average Score: -14.3000
# Draws: 24
#
# Episode: 52, Goalie Loss: 0.0007, Striker Loss: -0.0001
# Red Wins: 20, Score: 0.0000, Average Score: 14.3000
# Blue Wins: 7, Score: 0.0000, Average Score: -14.3000
# Draws: 25
#
# Episode: 53, Goalie Loss: -0.0320, Striker Loss: 0.0160
# Red Wins: 20, Score: -1.1000, Average Score: 13.2000
# Blue Wins: 8, Score: 1.1000, Average Score: -13.2000
# Draws: 25
#
# Episode: 54, Goalie Loss: 0.0035, Striker Loss: 0.0011
# Red Wins: 20, Score: 0.0000, Average Score: 13.2000
# Blue Wins: 8, Score: 0.0000, Average Score: -13.2000
# Draws: 26
#
# Episode: 55, Goalie Loss: 0.4635, Striker Loss: -0.0911
# Red Wins: 20, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 9, Score: 1.1000, Average Score: -12.1000
# Draws: 26
#
# Episode: 56, Goalie Loss: 0.0585, Striker Loss: 0.0085
# Red Wins: 21, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 9, Score: -1.1000, Average Score: -13.2000
# Draws: 26
#
# Episode: 57, Goalie Loss: 0.0034, Striker Loss: 0.0082
# Red Wins: 21, Score: 0.0000, Average Score: 13.2000
# Blue Wins: 9, Score: 0.0000, Average Score: -13.2000
# Draws: 27
#
# Episode: 58, Goalie Loss: 0.0047, Striker Loss: 0.0006
# Red Wins: 21, Score: 0.0000, Average Score: 13.2000
# Blue Wins: 9, Score: 0.0000, Average Score: -13.2000
# Draws: 28
#
# Episode: 59, Goalie Loss: -0.0019, Striker Loss: 0.0490
# Red Wins: 22, Score: 1.1000, Average Score: 14.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -14.3000
# Draws: 28
#
# Episode: 60, Goalie Loss: 0.0042, Striker Loss: 0.0066
# Red Wins: 22, Score: 0.0000, Average Score: 14.3000
# Blue Wins: 9, Score: 0.0000, Average Score: -14.3000
# Draws: 29
#
# Episode: 61, Goalie Loss: 0.0029, Striker Loss: 0.0016
# Red Wins: 22, Score: 0.0000, Average Score: 14.3000
# Blue Wins: 9, Score: 0.0000, Average Score: -14.3000
# Draws: 30
#
# Episode: 62, Goalie Loss: 0.5033, Striker Loss: -0.0010
# Red Wins: 22, Score: -1.1000, Average Score: 13.2000
# Blue Wins: 10, Score: 1.1000, Average Score: -13.2000
# Draws: 30
#
# Episode: 63, Goalie Loss: -0.0105, Striker Loss: 0.0163
# Red Wins: 22, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 11, Score: 1.1000, Average Score: -12.1000
# Draws: 30
#
# Episode: 64, Goalie Loss: 0.0048, Striker Loss: 0.0026
# Red Wins: 22, Score: 0.0000, Average Score: 12.1000
# Blue Wins: 11, Score: 0.0000, Average Score: -12.1000
# Draws: 31
#
# Episode: 65, Goalie Loss: 0.0513, Striker Loss: 0.3343
# Red Wins: 23, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 11, Score: -1.1000, Average Score: -13.2000
# Draws: 31
#
# Episode: 66, Goalie Loss: 0.0640, Striker Loss: -0.0183
# Red Wins: 23, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 12, Score: 1.1000, Average Score: -12.1000
# Draws: 31
#
# Episode: 67, Goalie Loss: 0.0061, Striker Loss: 0.0052
# Red Wins: 23, Score: 0.0000, Average Score: 12.1000
# Blue Wins: 12, Score: 0.0000, Average Score: -12.1000
# Draws: 32
#
# Episode: 68, Goalie Loss: -0.1063, Striker Loss: -0.1603
# Red Wins: 24, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 12, Score: -1.1000, Average Score: -13.2000
# Draws: 32
#
# Episode: 69, Goalie Loss: 0.0074, Striker Loss: 0.0040
# Red Wins: 24, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 13, Score: 1.1000, Average Score: -12.1000
# Draws: 32
#
# Episode: 70, Goalie Loss: -0.0013, Striker Loss: -0.0005
# Red Wins: 24, Score: 0.0000, Average Score: 12.1000
# Blue Wins: 13, Score: 0.0000, Average Score: -12.1000
# Draws: 33
#
# Episode: 71, Goalie Loss: 0.0001, Striker Loss: 0.0017
# Red Wins: 24, Score: 0.0000, Average Score: 12.1000
# Blue Wins: 13, Score: 0.0000, Average Score: -12.1000
# Draws: 34
#
# Episode: 72, Goalie Loss: -0.0355, Striker Loss: 0.0665
# Red Wins: 25, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 13, Score: -1.1000, Average Score: -13.2000
# Draws: 34
#
# Episode: 73, Goalie Loss: -0.0070, Striker Loss: 0.0695
# Red Wins: 26, Score: 1.1000, Average Score: 14.3000
# Blue Wins: 13, Score: -1.1000, Average Score: -14.3000
# Draws: 34
#
# Episode: 74, Goalie Loss: -0.0021, Striker Loss: 0.0432
# Red Wins: 27, Score: 1.1000, Average Score: 15.4000
# Blue Wins: 13, Score: -1.1000, Average Score: -15.4000
# Draws: 34
#
# Episode: 75, Goalie Loss: 0.0042, Striker Loss: 0.0092
# Red Wins: 27, Score: 0.0000, Average Score: 15.4000
# Blue Wins: 13, Score: 0.0000, Average Score: -15.4000
# Draws: 35
#
# Episode: 76, Goalie Loss: 0.0009, Striker Loss: 0.0061
# Red Wins: 27, Score: 0.0000, Average Score: 15.4000
# Blue Wins: 13, Score: 0.0000, Average Score: -15.4000
# Draws: 36
#
# Episode: 77, Goalie Loss: 0.0037, Striker Loss: 0.0041
# Red Wins: 27, Score: 0.0000, Average Score: 15.4000
# Blue Wins: 13, Score: 0.0000, Average Score: -15.4000
# Draws: 37
#
# Episode: 78, Goalie Loss: 0.0103, Striker Loss: 0.2288
# Red Wins: 28, Score: 1.1000, Average Score: 16.5000
# Blue Wins: 13, Score: -1.1000, Average Score: -16.5000
# Draws: 37
#
# Episode: 79, Goalie Loss: 0.1675, Striker Loss: 0.0028
# Red Wins: 28, Score: -1.1000, Average Score: 15.4000
# Blue Wins: 14, Score: 1.1000, Average Score: -15.4000
# Draws: 37
#
# Episode: 80, Goalie Loss: -0.0177, Striker Loss: 0.2528
# Red Wins: 29, Score: 1.1000, Average Score: 16.5000
# Blue Wins: 14, Score: -1.1000, Average Score: -16.5000
# Draws: 37
#
# Episode: 81, Goalie Loss: -0.0377, Striker Loss: 0.0086
# Red Wins: 30, Score: 1.1000, Average Score: 17.6000
# Blue Wins: 14, Score: -1.1000, Average Score: -17.6000
# Draws: 37
#
# Episode: 82, Goalie Loss: 0.0007, Striker Loss: 0.0044
# Red Wins: 31, Score: 1.1000, Average Score: 18.7000
# Blue Wins: 14, Score: -1.1000, Average Score: -18.7000
# Draws: 37
#
# Episode: 83, Goalie Loss: 0.0168, Striker Loss: 0.0683
# Red Wins: 32, Score: 1.1000, Average Score: 19.8000
# Blue Wins: 14, Score: -1.1000, Average Score: -19.8000
# Draws: 37
#
# Episode: 84, Goalie Loss: 0.0113, Striker Loss: 0.0165
# Red Wins: 32, Score: -1.1000, Average Score: 18.7000
# Blue Wins: 15, Score: 1.1000, Average Score: -18.7000
# Draws: 37
#
# Episode: 85, Goalie Loss: -0.0195, Striker Loss: -0.0036
# Red Wins: 33, Score: 1.1000, Average Score: 19.8000
# Blue Wins: 15, Score: -1.1000, Average Score: -19.8000
# Draws: 37
#
# Episode: 86, Goalie Loss: -0.0006, Striker Loss: 0.4184
# Red Wins: 34, Score: 1.1000, Average Score: 20.9000
# Blue Wins: 15, Score: -1.1000, Average Score: -20.9000
# Draws: 37
#
# Episode: 87, Goalie Loss: -0.0021, Striker Loss: 0.0048
# Red Wins: 35, Score: 1.1000, Average Score: 22.0000
# Blue Wins: 15, Score: -1.1000, Average Score: -22.0000
# Draws: 37
#
# Episode: 88, Goalie Loss: 0.0137, Striker Loss: -0.0106
# Red Wins: 36, Score: 1.1000, Average Score: 23.1000
# Blue Wins: 15, Score: -1.1000, Average Score: -23.1000
# Draws: 37
#
# Episode: 89, Goalie Loss: -0.0162, Striker Loss: -0.0383
# Red Wins: 37, Score: 1.1000, Average Score: 24.2000
# Blue Wins: 15, Score: -1.1000, Average Score: -24.2000
# Draws: 37
#
# Episode: 90, Goalie Loss: 0.0025, Striker Loss: 0.0131
# Red Wins: 37, Score: 0.0000, Average Score: 24.2000
# Blue Wins: 15, Score: 0.0000, Average Score: -24.2000
# Draws: 38
#
# Episode: 91, Goalie Loss: 0.3477, Striker Loss: 0.0085
# Red Wins: 37, Score: -1.1000, Average Score: 23.1000
# Blue Wins: 16, Score: 1.1000, Average Score: -23.1000
# Draws: 38
#
# Episode: 92, Goalie Loss: -0.0002, Striker Loss: 0.1520
# Red Wins: 38, Score: 1.1000, Average Score: 24.2000
# Blue Wins: 16, Score: -1.1000, Average Score: -24.2000
# Draws: 38
#
# Episode: 93, Goalie Loss: -0.0000, Striker Loss: 0.0049
# Red Wins: 38, Score: 0.0000, Average Score: 24.2000
# Blue Wins: 16, Score: 0.0000, Average Score: -24.2000
# Draws: 39
#
# Episode: 94, Goalie Loss: 0.0382, Striker Loss: 0.0233
# Red Wins: 38, Score: -1.1000, Average Score: 23.1000
# Blue Wins: 17, Score: 1.1000, Average Score: -23.1000
# Draws: 39
#
# Episode: 95, Goalie Loss: 0.4426, Striker Loss: 0.0021
# Red Wins: 38, Score: -1.1000, Average Score: 22.0000
# Blue Wins: 18, Score: 1.1000, Average Score: -22.0000
# Draws: 39
#
# Episode: 96, Goalie Loss: 0.0026, Striker Loss: 0.2331
# Red Wins: 39, Score: 1.1000, Average Score: 23.1000
# Blue Wins: 18, Score: -1.1000, Average Score: -23.1000
# Draws: 39
#
# Episode: 97, Goalie Loss: -0.0320, Striker Loss: 0.4910
# Red Wins: 40, Score: 1.1000, Average Score: 24.2000
# Blue Wins: 18, Score: -1.1000, Average Score: -24.2000
# Draws: 39
# Episode: 98, Goalie Loss: 0.0048, Striker Loss: 0.0013
# Red Wins: 40, Score: 0.0000, Average Score: 24.2000
# Blue Wins: 18, Score: 0.0000, Average Score: -24.2000
# Draws: 40
#
# Episode: 99, Goalie Loss: 0.0027, Striker Loss: 0.0059
# Red Wins: 40, Score: 0.0000, Average Score: 24.2000
# Blue Wins: 18, Score: 0.0000, Average Score: -24.2000
# Draws: 41
#
# Episode: 100, Goalie Loss: 0.0666, Striker Loss: 0.0640
# Red Wins: 40, Score: -1.1000, Average Score: 23.1000
# Blue Wins: 19, Score: 1.1000, Average Score: -23.1000
# Draws: 41
#
# Episode: 101, Goalie Loss: 0.0198, Striker Loss: 0.0125
# Red Wins: 40, Score: -1.1000, Average Score: 22.0000
# Blue Wins: 20, Score: 1.1000, Average Score: -22.0000
# Draws: 40
#
# Episode: 102, Goalie Loss: 0.0096, Striker Loss: 0.0147
# Red Wins: 40, Score: -1.1000, Average Score: 20.9000
# Blue Wins: 21, Score: 1.1000, Average Score: -20.9000
# Draws: 39
#
# Episode: 103, Goalie Loss: 0.0227, Striker Loss: 0.2014
# Red Wins: 41, Score: 1.1000, Average Score: 23.1000
# Blue Wins: 20, Score: -1.1000, Average Score: -23.1000
# Draws: 39
#
# Episode: 104, Goalie Loss: 0.0070, Striker Loss: 0.0041
# Red Wins: 40, Score: 0.0000, Average Score: 22.0000
# Blue Wins: 20, Score: 0.0000, Average Score: -22.0000
# Draws: 40
#
# Episode: 105, Goalie Loss: -0.0535, Striker Loss: 0.0650
# Red Wins: 41, Score: 1.1000, Average Score: 23.1000
# Blue Wins: 20, Score: -1.1000, Average Score: -23.1000
# Draws: 39
#
# Episode: 106, Goalie Loss: 0.0044, Striker Loss: 0.0048
# Red Wins: 40, Score: 0.0000, Average Score: 22.0000
# Blue Wins: 20, Score: 0.0000, Average Score: -22.0000
# Draws: 40
#
# Episode: 107, Goalie Loss: 0.0655, Striker Loss: 0.0197
# Red Wins: 39, Score: -1.1000, Average Score: 19.8000
# Blue Wins: 21, Score: 1.1000, Average Score: -19.8000
# Draws: 40
#
# Episode: 108, Goalie Loss: 0.0090, Striker Loss: 0.0036
# Red Wins: 38, Score: 0.0000, Average Score: 18.7000
# Blue Wins: 21, Score: 0.0000, Average Score: -18.7000
# Draws: 41
#
# Episode: 109, Goalie Loss: 0.0075, Striker Loss: -0.0041
# Red Wins: 38, Score: -1.1000, Average Score: 17.6000
# Blue Wins: 22, Score: 1.1000, Average Score: -17.6000
# Draws: 40
#
# Episode: 110, Goalie Loss: 0.0197, Striker Loss: 0.2127
# Red Wins: 38, Score: 1.1000, Average Score: 17.6000
# Blue Wins: 22, Score: -1.1000, Average Score: -17.6000
# Draws: 40
#
# Episode: 111, Goalie Loss: 0.0131, Striker Loss: -0.0140
# Red Wins: 37, Score: -1.1000, Average Score: 15.4000
# Blue Wins: 23, Score: 1.1000, Average Score: -15.4000
# Draws: 40
#
# Episode: 112, Goalie Loss: -0.0002, Striker Loss: 0.0055
# Red Wins: 37, Score: -1.1000, Average Score: 15.4000
# Blue Wins: 23, Score: 1.1000, Average Score: -15.4000
# Draws: 40
#
# Episode: 113, Goalie Loss: 0.0113, Striker Loss: -0.0041
# Red Wins: 37, Score: -1.1000, Average Score: 14.3000
# Blue Wins: 24, Score: 1.1000, Average Score: -14.3000
# Draws: 39
#
# Episode: 114, Goalie Loss: 0.1068, Striker Loss: 0.0367
# Red Wins: 37, Score: -1.1000, Average Score: 13.2000
# Blue Wins: 25, Score: 1.1000, Average Score: -13.2000
# Draws: 38
#
# Episode: 115, Goalie Loss: 0.0209, Striker Loss: -0.0020
# Red Wins: 38, Score: 1.1000, Average Score: 14.3000
# Blue Wins: 25, Score: -1.1000, Average Score: -14.3000
# Draws: 37
#
# Episode: 116, Goalie Loss: 0.0085, Striker Loss: -0.0025
# Red Wins: 38, Score: -1.1000, Average Score: 13.2000
# Blue Wins: 26, Score: 1.1000, Average Score: -13.2000
# Draws: 36
#
# Episode: 117, Goalie Loss: 0.1368, Striker Loss: 0.0873
# Red Wins: 37, Score: -1.1000, Average Score: 11.0000
# Blue Wins: 27, Score: 1.1000, Average Score: -11.0000
# Draws: 36
#
# Episode: 118, Goalie Loss: 0.2125, Striker Loss: 0.0015
# Red Wins: 37, Score: -1.1000, Average Score: 9.9000
# Blue Wins: 28, Score: 1.1000, Average Score: -9.9000
# Draws: 35
#
# Episode: 119, Goalie Loss: 0.0007, Striker Loss: 0.0098
# Red Wins: 37, Score: -1.1000, Average Score: 8.8000
# Blue Wins: 29, Score: 1.1000, Average Score: -8.8000
# Draws: 34
#
# Episode: 120, Goalie Loss: -0.0015, Striker Loss: 0.1221
# Red Wins: 38, Score: 1.1000, Average Score: 9.9000
# Blue Wins: 29, Score: -1.1000, Average Score: -9.9000
# Draws: 33
#
# Episode: 121, Goalie Loss: 0.0120, Striker Loss: 0.2674
# Red Wins: 39, Score: 1.1000, Average Score: 11.0000
# Blue Wins: 29, Score: -1.1000, Average Score: -11.0000
# Draws: 32
#
# Episode: 122, Goalie Loss: 0.2398, Striker Loss: 0.0348
# Red Wins: 39, Score: -1.1000, Average Score: 9.9000
# Blue Wins: 30, Score: 1.1000, Average Score: -9.9000
# Draws: 31
#
# Episode: 123, Goalie Loss: 0.0176, Striker Loss: 0.0370
# Red Wins: 40, Score: 1.1000, Average Score: 12.1000
# Blue Wins: 29, Score: -1.1000, Average Score: -12.1000
# Draws: 31
#
# Episode: 124, Goalie Loss: 0.2331, Striker Loss: 0.0124
# Red Wins: 40, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 29, Score: 1.1000, Average Score: -12.1000
# Draws: 31
#
# Episode: 125, Goalie Loss: 0.0161, Striker Loss: 0.0109
# Red Wins: 41, Score: 1.1000, Average Score: 13.2000
# Blue Wins: 29, Score: -1.1000, Average Score: -13.2000
# Draws: 30
#
# Episode: 126, Goalie Loss: 0.0538, Striker Loss: 0.0099
# Red Wins: 41, Score: -1.1000, Average Score: 12.1000
# Blue Wins: 30, Score: 1.1000, Average Score: -12.1000
# Draws: 29
#
# Episode: 127, Goalie Loss: 0.0064, Striker Loss: 0.0092
# Red Wins: 41, Score: -1.1000, Average Score: 11.0000
# Blue Wins: 31, Score: 1.1000, Average Score: -11.0000
# Draws: 28
#
# Episode: 128, Goalie Loss: 0.0055, Striker Loss: 0.0053
# Red Wins: 41, Score: 0.0000, Average Score: 11.0000
# Blue Wins: 31, Score: 0.0000, Average Score: -11.0000
# Draws: 28
#
# Episode: 129, Goalie Loss: 0.1085, Striker Loss: 0.0008
# Red Wins: 40, Score: -1.1000, Average Score: 8.8000
# Blue Wins: 32, Score: 1.1000, Average Score: -8.8000
# Draws: 28
#
# Episode: 130, Goalie Loss: 0.0040, Striker Loss: 0.0006
# Red Wins: 39, Score: 0.0000, Average Score: 7.7000
# Blue Wins: 32, Score: 0.0000, Average Score: -7.7000
# Draws: 29
#
# Episode: 131, Goalie Loss: 0.0016, Striker Loss: 0.0026
# Red Wins: 39, Score: 0.0000, Average Score: 7.7000
# Blue Wins: 32, Score: 0.0000, Average Score: -7.7000
# Draws: 29
#
# Episode: 132, Goalie Loss: 0.0115, Striker Loss: 0.0166
# Red Wins: 39, Score: -1.1000, Average Score: 6.6000
# Blue Wins: 33, Score: 1.1000, Average Score: -6.6000
# Draws: 28
#
# Episode: 133, Goalie Loss: 0.0047, Striker Loss: -0.0001
# Red Wins: 38, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 33, Score: 0.0000, Average Score: -5.5000
# Draws: 29
#
# Episode: 134, Goalie Loss: -0.0060, Striker Loss: 0.0203
# Red Wins: 39, Score: 1.1000, Average Score: 6.6000
# Blue Wins: 33, Score: -1.1000, Average Score: -6.6000
# Draws: 28
#
# Episode: 135, Goalie Loss: 0.1470, Striker Loss: -0.0158
# Red Wins: 38, Score: -1.1000, Average Score: 4.4000
# Blue Wins: 34, Score: 1.1000, Average Score: -4.4000
# Draws: 28
#
# Episode: 136, Goalie Loss: 0.0124, Striker Loss: 0.0727
# Red Wins: 38, Score: 1.1000, Average Score: 4.4000
# Blue Wins: 34, Score: -1.1000, Average Score: -4.4000
# Draws: 28
#
# Episode: 137, Goalie Loss: 0.0053, Striker Loss: 0.0082
# Red Wins: 38, Score: -1.1000, Average Score: 3.3000
# Blue Wins: 35, Score: 1.1000, Average Score: -3.3000
# Draws: 27
#
# Episode: 138, Goalie Loss: 0.0045, Striker Loss: 0.0014
# Red Wins: 37, Score: 0.0000, Average Score: 2.2000
# Blue Wins: 35, Score: 0.0000, Average Score: -2.2000
# Draws: 28
#
# Episode: 139, Goalie Loss: 0.0412, Striker Loss: 0.0156
# Red Wins: 37, Score: -1.1000, Average Score: 2.2000
# Blue Wins: 35, Score: 1.1000, Average Score: -2.2000
# Draws: 28
#
# Episode: 140, Goalie Loss: 0.0014, Striker Loss: 0.0066
# Red Wins: 37, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 35, Score: -1.1000, Average Score: -2.2000
# Draws: 28
#
# Episode: 141, Goalie Loss: 0.0066, Striker Loss: 0.0017
# Red Wins: 36, Score: 0.0000, Average Score: 1.1000
# Blue Wins: 35, Score: 0.0000, Average Score: -1.1000
# Draws: 29
#
# Episode: 142, Goalie Loss: 0.0070, Striker Loss: -0.0005
# Red Wins: 35, Score: 0.0000, Average Score: -0.0000
# Blue Wins: 35, Score: 0.0000, Average Score: 0.0000
# Draws: 30
#
# Episode: 143, Goalie Loss: 0.0277, Striker Loss: -0.0002
# Red Wins: 34, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: 2.2000
# Draws: 30
#
# Episode: 144, Goalie Loss: 0.0073, Striker Loss: 0.0037
# Red Wins: 35, Score: 1.1000, Average Score: -0.0000
# Blue Wins: 35, Score: -1.1000, Average Score: 0.0000
# Draws: 30
#
# Episode: 145, Goalie Loss: 0.0042, Striker Loss: -0.0012
# Red Wins: 34, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: 2.2000
# Draws: 30
# Episode: 146, Goalie Loss: 0.0049, Striker Loss: -0.0031
# Red Wins: 34, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 36, Score: 0.0000, Average Score: 2.2000
# Draws: 30
#
# Episode: 147, Goalie Loss: 0.0033, Striker Loss: 0.0031
# Red Wins: 34, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 36, Score: -1.1000, Average Score: 2.2000
# Draws: 30
#
# Episode: 148, Goalie Loss: 0.0058, Striker Loss: 0.1717
# Red Wins: 35, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: -1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 149, Goalie Loss: 0.0008, Striker Loss: 0.0096
# Red Wins: 35, Score: -1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: 1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 150, Goalie Loss: 0.0293, Striker Loss: 0.0086
# Red Wins: 35, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: 1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 151, Goalie Loss: 0.0020, Striker Loss: 0.0047
# Red Wins: 34, Score: 0.0000, Average Score: -3.3000
# Blue Wins: 37, Score: 0.0000, Average Score: 3.3000
# Draws: 29
#
# Episode: 152, Goalie Loss: 0.0079, Striker Loss: 0.0066
# Red Wins: 34, Score: 0.0000, Average Score: -3.3000
# Blue Wins: 37, Score: 0.0000, Average Score: 3.3000
# Draws: 29
#
# Episode: 153, Goalie Loss: 0.0002, Striker Loss: -0.0010
# Red Wins: 34, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 36, Score: 0.0000, Average Score: 2.2000
# Draws: 30
#
# Episode: 154, Goalie Loss: 0.0103, Striker Loss: 0.0471
# Red Wins: 35, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: -1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 155, Goalie Loss: -0.0016, Striker Loss: 0.0067
# Red Wins: 35, Score: 0.0000, Average Score: -0.0000
# Blue Wins: 35, Score: 0.0000, Average Score: 0.0000
# Draws: 30
#
# Episode: 156, Goalie Loss: 0.0073, Striker Loss: 0.0053
# Red Wins: 34, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: 2.2000
# Draws: 30
#
# Episode: 157, Goalie Loss: 0.0001, Striker Loss: 0.4476
# Red Wins: 35, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: -1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 158, Goalie Loss: 0.0328, Striker Loss: 0.0062
# Red Wins: 35, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: 1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 159, Goalie Loss: 0.0953, Striker Loss: 0.0607
# Red Wins: 34, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 38, Score: 1.1000, Average Score: 4.4000
# Draws: 28
#
# Episode: 160, Goalie Loss: 0.0048, Striker Loss: 0.2227
# Red Wins: 35, Score: 1.1000, Average Score: -3.3000
# Blue Wins: 38, Score: -1.1000, Average Score: 3.3000
# Draws: 27
#
# Episode: 161, Goalie Loss: -0.0055, Striker Loss: 0.0015
# Red Wins: 35, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 39, Score: 1.1000, Average Score: 4.4000
# Draws: 26
#
# Episode: 162, Goalie Loss: 0.0167, Striker Loss: 0.4798
# Red Wins: 36, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 38, Score: -1.1000, Average Score: 2.2000
# Draws: 26
#
# Episode: 163, Goalie Loss: 0.0076, Striker Loss: 0.0012
# Red Wins: 36, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 38, Score: 1.1000, Average Score: 2.2000
# Draws: 26
#
# Episode: 164, Goalie Loss: 0.0095, Striker Loss: -0.0044
# Red Wins: 37, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 38, Score: -1.1000, Average Score: 1.1000
# Draws: 25
#
# Episode: 165, Goalie Loss: -0.0152, Striker Loss: 0.0280
# Red Wins: 36, Score: -1.1000, Average Score: -3.3000
# Blue Wins: 39, Score: 1.1000, Average Score: 3.3000
# Draws: 25
#
# Episode: 166, Goalie Loss: 0.0508, Striker Loss: -0.0085
# Red Wins: 36, Score: -1.1000, Average Score: -3.3000
# Blue Wins: 39, Score: 1.1000, Average Score: 3.3000
# Draws: 25
#
# Episode: 167, Goalie Loss: -0.0033, Striker Loss: -0.0080
# Red Wins: 37, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 39, Score: -1.1000, Average Score: 2.2000
# Draws: 24
#
# Episode: 168, Goalie Loss: 0.0025, Striker Loss: 0.4311
# Red Wins: 37, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 39, Score: -1.1000, Average Score: 2.2000
# Draws: 24
#
# Episode: 169, Goalie Loss: 0.0055, Striker Loss: -0.0009
# Red Wins: 37, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 38, Score: 0.0000, Average Score: 1.1000
# Draws: 25
#
# Episode: 170, Goalie Loss: 0.0002, Striker Loss: 0.0794
# Red Wins: 38, Score: 1.1000, Average Score: -0.0000
# Blue Wins: 38, Score: -1.1000, Average Score: 0.0000
# Draws: 24
#
# Episode: 171, Goalie Loss: 0.0058, Striker Loss: 0.0044
# Red Wins: 38, Score: 0.0000, Average Score: -0.0000
# Blue Wins: 38, Score: 0.0000, Average Score: 0.0000
# Draws: 24
#
# Episode: 172, Goalie Loss: -0.0026, Striker Loss: 0.0250
# Red Wins: 38, Score: 1.1000, Average Score: -0.0000
# Blue Wins: 38, Score: -1.1000, Average Score: 0.0000
# Draws: 24
#
# Episode: 173, Goalie Loss: 0.0075, Striker Loss: 0.0054
# Red Wins: 37, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 38, Score: 0.0000, Average Score: 1.1000
# Draws: 25
#
# Episode: 174, Goalie Loss: 0.0014, Striker Loss: 0.4125
# Red Wins: 37, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 38, Score: -1.1000, Average Score: 1.1000
# Draws: 25
#
# Episode: 175, Goalie Loss: 0.0037, Striker Loss: 0.0032
# Red Wins: 37, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 38, Score: 0.0000, Average Score: 1.1000
# Draws: 25
#
# Episode: 176, Goalie Loss: 0.0026, Striker Loss: 0.0046
# Red Wins: 37, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 38, Score: 0.0000, Average Score: 1.1000
# Draws: 25
#
# Episode: 177, Goalie Loss: 0.0028, Striker Loss: 0.0035
# Red Wins: 37, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 38, Score: 0.0000, Average Score: 1.1000
# Draws: 25
#
# Episode: 178, Goalie Loss: 0.0027, Striker Loss: 0.4575
# Red Wins: 37, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 38, Score: -1.1000, Average Score: 1.1000
# Draws: 25
#
# Episode: 179, Goalie Loss: 0.0071, Striker Loss: 0.5266
# Red Wins: 38, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 37, Score: -1.1000, Average Score: -1.1000
# Draws: 25
#
# Episode: 180, Goalie Loss: 0.0054, Striker Loss: 0.0038
# Red Wins: 37, Score: 0.0000, Average Score: -0.0000
# Blue Wins: 37, Score: 0.0000, Average Score: 0.0000
# Draws: 26
#
# Episode: 181, Goalie Loss: 0.0225, Striker Loss: 0.0085
# Red Wins: 36, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 38, Score: 1.1000, Average Score: 2.2000
# Draws: 26
#
# Episode: 182, Goalie Loss: -0.0634, Striker Loss: 0.1958
# Red Wins: 36, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 38, Score: -1.1000, Average Score: 2.2000
# Draws: 26
#
# Episode: 183, Goalie Loss: 0.4080, Striker Loss: -0.0006
# Red Wins: 35, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 39, Score: 1.1000, Average Score: 4.4000
# Draws: 26
#
# Episode: 184, Goalie Loss: 0.0071, Striker Loss: 0.0051
# Red Wins: 35, Score: 0.0000, Average Score: -3.3000
# Blue Wins: 38, Score: 0.0000, Average Score: 3.3000
# Draws: 27
#
# Episode: 185, Goalie Loss: 0.0012, Striker Loss: 0.0000
# Red Wins: 34, Score: 0.0000, Average Score: -4.4000
# Blue Wins: 38, Score: 0.0000, Average Score: 4.4000
# Draws: 28
#
# Episode: 186, Goalie Loss: -0.0203, Striker Loss: -0.0140
# Red Wins: 33, Score: -1.1000, Average Score: -6.6000
# Blue Wins: 39, Score: 1.1000, Average Score: 6.6000
# Draws: 28
#
# Episode: 187, Goalie Loss: 0.1780, Striker Loss: -0.0155
# Red Wins: 32, Score: -1.1000, Average Score: -8.8000
# Blue Wins: 40, Score: 1.1000, Average Score: 8.8000
# Draws: 28
#
# Episode: 188, Goalie Loss: 0.0120, Striker Loss: 0.0092
# Red Wins: 32, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 40, Score: -1.1000, Average Score: 8.8000
# Draws: 28
#
# Episode: 189, Goalie Loss: 0.0019, Striker Loss: 0.4433
# Red Wins: 32, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 40, Score: -1.1000, Average Score: 8.8000
# Draws: 28
#
# Episode: 190, Goalie Loss: 0.0418, Striker Loss: 0.0618
# Red Wins: 33, Score: 1.1000, Average Score: -7.7000
# Blue Wins: 40, Score: -1.1000, Average Score: 7.7000
# Draws: 27
#
# Episode: 191, Goalie Loss: -0.0008, Striker Loss: -0.0106
# Red Wins: 34, Score: 1.1000, Average Score: -5.5000
# Blue Wins: 39, Score: -1.1000, Average Score: 5.5000
# Draws: 27
#
# Episode: 192, Goalie Loss: 0.3000, Striker Loss: 0.0100
# Red Wins: 33, Score: -1.1000, Average Score: -7.7000
# Blue Wins: 40, Score: 1.1000, Average Score: 7.7000
# Draws: 27
#
# Episode: 193, Goalie Loss: 0.0239, Striker Loss: 0.0120
# Red Wins: 33, Score: -1.1000, Average Score: -8.8000
# Blue Wins: 41, Score: 1.1000, Average Score: 8.8000
# Draws: 26
# Episode: 194, Goalie Loss: 0.0057, Striker Loss: 0.0030
# Red Wins: 34, Score: 1.1000, Average Score: -6.6000
# Blue Wins: 40, Score: -1.1000, Average Score: 6.6000
# Draws: 26
#
# Episode: 195, Goalie Loss: 0.0253, Striker Loss: 0.0428
# Red Wins: 35, Score: 1.1000, Average Score: -4.4000
# Blue Wins: 39, Score: -1.1000, Average Score: 4.4000
# Draws: 26
#
# Episode: 196, Goalie Loss: 0.0577, Striker Loss: 0.0113
# Red Wins: 34, Score: -1.1000, Average Score: -6.6000
# Blue Wins: 40, Score: 1.1000, Average Score: 6.6000
# Draws: 26
#
# Episode: 197, Goalie Loss: 0.0040, Striker Loss: 0.0092
# Red Wins: 33, Score: -1.1000, Average Score: -8.8000
# Blue Wins: 41, Score: 1.1000, Average Score: 8.8000
# Draws: 26
#
# Episode: 198, Goalie Loss: 0.0920, Striker Loss: 0.0525
# Red Wins: 33, Score: -1.1000, Average Score: -9.9000
# Blue Wins: 42, Score: 1.1000, Average Score: 9.9000
# Draws: 25
#
# Episode: 199, Goalie Loss: 0.0023, Striker Loss: -0.0009
# Red Wins: 33, Score: -1.1000, Average Score: -11.0000
# Blue Wins: 43, Score: 1.1000, Average Score: 11.0000
# Draws: 24
#
# Episode: 200, Goalie Loss: 0.0056, Striker Loss: -0.0188
# Red Wins: 33, Score: -1.1000, Average Score: -11.0000
# Blue Wins: 43, Score: 1.1000, Average Score: 11.0000
# Draws: 24
#
# Episode: 201, Goalie Loss: 0.0236, Striker Loss: 0.0079
# Red Wins: 33, Score: -1.1000, Average Score: -11.0000
# Blue Wins: 43, Score: 1.1000, Average Score: 11.0000
# Draws: 24
#
# Episode: 202, Goalie Loss: 0.1040, Striker Loss: 0.1073
# Red Wins: 34, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 42, Score: -1.1000, Average Score: 8.8000
# Draws: 24
#
# Episode: 203, Goalie Loss: -0.0002, Striker Loss: 0.0052
# Red Wins: 33, Score: 0.0000, Average Score: -9.9000
# Blue Wins: 42, Score: 0.0000, Average Score: 9.9000
# Draws: 25
#
# Episode: 204, Goalie Loss: 0.0051, Striker Loss: 0.0046
# Red Wins: 33, Score: 0.0000, Average Score: -9.9000
# Blue Wins: 42, Score: 0.0000, Average Score: 9.9000
# Draws: 25
#
# Episode: 205, Goalie Loss: 0.0038, Striker Loss: 0.0008
# Red Wins: 32, Score: 0.0000, Average Score: -11.0000
# Blue Wins: 42, Score: 0.0000, Average Score: 11.0000
# Draws: 26
#
# Episode: 206, Goalie Loss: 0.0105, Striker Loss: 0.0006
# Red Wins: 32, Score: -1.1000, Average Score: -12.1000
# Blue Wins: 43, Score: 1.1000, Average Score: 12.1000
# Draws: 25
#
# Episode: 207, Goalie Loss: 0.0167, Striker Loss: 0.0445
# Red Wins: 33, Score: 1.1000, Average Score: -9.9000
# Blue Wins: 42, Score: -1.1000, Average Score: 9.9000
# Draws: 25
#
# Episode: 208, Goalie Loss: -0.0014, Striker Loss: 0.0274
# Red Wins: 34, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 42, Score: -1.1000, Average Score: 8.8000
# Draws: 24
#
# Episode: 209, Goalie Loss: 0.0487, Striker Loss: 0.0991
# Red Wins: 34, Score: -1.1000, Average Score: -8.8000
# Blue Wins: 42, Score: 1.1000, Average Score: 8.8000
# Draws: 24
#
# Episode: 210, Goalie Loss: 0.0058, Striker Loss: 0.0086
# Red Wins: 33, Score: 0.0000, Average Score: -9.9000
# Blue Wins: 42, Score: 0.0000, Average Score: 9.9000
# Draws: 25
#
# Episode: 211, Goalie Loss: -0.0220, Striker Loss: -0.0023
# Red Wins: 33, Score: -1.1000, Average Score: -9.9000
# Blue Wins: 42, Score: 1.1000, Average Score: 9.9000
# Draws: 25
#
# Episode: 212, Goalie Loss: 0.0045, Striker Loss: 0.0155
# Red Wins: 34, Score: 1.1000, Average Score: -7.7000
# Blue Wins: 41, Score: -1.1000, Average Score: 7.7000
# Draws: 25
#
# Episode: 213, Goalie Loss: 0.1317, Striker Loss: -0.0161
# Red Wins: 34, Score: -1.1000, Average Score: -7.7000
# Blue Wins: 41, Score: 1.1000, Average Score: 7.7000
# Draws: 25
#
# Episode: 214, Goalie Loss: -0.0093, Striker Loss: 0.2907
# Red Wins: 35, Score: 1.1000, Average Score: -5.5000
# Blue Wins: 40, Score: -1.1000, Average Score: 5.5000
# Draws: 25
#
# Episode: 215, Goalie Loss: -0.0154, Striker Loss: 0.0139
# Red Wins: 34, Score: -1.1000, Average Score: -7.7000
# Blue Wins: 41, Score: 1.1000, Average Score: 7.7000
# Draws: 25
#
# Episode: 216, Goalie Loss: -0.0240, Striker Loss: 0.3900
# Red Wins: 35, Score: 1.1000, Average Score: -5.5000
# Blue Wins: 40, Score: -1.1000, Average Score: 5.5000
# Draws: 25
#
# Episode: 217, Goalie Loss: 0.0447, Striker Loss: -0.0109
# Red Wins: 35, Score: -1.1000, Average Score: -5.5000
# Blue Wins: 40, Score: 1.1000, Average Score: 5.5000
# Draws: 25
#
# Episode: 218, Goalie Loss: 0.0068, Striker Loss: 0.0474
# Red Wins: 36, Score: 1.1000, Average Score: -3.3000
# Blue Wins: 39, Score: -1.1000, Average Score: 3.3000
# Draws: 25
#
# Episode: 219, Goalie Loss: 0.0074, Striker Loss: 0.0048
# Red Wins: 36, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 38, Score: 0.0000, Average Score: 2.2000
# Draws: 26
#
# Episode: 220, Goalie Loss: 0.0490, Striker Loss: -0.1832
# Red Wins: 35, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 39, Score: 1.1000, Average Score: 4.4000
# Draws: 26
#
# Episode: 221, Goalie Loss: 0.0047, Striker Loss: 0.0038
# Red Wins: 34, Score: 0.0000, Average Score: -5.5000
# Blue Wins: 39, Score: 0.0000, Average Score: 5.5000
# Draws: 27
#
# Episode: 222, Goalie Loss: 0.2776, Striker Loss: -0.0349
# Red Wins: 34, Score: -1.1000, Average Score: -5.5000
# Blue Wins: 39, Score: 1.1000, Average Score: 5.5000
# Draws: 27
#
# Episode: 223, Goalie Loss: 0.0031, Striker Loss: 0.4302
# Red Wins: 34, Score: 1.1000, Average Score: -5.5000
# Blue Wins: 39, Score: -1.1000, Average Score: 5.5000
# Draws: 27
#
# Episode: 224, Goalie Loss: 0.0056, Striker Loss: 0.0025
# Red Wins: 34, Score: 0.0000, Average Score: -4.4000
# Blue Wins: 38, Score: 0.0000, Average Score: 4.4000
# Draws: 28
#
# Episode: 225, Goalie Loss: 0.0020, Striker Loss: 0.0682
# Red Wins: 34, Score: 1.1000, Average Score: -4.4000
# Blue Wins: 38, Score: -1.1000, Average Score: 4.4000
# Draws: 28
#
# Episode: 226, Goalie Loss: 0.0125, Striker Loss: 0.0035
# Red Wins: 34, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 38, Score: 1.1000, Average Score: 4.4000
# Draws: 28
#
# Episode: 227, Goalie Loss: 0.1487, Striker Loss: -0.0087
# Red Wins: 34, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 38, Score: 1.1000, Average Score: 4.4000
# Draws: 28
#
# Episode: 228, Goalie Loss: 0.0070, Striker Loss: 0.0062
# Red Wins: 34, Score: 0.0000, Average Score: -4.4000
# Blue Wins: 38, Score: 0.0000, Average Score: 4.4000
# Draws: 28
#
# Episode: 229, Goalie Loss: 0.0002, Striker Loss: 0.3692
# Red Wins: 35, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: -1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 230, Goalie Loss: 0.0051, Striker Loss: 0.0023
# Red Wins: 35, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 37, Score: 0.0000, Average Score: 2.2000
# Draws: 28
#
# Episode: 231, Goalie Loss: 0.0051, Striker Loss: 0.0443
# Red Wins: 36, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 37, Score: -1.1000, Average Score: 1.1000
# Draws: 27
#
# Episode: 232, Goalie Loss: 0.0001, Striker Loss: 0.4389
# Red Wins: 37, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 36, Score: -1.1000, Average Score: -1.1000
# Draws: 27
#
# Episode: 233, Goalie Loss: 0.1526, Striker Loss: -0.0199
# Red Wins: 37, Score: -1.1000, Average Score: 0.0000
# Blue Wins: 37, Score: 1.1000, Average Score: -0.0000
# Draws: 26
#
# Episode: 234, Goalie Loss: -0.0061, Striker Loss: 0.0226
# Red Wins: 37, Score: 1.1000, Average Score: 0.0000
# Blue Wins: 37, Score: -1.1000, Average Score: -0.0000
# Draws: 26
#
# Episode: 235, Goalie Loss: -0.5249, Striker Loss: 0.3265
# Red Wins: 38, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 36, Score: -1.1000, Average Score: -2.2000
# Draws: 26
#
# Episode: 236, Goalie Loss: 0.0102, Striker Loss: 0.0086
# Red Wins: 38, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 36, Score: -1.1000, Average Score: -2.2000
# Draws: 26
#
# Episode: 237, Goalie Loss: 0.0105, Striker Loss: 0.0076
# Red Wins: 38, Score: -1.1000, Average Score: 2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: -2.2000
# Draws: 26
#
# Episode: 238, Goalie Loss: 0.0042, Striker Loss: 0.0015
# Red Wins: 38, Score: 0.0000, Average Score: 2.2000
# Blue Wins: 36, Score: 0.0000, Average Score: -2.2000
# Draws: 26
#
# Episode: 239, Goalie Loss: -0.0013, Striker Loss: 0.0082
# Red Wins: 38, Score: -1.1000, Average Score: 2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: -2.2000
# Draws: 26
#
# Episode: 240, Goalie Loss: 0.0038, Striker Loss: 0.0038
# Red Wins: 37, Score: 0.0000, Average Score: 1.1000
# Blue Wins: 36, Score: 0.0000, Average Score: -1.1000
# Draws: 27
#
# Episode: 241, Goalie Loss: 0.0022, Striker Loss: 0.0068
# Red Wins: 37, Score: 0.0000, Average Score: 1.1000
# Blue Wins: 36, Score: 0.0000, Average Score: -1.1000
# Draws: 27
# Episode: 242, Goalie Loss: 0.0182, Striker Loss: 0.1112
# Red Wins: 38, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 36, Score: -1.1000, Average Score: -2.2000
# Draws: 26
#
# Episode: 243, Goalie Loss: 0.0071, Striker Loss: 0.0082
# Red Wins: 38, Score: 0.0000, Average Score: 3.3000
# Blue Wins: 35, Score: 0.0000, Average Score: -3.3000
# Draws: 27
#
# Episode: 244, Goalie Loss: 0.0015, Striker Loss: 0.0047
# Red Wins: 37, Score: 0.0000, Average Score: 2.2000
# Blue Wins: 35, Score: 0.0000, Average Score: -2.2000
# Draws: 28
#
# Episode: 245, Goalie Loss: 0.0971, Striker Loss: 0.0221
# Red Wins: 37, Score: -1.1000, Average Score: 2.2000
# Blue Wins: 35, Score: 1.1000, Average Score: -2.2000
# Draws: 28
#
# Episode: 246, Goalie Loss: 0.0049, Striker Loss: 0.0055
# Red Wins: 37, Score: 0.0000, Average Score: 2.2000
# Blue Wins: 35, Score: 0.0000, Average Score: -2.2000
# Draws: 28
#
# Episode: 247, Goalie Loss: 0.0118, Striker Loss: 0.0052
# Red Wins: 36, Score: -1.1000, Average Score: 0.0000
# Blue Wins: 36, Score: 1.1000, Average Score: -0.0000
# Draws: 28
#
# Episode: 248, Goalie Loss: 0.0012, Striker Loss: 0.0048
# Red Wins: 35, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 36, Score: 0.0000, Average Score: 1.1000
# Draws: 29
#
# Episode: 249, Goalie Loss: 0.1157, Striker Loss: -0.0147
# Red Wins: 35, Score: -1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: 1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 250, Goalie Loss: 0.0021, Striker Loss: 0.0016
# Red Wins: 35, Score: 0.0000, Average Score: 0.0000
# Blue Wins: 35, Score: 0.0000, Average Score: -0.0000
# Draws: 30
#
# Episode: 251, Goalie Loss: 0.0067, Striker Loss: 0.0022
# Red Wins: 35, Score: 0.0000, Average Score: 0.0000
# Blue Wins: 35, Score: 0.0000, Average Score: -0.0000
# Draws: 30
#
# Episode: 252, Goalie Loss: 0.4870, Striker Loss: 0.0018
# Red Wins: 35, Score: -1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: 1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 253, Goalie Loss: 0.0045, Striker Loss: 0.0030
# Red Wins: 36, Score: 1.1000, Average Score: 0.0000
# Blue Wins: 36, Score: -1.1000, Average Score: -0.0000
# Draws: 28
#
# Episode: 254, Goalie Loss: 0.0296, Striker Loss: -0.0009
# Red Wins: 35, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: 1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 255, Goalie Loss: 0.0362, Striker Loss: 0.0201
# Red Wins: 35, Score: -1.1000, Average Score: -3.3000
# Blue Wins: 38, Score: 1.1000, Average Score: 3.3000
# Draws: 27
#
# Episode: 256, Goalie Loss: 0.0084, Striker Loss: 0.0040
# Red Wins: 35, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 37, Score: 0.0000, Average Score: 2.2000
# Draws: 28
#
# Episode: 257, Goalie Loss: 0.0087, Striker Loss: 0.0154
# Red Wins: 35, Score: 1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: -1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 258, Goalie Loss: 0.1893, Striker Loss: 0.0713
# Red Wins: 35, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 37, Score: 1.1000, Average Score: 2.2000
# Draws: 28
#
# Episode: 259, Goalie Loss: 0.0055, Striker Loss: 0.0066
# Red Wins: 35, Score: 0.0000, Average Score: -1.1000
# Blue Wins: 36, Score: 0.0000, Average Score: 1.1000
# Draws: 29
#
# Episode: 260, Goalie Loss: -0.0194, Striker Loss: 0.1436
# Red Wins: 35, Score: 1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: -1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 261, Goalie Loss: 0.0829, Striker Loss: 0.0103
# Red Wins: 35, Score: -1.1000, Average Score: -1.1000
# Blue Wins: 36, Score: 1.1000, Average Score: 1.1000
# Draws: 29
#
# Episode: 262, Goalie Loss: 0.0028, Striker Loss: 0.0011
# Red Wins: 34, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 36, Score: 0.0000, Average Score: 2.2000
# Draws: 30
#
# Episode: 263, Goalie Loss: 0.0522, Striker Loss: 0.0130
# Red Wins: 34, Score: -1.1000, Average Score: -2.2000
# Blue Wins: 36, Score: 1.1000, Average Score: 2.2000
# Draws: 30
#
# Episode: 264, Goalie Loss: 0.0061, Striker Loss: 0.0022
# Red Wins: 33, Score: 0.0000, Average Score: -3.3000
# Blue Wins: 36, Score: 0.0000, Average Score: 3.3000
# Draws: 31
#
# Episode: 265, Goalie Loss: 0.0653, Striker Loss: -0.0855
# Red Wins: 33, Score: -1.1000, Average Score: -3.3000
# Blue Wins: 36, Score: 1.1000, Average Score: 3.3000
# Draws: 31
#
# Episode: 266, Goalie Loss: 0.0062, Striker Loss: 0.0035
# Red Wins: 33, Score: 0.0000, Average Score: -2.2000
# Blue Wins: 35, Score: 0.0000, Average Score: 2.2000
# Draws: 32
#
# Episode: 267, Goalie Loss: 0.3458, Striker Loss: -0.0595
# Red Wins: 32, Score: -1.1000, Average Score: -4.4000
# Blue Wins: 36, Score: 1.1000, Average Score: 4.4000
# Draws: 32
#
# Episode: 268, Goalie Loss: 0.0299, Striker Loss: 0.1649
# Red Wins: 32, Score: 1.1000, Average Score: -4.4000
# Blue Wins: 36, Score: -1.1000, Average Score: 4.4000
# Draws: 32
#
# Episode: 269, Goalie Loss: 0.0783, Striker Loss: 0.1021
# Red Wins: 33, Score: 1.1000, Average Score: -3.3000
# Blue Wins: 36, Score: -1.1000, Average Score: 3.3000
# Draws: 31
#
# Episode: 270, Goalie Loss: -0.0237, Striker Loss: 0.0110
# Red Wins: 32, Score: -1.1000, Average Score: -5.5000
# Blue Wins: 37, Score: 1.1000, Average Score: 5.5000
# Draws: 31
#
# Episode: 271, Goalie Loss: 0.1378, Striker Loss: -0.0162
# Red Wins: 32, Score: -1.1000, Average Score: -6.6000
# Blue Wins: 38, Score: 1.1000, Average Score: 6.6000
# Draws: 30
#
# Episode: 272, Goalie Loss: 0.0007, Striker Loss: 0.0062
# Red Wins: 31, Score: 0.0000, Average Score: -7.7000
# Blue Wins: 38, Score: 0.0000, Average Score: 7.7000
# Draws: 31
#
# Episode: 273, Goalie Loss: 0.0050, Striker Loss: 0.0066
# Red Wins: 31, Score: -1.1000, Average Score: -8.8000
# Blue Wins: 39, Score: 1.1000, Average Score: 8.8000
# Draws: 30
#
# Episode: 274, Goalie Loss: 0.0061, Striker Loss: 0.0050
# Red Wins: 30, Score: 0.0000, Average Score: -9.9000
# Blue Wins: 39, Score: 0.0000, Average Score: 9.9000
# Draws: 31
#
# Episode: 275, Goalie Loss: -0.0094, Striker Loss: 0.2250
# Red Wins: 31, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 39, Score: -1.1000, Average Score: 8.8000
# Draws: 30
#
# Episode: 276, Goalie Loss: 0.0045, Striker Loss: 0.0018
# Red Wins: 31, Score: 0.0000, Average Score: -8.8000
# Blue Wins: 39, Score: 0.0000, Average Score: 8.8000
# Draws: 30
#
# Episode: 277, Goalie Loss: 0.0032, Striker Loss: 0.0003
# Red Wins: 31, Score: 0.0000, Average Score: -8.8000
# Blue Wins: 39, Score: 0.0000, Average Score: 8.8000
# Draws: 30
#
# Episode: 278, Goalie Loss: -0.0163, Striker Loss: 0.0131
# Red Wins: 31, Score: 1.1000, Average Score: -8.8000
# Blue Wins: 39, Score: -1.1000, Average Score: 8.8000
# Draws: 30
#
# Episode: 279, Goalie Loss: 0.0014, Striker Loss: 0.0006
# Red Wins: 30, Score: 0.0000, Average Score: -9.9000
# Blue Wins: 39, Score: 0.0000, Average Score: 9.9000
# Draws: 31
#
# ...
# Red Wins: 83, Score: 1.1000, Average Score: 81.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -81.4000
# Draws: 8
#
# Episode: 9910, Goalie Loss: -0.0111, Striker Loss: 0.0841
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9911, Goalie Loss: -0.0133, Striker Loss: 0.0658
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9912, Goalie Loss: 0.0664, Striker Loss: 0.1558
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9913, Goalie Loss: 0.0019, Striker Loss: 0.0216
# Red Wins: 83, Score: 0.0000, Average Score: 82.5000
# Blue Wins: 8, Score: 0.0000, Average Score: -82.5000
# Draws: 9
#
# Episode: 9914, Goalie Loss: -0.0073, Striker Loss: 0.0896
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9915, Goalie Loss: -0.0500, Striker Loss: 0.2604
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
# Episode: 9916, Goalie Loss: 0.0658, Striker Loss: 0.0672
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9917, Goalie Loss: -0.2316, Striker Loss: -0.0566
# Red Wins: 84, Score: -1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: 1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9918, Goalie Loss: 0.5793, Striker Loss: 0.0435
# Red Wins: 84, Score: -1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: 1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9919, Goalie Loss: 0.0554, Striker Loss: -0.0141
# Red Wins: 84, Score: 1.1000, Average Score: 83.6000
# Blue Wins: 8, Score: -1.1000, Average Score: -83.6000
# Draws: 8
#
# Episode: 9920, Goalie Loss: 0.0025, Striker Loss: 0.0306
# Red Wins: 83, Score: 0.0000, Average Score: 82.5000
# Blue Wins: 8, Score: 0.0000, Average Score: -82.5000
# Draws: 9
#
# Episode: 9921, Goalie Loss: -0.0012, Striker Loss: 0.1295
# Red Wins: 83, Score: 1.1000, Average Score: 82.5000
# Blue Wins: 8, Score: -1.1000, Average Score: -82.5000
# Draws: 9
#
# Episode: 9922, Goalie Loss: 0.0040, Striker Loss: 0.0110
# Red Wins: 83, Score: 1.1000, Average Score: 82.5000
# Blue Wins: 8, Score: -1.1000, Average Score: -82.5000
# Draws: 9
#
# Episode: 9923, Goalie Loss: 0.0037, Striker Loss: 0.0251
# Red Wins: 82, Score: 0.0000, Average Score: 81.4000
# Blue Wins: 8, Score: 0.0000, Average Score: -81.4000
# Draws: 10
#
# Episode: 9924, Goalie Loss: -0.2393, Striker Loss: 0.3145
# Red Wins: 82, Score: 1.1000, Average Score: 81.4000
# Blue Wins: 8, Score: -1.1000, Average Score: -81.4000
# Draws: 10
#
# Episode: 9925, Goalie Loss: -0.0012, Striker Loss: 0.0542
# Red Wins: 82, Score: 1.1000, Average Score: 81.4000
# Blue Wins: 8, Score: -1.1000, Average Score: -81.4000
# Draws: 10
#
# Episode: 9926, Goalie Loss: 0.0067, Striker Loss: 0.0259
# Red Wins: 81, Score: 0.0000, Average Score: 80.3000
# Blue Wins: 8, Score: 0.0000, Average Score: -80.3000
# Draws: 11
#
# Episode: 9927, Goalie Loss: 0.0013, Striker Loss: 0.0243
# Red Wins: 80, Score: 0.0000, Average Score: 79.2000
# Blue Wins: 8, Score: 0.0000, Average Score: -79.2000
# Draws: 12
#
# Episode: 9928, Goalie Loss: 0.1130, Striker Loss: 0.0350
# Red Wins: 80, Score: 1.1000, Average Score: 79.2000
# Blue Wins: 8, Score: -1.1000, Average Score: -79.2000
# Draws: 12
#
# Episode: 9929, Goalie Loss: -0.0028, Striker Loss: 0.1513
# Red Wins: 80, Score: 1.1000, Average Score: 79.2000
# Blue Wins: 8, Score: -1.1000, Average Score: -79.2000
# Draws: 12
#
# Episode: 9930, Goalie Loss: -0.1689, Striker Loss: 0.1569
# Red Wins: 80, Score: 1.1000, Average Score: 79.2000
# Blue Wins: 8, Score: -1.1000, Average Score: -79.2000
# Draws: 12
#
# Episode: 9931, Goalie Loss: 0.0038, Striker Loss: 0.0190
# Red Wins: 79, Score: 0.0000, Average Score: 78.1000
# Blue Wins: 8, Score: 0.0000, Average Score: -78.1000
# Draws: 13
#
# Episode: 9932, Goalie Loss: -0.0270, Striker Loss: 0.0173
# Red Wins: 79, Score: 1.1000, Average Score: 78.1000
# Blue Wins: 8, Score: -1.1000, Average Score: -78.1000
# Draws: 13
#
# Episode: 9933, Goalie Loss: 0.0011, Striker Loss: 0.0171
# Red Wins: 79, Score: 1.1000, Average Score: 78.1000
# Blue Wins: 8, Score: -1.1000, Average Score: -78.1000
# Draws: 13
#
# Episode: 9934, Goalie Loss: 0.0066, Striker Loss: 0.0392
# Red Wins: 79, Score: 1.1000, Average Score: 78.1000
# Blue Wins: 8, Score: -1.1000, Average Score: -78.1000
# Draws: 13
#
# Episode: 9935, Goalie Loss: 0.0072, Striker Loss: 0.0096
# Red Wins: 78, Score: 0.0000, Average Score: 77.0000
# Blue Wins: 8, Score: 0.0000, Average Score: -77.0000
# Draws: 14
#
# Episode: 9936, Goalie Loss: 0.0381, Striker Loss: 0.0241
# Red Wins: 77, Score: -1.1000, Average Score: 74.8000
# Blue Wins: 9, Score: 1.1000, Average Score: -74.8000
# Draws: 14
#
# Episode: 9937, Goalie Loss: 0.0046, Striker Loss: 0.0149
# Red Wins: 76, Score: 0.0000, Average Score: 73.7000
# Blue Wins: 9, Score: 0.0000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9938, Goalie Loss: 0.0036, Striker Loss: 0.0049
# Red Wins: 76, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 9, Score: -1.1000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9939, Goalie Loss: 0.0046, Striker Loss: 0.0039
# Red Wins: 75, Score: 0.0000, Average Score: 72.6000
# Blue Wins: 9, Score: 0.0000, Average Score: -72.6000
# Draws: 16
#
# Episode: 9940, Goalie Loss: 0.0016, Striker Loss: 0.1290
# Red Wins: 75, Score: 1.1000, Average Score: 72.6000
# Blue Wins: 9, Score: -1.1000, Average Score: -72.6000
# Draws: 16
#
# Episode: 9941, Goalie Loss: -0.0032, Striker Loss: 0.0576
# Red Wins: 76, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 9, Score: -1.1000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9942, Goalie Loss: 0.0018, Striker Loss: 0.2908
# Red Wins: 76, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 9, Score: -1.1000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9943, Goalie Loss: -0.0589, Striker Loss: 0.1989
# Red Wins: 76, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 9, Score: -1.1000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9944, Goalie Loss: 0.0032, Striker Loss: 0.2622
# Red Wins: 76, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 9, Score: -1.1000, Average Score: -73.7000
# Draws: 15
#
# Episode: 9945, Goalie Loss: 0.0019, Striker Loss: 0.0154
# Red Wins: 76, Score: 0.0000, Average Score: 74.8000
# Blue Wins: 8, Score: 0.0000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9946, Goalie Loss: 0.0072, Striker Loss: 0.0544
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9947, Goalie Loss: 0.0065, Striker Loss: 0.2468
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9948, Goalie Loss: -0.2512, Striker Loss: 0.1752
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9949, Goalie Loss: 0.0171, Striker Loss: 0.1726
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9950, Goalie Loss: 0.0029, Striker Loss: 0.0106
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9951, Goalie Loss: -0.0023, Striker Loss: 0.0223
# Red Wins: 75, Score: 0.0000, Average Score: 73.7000
# Blue Wins: 8, Score: 0.0000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9952, Goalie Loss: 0.0175, Striker Loss: 0.0059
# Red Wins: 75, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 8, Score: -1.1000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9953, Goalie Loss: 0.0322, Striker Loss: 0.0404
# Red Wins: 75, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 8, Score: -1.1000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9954, Goalie Loss: 0.0066, Striker Loss: 0.1736
# Red Wins: 75, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 8, Score: -1.1000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9955, Goalie Loss: 0.3285, Striker Loss: -0.0838
# Red Wins: 76, Score: 1.1000, Average Score: 75.9000
# Blue Wins: 7, Score: -1.1000, Average Score: -75.9000
# Draws: 17
#
# Episode: 9956, Goalie Loss: 0.0044, Striker Loss: 0.0112
# Red Wins: 75, Score: 0.0000, Average Score: 74.8000
# Blue Wins: 7, Score: 0.0000, Average Score: -74.8000
# Draws: 18
#
# Episode: 9957, Goalie Loss: 0.3804, Striker Loss: 0.0481
# Red Wins: 74, Score: -1.1000, Average Score: 72.6000
# Blue Wins: 8, Score: 1.1000, Average Score: -72.6000
# Draws: 18
#
# Episode: 9958, Goalie Loss: 0.0476, Striker Loss: 0.0308
# Red Wins: 75, Score: 1.1000, Average Score: 73.7000
# Blue Wins: 8, Score: -1.1000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9959, Goalie Loss: 0.1487, Striker Loss: 0.0061
# Red Wins: 74, Score: -1.1000, Average Score: 71.5000
# Blue Wins: 9, Score: 1.1000, Average Score: -71.5000
# Draws: 17
#
# Episode: 9960, Goalie Loss: 0.0548, Striker Loss: 0.1904
# Red Wins: 75, Score: 1.1000, Average Score: 72.6000
# Blue Wins: 9, Score: -1.1000, Average Score: -72.6000
# Draws: 16
#
# Episode: 9961, Goalie Loss: 0.0504, Striker Loss: 0.3055
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9962, Goalie Loss: 0.0409, Striker Loss: 0.0488
# Red Wins: 75, Score: -1.1000, Average Score: 72.6000
# Blue Wins: 9, Score: 1.1000, Average Score: -72.6000
# Draws: 16
#
# Episode: 9963, Goalie Loss: 0.0199, Striker Loss: 0.0097
# Red Wins: 75, Score: 1.1000, Average Score: 72.6000
# Blue Wins: 9, Score: -1.1000, Average Score: -72.6000
# Draws: 16
# Episode: 9964, Goalie Loss: 0.0003, Striker Loss: 0.2656
# Red Wins: 76, Score: 1.1000, Average Score: 74.8000
# Blue Wins: 8, Score: -1.1000, Average Score: -74.8000
# Draws: 16
#
# Episode: 9965, Goalie Loss: 0.0034, Striker Loss: 0.0123
# Red Wins: 75, Score: 0.0000, Average Score: 73.7000
# Blue Wins: 8, Score: 0.0000, Average Score: -73.7000
# Draws: 17
#
# Episode: 9966, Goalie Loss: 0.0537, Striker Loss: 0.0169
# Red Wins: 74, Score: -1.1000, Average Score: 71.5000
# Blue Wins: 9, Score: 1.1000, Average Score: -71.5000
# Draws: 17
#
# Episode: 9967, Goalie Loss: 0.0094, Striker Loss: 0.1008
# Red Wins: 74, Score: 1.1000, Average Score: 71.5000
# Blue Wins: 9, Score: -1.1000, Average Score: -71.5000
# Draws: 17
#
# Episode: 9968, Goalie Loss: 0.0047, Striker Loss: 0.0068
# Red Wins: 73, Score: 0.0000, Average Score: 70.4000
# Blue Wins: 9, Score: 0.0000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9969, Goalie Loss: 0.0119, Striker Loss: 0.1125
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9970, Goalie Loss: 0.0067, Striker Loss: 0.0052
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9971, Goalie Loss: -0.0584, Striker Loss: 0.0379
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9972, Goalie Loss: 0.0072, Striker Loss: 0.0025
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9973, Goalie Loss: -0.0042, Striker Loss: 0.0168
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9974, Goalie Loss: -0.0116, Striker Loss: -0.0026
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9975, Goalie Loss: 0.0577, Striker Loss: 0.1804
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9976, Goalie Loss: 0.0025, Striker Loss: 0.0173
# Red Wins: 72, Score: 0.0000, Average Score: 69.3000
# Blue Wins: 9, Score: 0.0000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9977, Goalie Loss: 0.0029, Striker Loss: 0.0139
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9978, Goalie Loss: -0.0013, Striker Loss: 0.0144
# Red Wins: 71, Score: 0.0000, Average Score: 68.2000
# Blue Wins: 9, Score: 0.0000, Average Score: -68.2000
# Draws: 20
#
# Episode: 9979, Goalie Loss: 0.1468, Striker Loss: -0.0801
# Red Wins: 71, Score: 1.1000, Average Score: 68.2000
# Blue Wins: 9, Score: -1.1000, Average Score: -68.2000
# Draws: 20
#
# Episode: 9980, Goalie Loss: 0.0051, Striker Loss: 0.0095
# Red Wins: 70, Score: 0.0000, Average Score: 67.1000
# Blue Wins: 9, Score: 0.0000, Average Score: -67.1000
# Draws: 21
#
# Episode: 9981, Goalie Loss: 0.0223, Striker Loss: 0.0094
# Red Wins: 69, Score: -1.1000, Average Score: 64.9000
# Blue Wins: 10, Score: 1.1000, Average Score: -64.9000
# Draws: 21
#
# Episode: 9982, Goalie Loss: -0.0047, Striker Loss: 0.1249
# Red Wins: 70, Score: 1.1000, Average Score: 66.0000
# Blue Wins: 10, Score: -1.1000, Average Score: -66.0000
# Draws: 20
#
# Episode: 9983, Goalie Loss: 0.0129, Striker Loss: 0.2473
# Red Wins: 70, Score: 1.1000, Average Score: 66.0000
# Blue Wins: 10, Score: -1.1000, Average Score: -66.0000
# Draws: 20
#
# Episode: 9984, Goalie Loss: -0.0052, Striker Loss: 0.2341
# Red Wins: 70, Score: 1.1000, Average Score: 66.0000
# Blue Wins: 10, Score: -1.1000, Average Score: -66.0000
# Draws: 20
#
# Episode: 9985, Goalie Loss: -0.0333, Striker Loss: 0.0031
# Red Wins: 70, Score: 1.1000, Average Score: 66.0000
# Blue Wins: 10, Score: -1.1000, Average Score: -66.0000
# Draws: 20
#
# Episode: 9986, Goalie Loss: 0.0005, Striker Loss: 0.3074
# Red Wins: 71, Score: 1.1000, Average Score: 68.2000
# Blue Wins: 9, Score: -1.1000, Average Score: -68.2000
# Draws: 20
#
# Episode: 9987, Goalie Loss: -0.0042, Striker Loss: 0.2227
# Red Wins: 71, Score: 1.1000, Average Score: 68.2000
# Blue Wins: 9, Score: -1.1000, Average Score: -68.2000
# Draws: 20
#
# Episode: 9988, Goalie Loss: 0.0004, Striker Loss: 0.3028
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9989, Goalie Loss: -0.0006, Striker Loss: 0.0774
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9990, Goalie Loss: 0.0131, Striker Loss: 0.1876
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9991, Goalie Loss: 0.0080, Striker Loss: 0.1765
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9992, Goalie Loss: -0.2124, Striker Loss: 0.1995
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9993, Goalie Loss: 0.0031, Striker Loss: 0.0630
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9994, Goalie Loss: -0.0156, Striker Loss: 0.0322
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9995, Goalie Loss: -0.0112, Striker Loss: -0.0868
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9996, Goalie Loss: 0.4903, Striker Loss: 0.2895
# Red Wins: 72, Score: 1.1000, Average Score: 69.3000
# Blue Wins: 9, Score: -1.1000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9997, Goalie Loss: 0.0007, Striker Loss: 0.2511
# Red Wins: 73, Score: 1.1000, Average Score: 70.4000
# Blue Wins: 9, Score: -1.1000, Average Score: -70.4000
# Draws: 18
#
# Episode: 9998, Goalie Loss: 0.0037, Striker Loss: 0.0197
# Red Wins: 72, Score: 0.0000, Average Score: 69.3000
# Blue Wins: 9, Score: 0.0000, Average Score: -69.3000
# Draws: 19
#
# Episode: 9999, Goalie Loss: 0.4421, Striker Loss: 0.0548
# Red Wins: 71, Score: -1.1000, Average Score: 67.1000
# Blue Wins: 10, Score: 1.1000, Average Score: -67.1000
# Draws: 19
#
# Episode: 10000, Goalie Loss: 0.0139, Striker Loss: 0.0245
# Red Wins: 71, Score: -1.1000, Average Score: 66.0000
# Blue Wins: 11, Score: 1.1000, Average Score: -66.0000
# Draws: 18
#
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_ppo_evaluation.png')
plt.show()

# %% [markdown]
# ## 🎬 Watch The Smart Agent

# %%
def watch_agent(goalie, striker, num_episodes=10):
        
    trained_agent_scores_window = deque(maxlen=DEQUE_SIZE)
    trained_agent_scores_window_wins = deque(maxlen=DEQUE_SIZE)

    random_agent_scores_window = deque(maxlen=DEQUE_SIZE)
    random_agent_scores_window_wins = deque(maxlen=DEQUE_SIZE)

    draws = deque(maxlen=DEQUE_SIZE)

    # training loop
    for i_episode in range(1, num_episodes+1):

        env_info = env.reset(train_mode=True)

        goalie_states = env_info[goalie_brain_name].vector_observations
        striker_states = env_info[striker_brain_name].vector_observations

        goalie_scores = np.zeros(len(env_info[goalie_brain_name].agents))
        striker_scores = np.zeros(len(env_info[striker_brain_name].agents))

        while True:

            trained_goalie_action, trained_goalie_log_prob = goalie.act(goalie_states[TRAINED_AGENT_KEY])
            trained_striker_action, trained_striker_log_prob = striker.act(striker_states[TRAINED_AGENT_KEY])

            random_goalie_action = np.asarray([np.random.choice(goalie_action_size)])
            random_striker_action = np.asarray([np.random.choice(striker_action_size)])

            goalie_actions = np.array((trained_goalie_action, random_goalie_action))
            striker_actions = np.array((trained_striker_action, random_striker_action))

            actions = dict(zip([goalie_brain_name, striker_brain_name], [goalie_actions, striker_actions]))

            env_info = env.step(actions)

            # agents get next states
            goalie_next_states = env_info[goalie_brain_name].vector_observations
            striker_next_states = env_info[striker_brain_name].vector_observations

            # agents get rewards
            goalie_rewards = env_info[goalie_brain_name].rewards
            striker_rewards = env_info[striker_brain_name].rewards

            # agents update scores
            goalie_scores += goalie_rewards
            striker_scores += striker_rewards

            # agents roll over states to next states
            goalie_states = goalie_next_states
            striker_states = striker_next_states

            # check if episode finished
            done = np.any(env_info[goalie_brain_name].local_done)
            if done: break

        # agents record scores
        trained_agent_score = goalie_scores[TRAINED_AGENT_KEY] + striker_scores[TRAINED_AGENT_KEY]
        trained_agent_scores_window.append(trained_agent_score)
        trained_agent_scores_window_wins.append(1 if trained_agent_score > 0 else 0)

        random_agent_score = goalie_scores[RANDOM_AGENT_KEY] + striker_scores[RANDOM_AGENT_KEY]
        random_agent_scores_window.append(random_agent_score)
        random_agent_scores_window_wins.append(1 if random_agent_score > 0 else 0)

        draws.append(trained_agent_score == random_agent_score)

        print(f'\rEpisode: {i_episode}')
        print(f'Red Wins: {np.count_nonzero(trained_agent_scores_window_wins)}, Score: {trained_agent_score:.4f}, Average Score: {np.sum(trained_agent_scores_window):.4f}')
        print(f'Blue Wins: {np.count_nonzero(random_agent_scores_window_wins)}, Score: {random_agent_score:.4f}, Average Score: {np.sum(random_agent_scores_window):.4f}')
        print(f'Draws: {np.count_nonzero(draws)}\n')
        
    if np.count_nonzero(trained_agent_scores_window_wins) > np.count_nonzero(random_agent_scores_window_wins):
        print('Red Player Wins!')
    else:
        print('Red Player Loses!')

# %%
goalie.load(f'./agents/Actor_{goalie_brain_name}.pth', f'./agents/Critic_{goalie_brain_name}.pth');
striker.load(f'./agents/Actor_{striker_brain_name}.pth', f'./agents/Critic_{striker_brain_name}.pth');

# %%
watch_agent(goalie, striker, num_episodes=20)
# Out:
# Episode: 1
# Red Wins: 1, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 0, Score: -1.1000, Average Score: -1.1000
# Draws: 0
#
# Episode: 2
# Red Wins: 1, Score: -1.1000, Average Score: 0.0000
# Blue Wins: 1, Score: 1.1000, Average Score: -0.0000
# Draws: 0
#
# Episode: 3
# Red Wins: 2, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 1, Score: -1.1000, Average Score: -1.1000
# Draws: 0
#
# Episode: 4
# Red Wins: 2, Score: -1.1000, Average Score: 0.0000
# Blue Wins: 2, Score: 1.1000, Average Score: -0.0000
# Draws: 0
#
# Episode: 5
# Red Wins: 3, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 2, Score: -1.1000, Average Score: -1.1000
# Draws: 0
#
# Episode: 6
# Red Wins: 3, Score: -1.1000, Average Score: 0.0000
# Blue Wins: 3, Score: 1.1000, Average Score: -0.0000
# Draws: 0
#
# Episode: 7
# Red Wins: 4, Score: 1.1000, Average Score: 1.1000
# Blue Wins: 3, Score: -1.1000, Average Score: -1.1000
# Draws: 0
#
# Episode: 8
# Red Wins: 5, Score: 1.1000, Average Score: 2.2000
# Blue Wins: 3, Score: -1.1000, Average Score: -2.2000
# Draws: 0
#
# Episode: 9
# Red Wins: 6, Score: 1.1000, Average Score: 3.3000
# Blue Wins: 3, Score: -1.1000, Average Score: -3.3000
# Draws: 0
#
# Episode: 10
# Red Wins: 7, Score: 1.1000, Average Score: 4.4000
# Blue Wins: 3, Score: -1.1000, Average Score: -4.4000
# Draws: 0
#
# Episode: 11
# Red Wins: 8, Score: 1.1000, Average Score: 5.5000
# Blue Wins: 3, Score: -1.1000, Average Score: -5.5000
# Draws: 0
#
# Episode: 12
# Red Wins: 8, Score: -1.1000, Average Score: 4.4000
# Blue Wins: 4, Score: 1.1000, Average Score: -4.4000
# Draws: 0
#
# Episode: 13
# Red Wins: 9, Score: 1.1000, Average Score: 5.5000
# Blue Wins: 4, Score: -1.1000, Average Score: -5.5000
# Draws: 0
#
# Episode: 14
# Red Wins: 9, Score: 0.0000, Average Score: 5.5000
# Blue Wins: 4, Score: 0.0000, Average Score: -5.5000
# Draws: 1
#
# Episode: 15
# Red Wins: 10, Score: 1.1000, Average Score: 6.6000
# Blue Wins: 4, Score: -1.1000, Average Score: -6.6000
# Draws: 1
#
# Episode: 16
# Red Wins: 11, Score: 1.1000, Average Score: 7.7000
# Blue Wins: 4, Score: -1.1000, Average Score: -7.7000
# Draws: 1
#
# Episode: 17
# Red Wins: 11, Score: 0.0000, Average Score: 7.7000
# Blue Wins: 4, Score: 0.0000, Average Score: -7.7000
# Draws: 2
#
# Episode: 18
# Red Wins: 12, Score: 1.1000, Average Score: 8.8000
# Blue Wins: 4, Score: -1.1000, Average Score: -8.8000
# Draws: 2
#
# Episode: 19
# Red Wins: 13, Score: 1.1000, Average Score: 9.9000
# Blue Wins: 4, Score: -1.1000, Average Score: -9.9000
# Draws: 2
#
# Episode: 20
# Red Wins: 14, Score: 1.1000, Average Score: 11.0000
# Blue Wins: 4, Score: -1.1000, Average Score: -11.0000
# Draws: 2
#
# Red Player Wins!

# %% [markdown]
# ---
