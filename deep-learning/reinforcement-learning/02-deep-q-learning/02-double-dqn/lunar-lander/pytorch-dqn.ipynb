# %% [markdown]
# # Double DQN, Deep Q Learning

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from collections import namedtuple, deque

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3 # for soft update of target parameters
LR = 5e-4
PRINT_EVERY = 100
UPDATE_EVERY = 4

# %% [markdown]
# ## Set Environment

# %%
ENV_NAME = 'LunarLander-v2'
env = gym.make(ENV_NAME).unwrapped; env.seed(90);

# %%
print('Environment Display:')
env.reset() # reset environment to a new, random state
env.render()

print('State space {}'.format(env.observation_space))
print('Action space {}'.format(env.action_space))
# Out:
# Environment Display:
# State space Box(8,)
# Action space Discrete(4)

# %% [markdown]
# ## Build DQN Architecture

# %%
class DQN(nn.Module):
    """Define DQN architecture."""
    
    def __init__(self, state_size, action_size, seed, fcl_units=64, fc2_units=64):
        """Initialize parameters and build model."""
        
        super(DQN, self).__init__()
        
        self.seed = torch.manual_seed(seed)
        
        self.fc1_layer = nn.Linear(state_size, fcl_units)
        self.fc2_layer = nn.Linear(fcl_units, fc2_units)
        self.fc3_layer = nn.Linear(fc2_units, action_size)
        
    def forward(self, state):
        """Build a network that maps state into action values."""
        
        state = F.relu(self.fc1_layer(state))
        state = F.relu(self.fc2_layer(state))
        Qsa = self.fc3_layer(state)
        
        return Qsa

# %% [markdown]
# ## Set Replay Buffer

# %%
class ReplayBuffer(object):
    """Fixed-size buffer to store experience tuples."""
    
    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayMemory object."""
        
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to buffer."""
        
        self.memory.append(self.experience(state, action, reward, next_state, done))
        
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)
        
        states = torch.from_numpy(np.vstack([exp.state for exp in experiences if exp is not None])).float()
        states = states.to(device)
        
        actions = torch.from_numpy(np.vstack([exp.action for exp in experiences if exp is not None])).long()
        actions = actions.to(device)
        
        rewards = torch.from_numpy(np.vstack([exp.reward for exp in experiences if exp is not None])).float()
        rewards = rewards.to(device)
        
        next_states = torch.from_numpy(np.vstack([exp.next_state for exp in experiences if exp is not None])).float()
        next_states = next_states.to(device)
        
        dones = torch.from_numpy(np.vstack([exp.done for exp in experiences if exp is not None]).astype(np.uint8)).float()
        dones = dones.to(device)
        
        return (states, actions, rewards, next_states, dones)
        
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Define Double DQN Agent

# %%
class Double_DQNAgent():
    """The agent interacting with and learning from the environment."""
    
    def __init__(self, state_size, action_size, seed):
        """Initialize an agent object."""
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        
        # Q-Network
        self.dqn_net = DQN(state_size, action_size, seed).to(device)
        self.target_net = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.dqn_net.parameters(), lr=LR)
        
        # Replay Buffer
        self.buffer = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        self.time_step = 0
        
    def memorize(self, state, action, reward, next_state, done):
        """Save experience in replay buffer."""
        
        self.buffer.add(state, action, reward, next_state, done)
    
        self.time_step = (self.time_step + 1) % UPDATE_EVERY
        if self.time_step == 0:
            # if enough samples are available in memory, get random subset and learn
            if len(self.buffer) > BATCH_SIZE:
                experiences = self.buffer.sample()
                self.learn(experiences, GAMMA)
            
    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.dqn_net.eval()
        with torch.no_grad():
            action_values = self.dqn_net(state)
        self.dqn_net.train()
        
        # epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
    
    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples."""
    
        states, actions, rewards, next_states, dones = experiences
        
        self.optimizer.zero_grad()
        
        # get index of maximum value for next state
        Qsa_next = self.dqn_net(next_states).detach()
        _, action_max = Qsa_next.max(1)

        # get max predicted Q values (for next states) from target network
        Q_target_next = self.target_net(next_states).detach().gather(1, action_max.unsqueeze(1))
        
        # compute Q target
        Q_target = rewards + (gamma * Q_target_next * (1 - dones))
        
        # get expected Q values from dqn network
        Q_expected = self.dqn_net(states).gather(1, actions)
        
        # compute loss
        loss = F.mse_loss(Q_expected, Q_target)
        
        # minimize the loss
        loss.backward()
        self.optimizer.step()
        
        # update target network
        self.soft_update(self.dqn_net, self.target_net, TAU)
        
    def soft_update(self, dqn_net, target_net, tau):
        """Soft update target network parameters."""
        
        for dqn_param, target_param in zip(dqn_net.parameters(), target_net.parameters()):
            target_param.data.copy_(tau*dqn_param.data + (1.0-tau) * target_param.data)

# %%
agent = Double_DQNAgent(state_size=env.observation_space.shape[0], action_size=env.action_space.n, seed=90)

# %%
# watch an untrained agent
state = env.reset()
for time_step in range(200):
    
    # select an action
    action = agent.act(state)
    env.render()
    
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes, max_time=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Train DQN agent."""
    
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    
    for i_episode in range(1, num_episodes+1):
        state = env.reset()
        score = 0
        for time_step in range(max_time):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
                
        scores_window.append(score)
        scores.append(score)
        eps = max(eps_end, eps_decay*eps)
        
        print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}', end='')
        
        if i_episode % PRINT_EVERY == 0:
            print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}')
        if np.mean(scores_window) >= 200.0:
            print(f'\nEnvironment solved in {i_episode-100:d} episodes! Average Score: {np.mean(scores_window):.2f}')
            if not os.path.exists('./agents/'): os.makedirs('./agents/')
            torch.save(agent.dqn_net.state_dict(), f'./agents/Double_DQN_{ENV_NAME}.pth')
            
    print('Training completed.')
    return scores

# %%
scores = train_agent(num_episodes=2000, max_time=1000)
# Out:
# Episode: 100, Average Score: -162.50
# Episode: 200, Average Score: -133.88
# Episode: 300, Average Score: -69.032
# Episode: 400, Average Score: 3.9214
# Episode: 500, Average Score: 92.22
# Episode: 600, Average Score: 158.25
# Episode: 700, Average Score: 189.76
# Episode: 732, Average Score: 200.64
# Environment solved in 632 episodes! Average Score: 200.64
# Episode: 733, Average Score: 200.56
# Environment solved in 633 episodes! Average Score: 200.56
# Episode: 734, Average Score: 200.65
# Environment solved in 634 episodes! Average Score: 200.65
# Episode: 735, Average Score: 201.55
# Environment solved in 635 episodes! Average Score: 201.55
# Episode: 736, Average Score: 203.83
# Environment solved in 636 episodes! Average Score: 203.83
# Episode: 737, Average Score: 204.73
# Environment solved in 637 episodes! Average Score: 204.73
# Episode: 738, Average Score: 204.98
# Environment solved in 638 episodes! Average Score: 204.98
# Episode: 739, Average Score: 205.08
# Environment solved in 639 episodes! Average Score: 205.08
# Episode: 740, Average Score: 204.65
# Environment solved in 640 episodes! Average Score: 204.65
# Episode: 741, Average Score: 204.71
# Environment solved in 641 episodes! Average Score: 204.71
# Episode: 742, Average Score: 208.34
# Environment solved in 642 episodes! Average Score: 208.34
# Episode: 743, Average Score: 208.73
# Environment solved in 643 episodes! Average Score: 208.73
# Episode: 744, Average Score: 209.48
# Environment solved in 644 episodes! Average Score: 209.48
# Episode: 745, Average Score: 209.31
# Environment solved in 645 episodes! Average Score: 209.31
# Episode: 746, Average Score: 211.58
# Environment solved in 646 episodes! Average Score: 211.58
# Episode: 747, Average Score: 211.99
# Environment solved in 647 episodes! Average Score: 211.99
# Episode: 748, Average Score: 213.27
# Environment solved in 648 episodes! Average Score: 213.27
# Episode: 749, Average Score: 214.19
# Environment solved in 649 episodes! Average Score: 214.19
# Episode: 750, Average Score: 214.95
# Environment solved in 650 episodes! Average Score: 214.95
# Episode: 751, Average Score: 217.25
# Environment solved in 651 episodes! Average Score: 217.25
# Episode: 752, Average Score: 217.67
# Environment solved in 652 episodes! Average Score: 217.67
# Episode: 753, Average Score: 217.87
# Environment solved in 653 episodes! Average Score: 217.87
# Episode: 754, Average Score: 218.29
# Environment solved in 654 episodes! Average Score: 218.29
# Episode: 755, Average Score: 218.62
# Environment solved in 655 episodes! Average Score: 218.62
# Episode: 756, Average Score: 218.78
# Environment solved in 656 episodes! Average Score: 218.78
# Episode: 757, Average Score: 218.35
# Environment solved in 657 episodes! Average Score: 218.35
# Episode: 758, Average Score: 218.16
# Environment solved in 658 episodes! Average Score: 218.16
# Episode: 759, Average Score: 218.41
# Environment solved in 659 episodes! Average Score: 218.41
# Episode: 760, Average Score: 218.65
# Environment solved in 660 episodes! Average Score: 218.65
# Episode: 761, Average Score: 219.63
# Environment solved in 661 episodes! Average Score: 219.63
# Episode: 762, Average Score: 219.92
# Environment solved in 662 episodes! Average Score: 219.92
# Episode: 763, Average Score: 220.12
# Environment solved in 663 episodes! Average Score: 220.12
# Episode: 764, Average Score: 222.81
# Environment solved in 664 episodes! Average Score: 222.81
# Episode: 765, Average Score: 222.72
# Environment solved in 665 episodes! Average Score: 222.72
# Episode: 766, Average Score: 223.05
# Environment solved in 666 episodes! Average Score: 223.05
# Episode: 767, Average Score: 223.53
# Environment solved in 667 episodes! Average Score: 223.53
# Episode: 768, Average Score: 223.92
# Environment solved in 668 episodes! Average Score: 223.92
# Episode: 769, Average Score: 224.22
# Environment solved in 669 episodes! Average Score: 224.22
# Episode: 770, Average Score: 224.48
# Environment solved in 670 episodes! Average Score: 224.48
# Episode: 771, Average Score: 225.22
# Environment solved in 671 episodes! Average Score: 225.22
# Episode: 772, Average Score: 227.06
# Environment solved in 672 episodes! Average Score: 227.06
# Episode: 773, Average Score: 227.48
# Environment solved in 673 episodes! Average Score: 227.48
# Episode: 774, Average Score: 228.29
# Environment solved in 674 episodes! Average Score: 228.29
# Episode: 775, Average Score: 229.06
# Environment solved in 675 episodes! Average Score: 229.06
# Episode: 776, Average Score: 229.58
# Environment solved in 676 episodes! Average Score: 229.58
# Episode: 777, Average Score: 230.45
# Environment solved in 677 episodes! Average Score: 230.45
# Episode: 778, Average Score: 230.73
# Environment solved in 678 episodes! Average Score: 230.73
# Episode: 779, Average Score: 230.25
# Environment solved in 679 episodes! Average Score: 230.25
# Episode: 780, Average Score: 230.03
# Environment solved in 680 episodes! Average Score: 230.03
# Episode: 781, Average Score: 230.20
# Environment solved in 681 episodes! Average Score: 230.20
# Episode: 782, Average Score: 230.11
# Environment solved in 682 episodes! Average Score: 230.11
# Episode: 783, Average Score: 230.37
# Environment solved in 683 episodes! Average Score: 230.37
# Episode: 784, Average Score: 231.57
# Environment solved in 684 episodes! Average Score: 231.57
# Episode: 785, Average Score: 231.43
# Environment solved in 685 episodes! Average Score: 231.43
# Episode: 786, Average Score: 231.31
# Environment solved in 686 episodes! Average Score: 231.31
# Episode: 787, Average Score: 231.53
# Environment solved in 687 episodes! Average Score: 231.53
# Episode: 788, Average Score: 231.61
# Environment solved in 688 episodes! Average Score: 231.61
# Episode: 789, Average Score: 232.49
# Environment solved in 689 episodes! Average Score: 232.49
# Episode: 790, Average Score: 232.58
# Environment solved in 690 episodes! Average Score: 232.58
# Episode: 791, Average Score: 232.68
# Environment solved in 691 episodes! Average Score: 232.68
# Episode: 792, Average Score: 232.51
# Environment solved in 692 episodes! Average Score: 232.51
# Episode: 793, Average Score: 232.78
# Environment solved in 693 episodes! Average Score: 232.78
# Episode: 794, Average Score: 232.60
# Environment solved in 694 episodes! Average Score: 232.60
# Episode: 795, Average Score: 232.44
# Environment solved in 695 episodes! Average Score: 232.44
# Episode: 796, Average Score: 232.25
# Environment solved in 696 episodes! Average Score: 232.25
# Episode: 797, Average Score: 232.63
# Environment solved in 697 episodes! Average Score: 232.63
# Episode: 798, Average Score: 233.38
# Environment solved in 698 episodes! Average Score: 233.38
# Episode: 799, Average Score: 233.10
# Environment solved in 699 episodes! Average Score: 233.10
# Episode: 800, Average Score: 232.90
#
# Environment solved in 700 episodes! Average Score: 232.90
# Episode: 801, Average Score: 232.36
# Environment solved in 701 episodes! Average Score: 232.36
# Episode: 802, Average Score: 232.91
# Environment solved in 702 episodes! Average Score: 232.91
# Episode: 803, Average Score: 232.38
# Environment solved in 703 episodes! Average Score: 232.38
# Episode: 804, Average Score: 232.59
# Environment solved in 704 episodes! Average Score: 232.59
# Episode: 805, Average Score: 233.18
# Environment solved in 705 episodes! Average Score: 233.18
# Episode: 806, Average Score: 232.98
# Environment solved in 706 episodes! Average Score: 232.98
# Episode: 807, Average Score: 233.65
# Environment solved in 707 episodes! Average Score: 233.65
# Episode: 808, Average Score: 234.06
# Environment solved in 708 episodes! Average Score: 234.06
# Episode: 809, Average Score: 234.55
# Environment solved in 709 episodes! Average Score: 234.55
# Episode: 810, Average Score: 233.88
# Environment solved in 710 episodes! Average Score: 233.88
# Episode: 811, Average Score: 234.17
# Environment solved in 711 episodes! Average Score: 234.17
# Episode: 812, Average Score: 234.73
# Environment solved in 712 episodes! Average Score: 234.73
# Episode: 813, Average Score: 234.30
# Environment solved in 713 episodes! Average Score: 234.30
# Episode: 814, Average Score: 234.19
# Environment solved in 714 episodes! Average Score: 234.19
# Episode: 815, Average Score: 234.08
# Environment solved in 715 episodes! Average Score: 234.08
# Episode: 816, Average Score: 232.93
# Environment solved in 716 episodes! Average Score: 232.93
# Episode: 817, Average Score: 233.12
# Environment solved in 717 episodes! Average Score: 233.12
# Episode: 818, Average Score: 232.67
# Environment solved in 718 episodes! Average Score: 232.67
# Episode: 819, Average Score: 232.26
# Environment solved in 719 episodes! Average Score: 232.26
# Episode: 820, Average Score: 233.12
# Environment solved in 720 episodes! Average Score: 233.12
# Episode: 821, Average Score: 233.74
# Environment solved in 721 episodes! Average Score: 233.74
# Episode: 822, Average Score: 233.28
# Environment solved in 722 episodes! Average Score: 233.28
# Episode: 823, Average Score: 232.91
# Environment solved in 723 episodes! Average Score: 232.91
# Episode: 824, Average Score: 233.15
# Environment solved in 724 episodes! Average Score: 233.15
# Episode: 825, Average Score: 233.61
# Environment solved in 725 episodes! Average Score: 233.61
# Episode: 826, Average Score: 234.21
# Environment solved in 726 episodes! Average Score: 234.21
# Episode: 827, Average Score: 233.90
# Environment solved in 727 episodes! Average Score: 233.90
# Episode: 828, Average Score: 234.60
# Environment solved in 728 episodes! Average Score: 234.60
# Episode: 829, Average Score: 235.53
# Environment solved in 729 episodes! Average Score: 235.53
# Episode: 830, Average Score: 235.09
# Environment solved in 730 episodes! Average Score: 235.09
# Episode: 831, Average Score: 235.33
# Environment solved in 731 episodes! Average Score: 235.33
# Episode: 832, Average Score: 235.45
# Environment solved in 732 episodes! Average Score: 235.45
# Episode: 833, Average Score: 236.06
# Environment solved in 733 episodes! Average Score: 236.06
# Episode: 834, Average Score: 236.28
# Environment solved in 734 episodes! Average Score: 236.28
# Episode: 835, Average Score: 233.46
# Environment solved in 735 episodes! Average Score: 233.46
# Episode: 836, Average Score: 233.48
# Environment solved in 736 episodes! Average Score: 233.48
# Episode: 837, Average Score: 233.27
# Environment solved in 737 episodes! Average Score: 233.27
# Episode: 838, Average Score: 233.33
# Environment solved in 738 episodes! Average Score: 233.33
# Episode: 839, Average Score: 233.22
# Environment solved in 739 episodes! Average Score: 233.22
# Episode: 840, Average Score: 233.43
# Environment solved in 740 episodes! Average Score: 233.43
# Episode: 841, Average Score: 233.16
# Environment solved in 741 episodes! Average Score: 233.16
# Episode: 842, Average Score: 232.84
# Environment solved in 742 episodes! Average Score: 232.84
# Episode: 843, Average Score: 233.03
# Environment solved in 743 episodes! Average Score: 233.03
# Episode: 844, Average Score: 233.30
# Environment solved in 744 episodes! Average Score: 233.30
# Episode: 845, Average Score: 232.89
# Environment solved in 745 episodes! Average Score: 232.89
# Episode: 846, Average Score: 233.36
# Environment solved in 746 episodes! Average Score: 233.36
# Episode: 847, Average Score: 233.14
# Environment solved in 747 episodes! Average Score: 233.14
# Episode: 848, Average Score: 232.83
# Environment solved in 748 episodes! Average Score: 232.83
# Episode: 849, Average Score: 232.17
# Environment solved in 749 episodes! Average Score: 232.17
# Episode: 850, Average Score: 231.46
# Environment solved in 750 episodes! Average Score: 231.46
# Episode: 851, Average Score: 231.62
# Environment solved in 751 episodes! Average Score: 231.62
# Episode: 852, Average Score: 231.99
# Environment solved in 752 episodes! Average Score: 231.99
# Episode: 853, Average Score: 232.13
# Environment solved in 753 episodes! Average Score: 232.13
# Episode: 854, Average Score: 232.41
# Environment solved in 754 episodes! Average Score: 232.41
# Episode: 855, Average Score: 232.21
# Environment solved in 755 episodes! Average Score: 232.21
# Episode: 856, Average Score: 232.61
# Environment solved in 756 episodes! Average Score: 232.61
# Episode: 857, Average Score: 232.89
# Environment solved in 757 episodes! Average Score: 232.89
# Episode: 858, Average Score: 233.35
# Environment solved in 758 episodes! Average Score: 233.35
# Episode: 859, Average Score: 233.73
# Environment solved in 759 episodes! Average Score: 233.73
# Episode: 860, Average Score: 233.69
# Environment solved in 760 episodes! Average Score: 233.69
# Episode: 861, Average Score: 233.81
# Environment solved in 761 episodes! Average Score: 233.81
# Episode: 862, Average Score: 233.75
# Environment solved in 762 episodes! Average Score: 233.75
# Episode: 863, Average Score: 233.54
# Environment solved in 763 episodes! Average Score: 233.54
# Episode: 864, Average Score: 233.31
# Environment solved in 764 episodes! Average Score: 233.31
# Episode: 865, Average Score: 233.56
# Environment solved in 765 episodes! Average Score: 233.56
# Episode: 866, Average Score: 233.67
# Environment solved in 766 episodes! Average Score: 233.67
# Episode: 867, Average Score: 233.88
# Environment solved in 767 episodes! Average Score: 233.88
# Episode: 868, Average Score: 232.97
# Environment solved in 768 episodes! Average Score: 232.97
# Episode: 869, Average Score: 232.76
# Environment solved in 769 episodes! Average Score: 232.76
# Episode: 870, Average Score: 232.61
# Environment solved in 770 episodes! Average Score: 232.61
# Episode: 871, Average Score: 232.91
# Environment solved in 771 episodes! Average Score: 232.91
# Episode: 872, Average Score: 233.99
# Environment solved in 772 episodes! Average Score: 233.99
# Episode: 873, Average Score: 233.83
# Environment solved in 773 episodes! Average Score: 233.83
# Episode: 874, Average Score: 233.73
# Environment solved in 774 episodes! Average Score: 233.73
# Episode: 875, Average Score: 233.89
# Environment solved in 775 episodes! Average Score: 233.89
# Episode: 876, Average Score: 233.35
# Environment solved in 776 episodes! Average Score: 233.35
# Episode: 877, Average Score: 233.25
# Environment solved in 777 episodes! Average Score: 233.25
# Episode: 878, Average Score: 232.84
# Environment solved in 778 episodes! Average Score: 232.84
# Episode: 879, Average Score: 232.77
# Environment solved in 779 episodes! Average Score: 232.77
# Episode: 880, Average Score: 232.94
# Environment solved in 780 episodes! Average Score: 232.94
# Episode: 881, Average Score: 230.76
# Environment solved in 781 episodes! Average Score: 230.76
# Episode: 882, Average Score: 229.90
# Environment solved in 782 episodes! Average Score: 229.90
# Episode: 883, Average Score: 229.71
# Environment solved in 783 episodes! Average Score: 229.71
# Episode: 884, Average Score: 229.62
# Environment solved in 784 episodes! Average Score: 229.62
# Episode: 885, Average Score: 229.39
# Environment solved in 785 episodes! Average Score: 229.39
# Episode: 886, Average Score: 229.72
# Environment solved in 786 episodes! Average Score: 229.72
# Episode: 887, Average Score: 229.60
# Environment solved in 787 episodes! Average Score: 229.60
# Episode: 888, Average Score: 229.90
# Environment solved in 788 episodes! Average Score: 229.90
# Episode: 889, Average Score: 229.56
# Environment solved in 789 episodes! Average Score: 229.56
# Episode: 890, Average Score: 231.13
# Environment solved in 790 episodes! Average Score: 231.13
# Episode: 891, Average Score: 230.26
# Environment solved in 791 episodes! Average Score: 230.26
# Episode: 892, Average Score: 230.28
# Environment solved in 792 episodes! Average Score: 230.28
# Episode: 893, Average Score: 229.78
# Environment solved in 793 episodes! Average Score: 229.78
# Episode: 894, Average Score: 229.34
# Environment solved in 794 episodes! Average Score: 229.34
# Episode: 895, Average Score: 229.30
# Environment solved in 795 episodes! Average Score: 229.30
# Episode: 896, Average Score: 229.70
# Environment solved in 796 episodes! Average Score: 229.70
# Episode: 897, Average Score: 229.36
# Environment solved in 797 episodes! Average Score: 229.36
# Episode: 898, Average Score: 229.27
# Environment solved in 798 episodes! Average Score: 229.27
# Episode: 899, Average Score: 229.93
# Environment solved in 799 episodes! Average Score: 229.93
# Episode: 900, Average Score: 229.82
#
# Environment solved in 800 episodes! Average Score: 229.82
# Episode: 901, Average Score: 229.57
# Environment solved in 801 episodes! Average Score: 229.57
# Episode: 902, Average Score: 229.59
# Environment solved in 802 episodes! Average Score: 229.59
# Episode: 903, Average Score: 229.46
# Environment solved in 803 episodes! Average Score: 229.46
# Episode: 904, Average Score: 229.88
# Environment solved in 804 episodes! Average Score: 229.88
# Episode: 905, Average Score: 229.74
# Environment solved in 805 episodes! Average Score: 229.74
# Episode: 906, Average Score: 230.31
# Environment solved in 806 episodes! Average Score: 230.31
# Episode: 907, Average Score: 226.87
# Environment solved in 807 episodes! Average Score: 226.87
# Episode: 908, Average Score: 226.95
# Environment solved in 808 episodes! Average Score: 226.95
# Episode: 909, Average Score: 226.73
# Environment solved in 809 episodes! Average Score: 226.73
# Episode: 910, Average Score: 226.61
# Environment solved in 810 episodes! Average Score: 226.61
# Episode: 911, Average Score: 225.31
# Environment solved in 811 episodes! Average Score: 225.31
# Episode: 912, Average Score: 225.21
# Environment solved in 812 episodes! Average Score: 225.21
# Episode: 913, Average Score: 223.85
# Environment solved in 813 episodes! Average Score: 223.85
# Episode: 914, Average Score: 223.90
# Environment solved in 814 episodes! Average Score: 223.90
# Episode: 915, Average Score: 221.65
# Environment solved in 815 episodes! Average Score: 221.65
# Episode: 916, Average Score: 223.12
# Environment solved in 816 episodes! Average Score: 223.12
# Episode: 917, Average Score: 223.42
# Environment solved in 817 episodes! Average Score: 223.42
# Episode: 918, Average Score: 224.45
# Environment solved in 818 episodes! Average Score: 224.45
# Episode: 919, Average Score: 224.89
# Environment solved in 819 episodes! Average Score: 224.89
# Episode: 920, Average Score: 224.30
# Environment solved in 820 episodes! Average Score: 224.30
# Episode: 921, Average Score: 222.46
# Environment solved in 821 episodes! Average Score: 222.46
# Episode: 922, Average Score: 222.68
# Environment solved in 822 episodes! Average Score: 222.68
# Episode: 923, Average Score: 222.90
# Environment solved in 823 episodes! Average Score: 222.90
# Episode: 924, Average Score: 223.17
# Environment solved in 824 episodes! Average Score: 223.17
# Episode: 925, Average Score: 223.01
# Environment solved in 825 episodes! Average Score: 223.01
# Episode: 926, Average Score: 222.29
# Environment solved in 826 episodes! Average Score: 222.29
# Episode: 927, Average Score: 222.28
# Environment solved in 827 episodes! Average Score: 222.28
# Episode: 928, Average Score: 222.09
# Environment solved in 828 episodes! Average Score: 222.09
# Episode: 929, Average Score: 222.37
# Environment solved in 829 episodes! Average Score: 222.37
# Episode: 930, Average Score: 222.54
# Environment solved in 830 episodes! Average Score: 222.54
# Episode: 931, Average Score: 222.06
# Environment solved in 831 episodes! Average Score: 222.06
# Episode: 932, Average Score: 221.38
# Environment solved in 832 episodes! Average Score: 221.38
# Episode: 933, Average Score: 221.55
# Environment solved in 833 episodes! Average Score: 221.55
# Episode: 934, Average Score: 220.99
# Environment solved in 834 episodes! Average Score: 220.99
# Episode: 935, Average Score: 223.31
# Environment solved in 835 episodes! Average Score: 223.31
# Episode: 936, Average Score: 224.10
# Environment solved in 836 episodes! Average Score: 224.10
# Episode: 937, Average Score: 223.87
# Environment solved in 837 episodes! Average Score: 223.87
# Episode: 938, Average Score: 223.79
# Environment solved in 838 episodes! Average Score: 223.79
# Episode: 939, Average Score: 224.15
# Environment solved in 839 episodes! Average Score: 224.15
# Episode: 940, Average Score: 223.93
# Environment solved in 840 episodes! Average Score: 223.93
# Episode: 941, Average Score: 223.47
# Environment solved in 841 episodes! Average Score: 223.47
# Episode: 942, Average Score: 223.46
# Environment solved in 842 episodes! Average Score: 223.46
# Episode: 943, Average Score: 223.29
# Environment solved in 843 episodes! Average Score: 223.29
# Episode: 944, Average Score: 222.94
# Environment solved in 844 episodes! Average Score: 222.94
# Episode: 945, Average Score: 223.62
# Environment solved in 845 episodes! Average Score: 223.62
# Episode: 946, Average Score: 222.21
# Environment solved in 846 episodes! Average Score: 222.21
# Episode: 947, Average Score: 222.16
# Environment solved in 847 episodes! Average Score: 222.16
# Episode: 948, Average Score: 221.93
# Environment solved in 848 episodes! Average Score: 221.93
# Episode: 949, Average Score: 221.55
# Environment solved in 849 episodes! Average Score: 221.55
# Episode: 950, Average Score: 222.21
# Environment solved in 850 episodes! Average Score: 222.21
# Episode: 951, Average Score: 222.34
# Environment solved in 851 episodes! Average Score: 222.34
# Episode: 952, Average Score: 222.46
# Environment solved in 852 episodes! Average Score: 222.46
# Episode: 953, Average Score: 222.59
# Environment solved in 853 episodes! Average Score: 222.59
# Episode: 954, Average Score: 219.57
# Environment solved in 854 episodes! Average Score: 219.57
# Episode: 955, Average Score: 220.61
# Environment solved in 855 episodes! Average Score: 220.61
# Episode: 956, Average Score: 219.90
# Environment solved in 856 episodes! Average Score: 219.90
# Episode: 957, Average Score: 220.02
# Environment solved in 857 episodes! Average Score: 220.02
# Episode: 958, Average Score: 220.64
# Environment solved in 858 episodes! Average Score: 220.64
# Episode: 959, Average Score: 219.66
# Environment solved in 859 episodes! Average Score: 219.66
# Episode: 960, Average Score: 216.78
# Environment solved in 860 episodes! Average Score: 216.78
# Episode: 961, Average Score: 216.19
# Environment solved in 861 episodes! Average Score: 216.19
# Episode: 962, Average Score: 216.61
# Environment solved in 862 episodes! Average Score: 216.61
# Episode: 963, Average Score: 214.12
# Environment solved in 863 episodes! Average Score: 214.12
# Episode: 964, Average Score: 214.29
# Environment solved in 864 episodes! Average Score: 214.29
# Episode: 965, Average Score: 213.73
# Environment solved in 865 episodes! Average Score: 213.73
# Episode: 966, Average Score: 213.70
# Environment solved in 866 episodes! Average Score: 213.70
# Episode: 967, Average Score: 213.16
# Environment solved in 867 episodes! Average Score: 213.16
# Episode: 968, Average Score: 214.21
# Environment solved in 868 episodes! Average Score: 214.21
# Episode: 969, Average Score: 213.98
# Environment solved in 869 episodes! Average Score: 213.98
# Episode: 970, Average Score: 214.00
# Environment solved in 870 episodes! Average Score: 214.00
# Episode: 971, Average Score: 214.29
# Environment solved in 871 episodes! Average Score: 214.29
# Episode: 972, Average Score: 213.48
# Environment solved in 872 episodes! Average Score: 213.48
# Episode: 973, Average Score: 213.09
# Environment solved in 873 episodes! Average Score: 213.09
# Episode: 974, Average Score: 213.22
# Environment solved in 874 episodes! Average Score: 213.22
# Episode: 975, Average Score: 213.18
# Environment solved in 875 episodes! Average Score: 213.18
# Episode: 976, Average Score: 213.39
# Environment solved in 876 episodes! Average Score: 213.39
# Episode: 977, Average Score: 212.71
# Environment solved in 877 episodes! Average Score: 212.71
# Episode: 978, Average Score: 212.23
# Environment solved in 878 episodes! Average Score: 212.23
# Episode: 979, Average Score: 212.20
# Environment solved in 879 episodes! Average Score: 212.20
# Episode: 980, Average Score: 212.07
# Environment solved in 880 episodes! Average Score: 212.07
# Episode: 981, Average Score: 214.87
# Environment solved in 881 episodes! Average Score: 214.87
# Episode: 982, Average Score: 215.76
# Environment solved in 882 episodes! Average Score: 215.76
# Episode: 983, Average Score: 216.12
# Environment solved in 883 episodes! Average Score: 216.12
# Episode: 984, Average Score: 215.50
# Environment solved in 884 episodes! Average Score: 215.50
# Episode: 985, Average Score: 216.45
# Environment solved in 885 episodes! Average Score: 216.45
# Episode: 986, Average Score: 216.72
# Environment solved in 886 episodes! Average Score: 216.72
# Episode: 987, Average Score: 216.19
# Environment solved in 887 episodes! Average Score: 216.19
# Episode: 988, Average Score: 216.60
# Environment solved in 888 episodes! Average Score: 216.60
# Episode: 989, Average Score: 217.09
# Environment solved in 889 episodes! Average Score: 217.09
# Episode: 990, Average Score: 216.61
# Environment solved in 890 episodes! Average Score: 216.61
# Episode: 991, Average Score: 217.92
# Environment solved in 891 episodes! Average Score: 217.92
# Episode: 992, Average Score: 217.73
# Environment solved in 892 episodes! Average Score: 217.73
# Episode: 993, Average Score: 218.78
# Environment solved in 893 episodes! Average Score: 218.78
# Episode: 994, Average Score: 219.57
# Environment solved in 894 episodes! Average Score: 219.57
# Episode: 995, Average Score: 219.73
# Environment solved in 895 episodes! Average Score: 219.73
# Episode: 996, Average Score: 219.62
# Environment solved in 896 episodes! Average Score: 219.62
# Episode: 997, Average Score: 219.57
# Environment solved in 897 episodes! Average Score: 219.57
# Episode: 998, Average Score: 220.04
# Environment solved in 898 episodes! Average Score: 220.04
# Episode: 999, Average Score: 219.95
# Environment solved in 899 episodes! Average Score: 219.95
# Episode: 1000, Average Score: 220.35
#
# Environment solved in 900 episodes! Average Score: 220.35
# Episode: 1001, Average Score: 220.08
# Environment solved in 901 episodes! Average Score: 220.08
# Episode: 1002, Average Score: 219.30
# Environment solved in 902 episodes! Average Score: 219.30
# Episode: 1003, Average Score: 219.65
# Environment solved in 903 episodes! Average Score: 219.65
# Episode: 1004, Average Score: 218.38
# Environment solved in 904 episodes! Average Score: 218.38
# Episode: 1005, Average Score: 218.18
# Environment solved in 905 episodes! Average Score: 218.18
# Episode: 1006, Average Score: 217.01
# Environment solved in 906 episodes! Average Score: 217.01
# Episode: 1007, Average Score: 219.88
# Environment solved in 907 episodes! Average Score: 219.88
# Episode: 1008, Average Score: 219.12
# Environment solved in 908 episodes! Average Score: 219.12
# Episode: 1009, Average Score: 219.72
# Environment solved in 909 episodes! Average Score: 219.72
# Episode: 1010, Average Score: 220.97
# Environment solved in 910 episodes! Average Score: 220.97
# Episode: 1011, Average Score: 222.63
# Environment solved in 911 episodes! Average Score: 222.63
# Episode: 1012, Average Score: 222.41
# Environment solved in 912 episodes! Average Score: 222.41
# Episode: 1013, Average Score: 224.12
# Environment solved in 913 episodes! Average Score: 224.12
# Episode: 1014, Average Score: 220.95
# Environment solved in 914 episodes! Average Score: 220.95
# Episode: 1015, Average Score: 221.22
# Environment solved in 915 episodes! Average Score: 221.22
# Episode: 1016, Average Score: 218.54
# Environment solved in 916 episodes! Average Score: 218.54
# Episode: 1017, Average Score: 217.63
# Environment solved in 917 episodes! Average Score: 217.63
# Episode: 1018, Average Score: 216.92
# Environment solved in 918 episodes! Average Score: 216.92
# Episode: 1019, Average Score: 217.61
# Environment solved in 919 episodes! Average Score: 217.61
# Episode: 1020, Average Score: 218.16
# Environment solved in 920 episodes! Average Score: 218.16
# Episode: 1021, Average Score: 219.64
# Environment solved in 921 episodes! Average Score: 219.64
# Episode: 1022, Average Score: 219.90
# Environment solved in 922 episodes! Average Score: 219.90
# Episode: 1023, Average Score: 217.81
# Environment solved in 923 episodes! Average Score: 217.81
# Episode: 1024, Average Score: 217.37
# Environment solved in 924 episodes! Average Score: 217.37
# Episode: 1025, Average Score: 217.47
# Environment solved in 925 episodes! Average Score: 217.47
# Episode: 1026, Average Score: 217.06
# Environment solved in 926 episodes! Average Score: 217.06
# Episode: 1027, Average Score: 216.84
# Environment solved in 927 episodes! Average Score: 216.84
# Episode: 1028, Average Score: 215.88
# Environment solved in 928 episodes! Average Score: 215.88
# Episode: 1029, Average Score: 215.79
# Environment solved in 929 episodes! Average Score: 215.79
# Episode: 1030, Average Score: 216.30
# Environment solved in 930 episodes! Average Score: 216.30
# Episode: 1031, Average Score: 216.49
# Environment solved in 931 episodes! Average Score: 216.49
# Episode: 1032, Average Score: 216.93
# Environment solved in 932 episodes! Average Score: 216.93
# Episode: 1033, Average Score: 216.96
# Environment solved in 933 episodes! Average Score: 216.96
# Episode: 1034, Average Score: 217.55
# Environment solved in 934 episodes! Average Score: 217.55
# Episode: 1035, Average Score: 218.10
# Environment solved in 935 episodes! Average Score: 218.10
# Episode: 1036, Average Score: 217.69
# Environment solved in 936 episodes! Average Score: 217.69
# Episode: 1037, Average Score: 217.84
# Environment solved in 937 episodes! Average Score: 217.84
# Episode: 1038, Average Score: 217.74
# Environment solved in 938 episodes! Average Score: 217.74
# Episode: 1039, Average Score: 214.69
# Environment solved in 939 episodes! Average Score: 214.69
# Episode: 1040, Average Score: 214.97
# Environment solved in 940 episodes! Average Score: 214.97
# Episode: 1041, Average Score: 213.47
# Environment solved in 941 episodes! Average Score: 213.47
# Episode: 1042, Average Score: 212.90
# Environment solved in 942 episodes! Average Score: 212.90
# Episode: 1043, Average Score: 212.58
# Environment solved in 943 episodes! Average Score: 212.58
# Episode: 1044, Average Score: 212.58
# Environment solved in 944 episodes! Average Score: 212.58
# Episode: 1045, Average Score: 212.26
# Environment solved in 945 episodes! Average Score: 212.26
# Episode: 1046, Average Score: 213.35
# Environment solved in 946 episodes! Average Score: 213.35
# Episode: 1047, Average Score: 213.56
# Environment solved in 947 episodes! Average Score: 213.56
# Episode: 1048, Average Score: 214.03
# Environment solved in 948 episodes! Average Score: 214.03
# Episode: 1049, Average Score: 214.66
# Environment solved in 949 episodes! Average Score: 214.66
# Episode: 1050, Average Score: 214.85
# Environment solved in 950 episodes! Average Score: 214.85
# Episode: 1051, Average Score: 215.18
# Environment solved in 951 episodes! Average Score: 215.18
# Episode: 1052, Average Score: 214.34
# Environment solved in 952 episodes! Average Score: 214.34
# Episode: 1053, Average Score: 213.83
# Environment solved in 953 episodes! Average Score: 213.83
# Episode: 1054, Average Score: 216.92
# Environment solved in 954 episodes! Average Score: 216.92
# Episode: 1055, Average Score: 216.66
# Environment solved in 955 episodes! Average Score: 216.66
# Episode: 1056, Average Score: 217.56
# Environment solved in 956 episodes! Average Score: 217.56
# Episode: 1057, Average Score: 217.27
# Environment solved in 957 episodes! Average Score: 217.27
# Episode: 1058, Average Score: 216.55
# Environment solved in 958 episodes! Average Score: 216.55
# Episode: 1059, Average Score: 216.65
# Environment solved in 959 episodes! Average Score: 216.65
# Episode: 1060, Average Score: 219.23
# Environment solved in 960 episodes! Average Score: 219.23
# Episode: 1061, Average Score: 219.05
# Environment solved in 961 episodes! Average Score: 219.05
# Episode: 1062, Average Score: 218.72
# Environment solved in 962 episodes! Average Score: 218.72
# Episode: 1063, Average Score: 220.95
# Environment solved in 963 episodes! Average Score: 220.95
# Episode: 1064, Average Score: 221.30
# Environment solved in 964 episodes! Average Score: 221.30
# Episode: 1065, Average Score: 221.45
# Environment solved in 965 episodes! Average Score: 221.45
# Episode: 1066, Average Score: 219.19
# Environment solved in 966 episodes! Average Score: 219.19
# Episode: 1067, Average Score: 217.08
# Environment solved in 967 episodes! Average Score: 217.08
# Episode: 1068, Average Score: 216.36
# Environment solved in 968 episodes! Average Score: 216.36
# Episode: 1069, Average Score: 217.16
# Environment solved in 969 episodes! Average Score: 217.16
# Episode: 1070, Average Score: 217.49
# Environment solved in 970 episodes! Average Score: 217.49
# Episode: 1071, Average Score: 215.03
# Environment solved in 971 episodes! Average Score: 215.03
# Episode: 1072, Average Score: 213.22
# Environment solved in 972 episodes! Average Score: 213.22
# Episode: 1073, Average Score: 213.46
# Environment solved in 973 episodes! Average Score: 213.46
# Episode: 1074, Average Score: 213.29
# Environment solved in 974 episodes! Average Score: 213.29
# Episode: 1075, Average Score: 212.64
# Environment solved in 975 episodes! Average Score: 212.64
# Episode: 1076, Average Score: 213.16
# Environment solved in 976 episodes! Average Score: 213.16
# Episode: 1077, Average Score: 213.64
# Environment solved in 977 episodes! Average Score: 213.64
# Episode: 1078, Average Score: 213.81
# Environment solved in 978 episodes! Average Score: 213.81
# Episode: 1079, Average Score: 213.66
# Environment solved in 979 episodes! Average Score: 213.66
# Episode: 1080, Average Score: 210.91
# Environment solved in 980 episodes! Average Score: 210.91
# Episode: 1081, Average Score: 210.34
# Environment solved in 981 episodes! Average Score: 210.34
# Episode: 1082, Average Score: 210.81
# Environment solved in 982 episodes! Average Score: 210.81
# Episode: 1083, Average Score: 210.89
# Environment solved in 983 episodes! Average Score: 210.89
# Episode: 1084, Average Score: 211.39
# Environment solved in 984 episodes! Average Score: 211.39
# Episode: 1085, Average Score: 211.35
# Environment solved in 985 episodes! Average Score: 211.35
# Episode: 1086, Average Score: 210.91
# Environment solved in 986 episodes! Average Score: 210.91
# Episode: 1087, Average Score: 211.60
# Environment solved in 987 episodes! Average Score: 211.60
# Episode: 1088, Average Score: 208.69
# Environment solved in 988 episodes! Average Score: 208.69
# Episode: 1089, Average Score: 208.77
# Environment solved in 989 episodes! Average Score: 208.77
# Episode: 1090, Average Score: 208.54
# Environment solved in 990 episodes! Average Score: 208.54
# Episode: 1091, Average Score: 208.19
# Environment solved in 991 episodes! Average Score: 208.19
# Episode: 1092, Average Score: 207.54
# Environment solved in 992 episodes! Average Score: 207.54
# Episode: 1093, Average Score: 207.29
# Environment solved in 993 episodes! Average Score: 207.29
# Episode: 1094, Average Score: 207.13
# Environment solved in 994 episodes! Average Score: 207.13
# Episode: 1095, Average Score: 206.86
# Environment solved in 995 episodes! Average Score: 206.86
# Episode: 1096, Average Score: 204.95
# Environment solved in 996 episodes! Average Score: 204.95
# Episode: 1097, Average Score: 205.09
# Environment solved in 997 episodes! Average Score: 205.09
# Episode: 1098, Average Score: 204.99
# Environment solved in 998 episodes! Average Score: 204.99
# Episode: 1099, Average Score: 204.40
# Environment solved in 999 episodes! Average Score: 204.40
# Episode: 1100, Average Score: 203.75
#
# Environment solved in 1000 episodes! Average Score: 203.75
# Episode: 1101, Average Score: 204.62
# Environment solved in 1001 episodes! Average Score: 204.62
# Episode: 1102, Average Score: 205.06
# Environment solved in 1002 episodes! Average Score: 205.06
# Episode: 1103, Average Score: 205.34
# Environment solved in 1003 episodes! Average Score: 205.34
# Episode: 1104, Average Score: 207.04
# Environment solved in 1004 episodes! Average Score: 207.04
# Episode: 1105, Average Score: 206.91
# Environment solved in 1005 episodes! Average Score: 206.91
# Episode: 1106, Average Score: 207.72
# Environment solved in 1006 episodes! Average Score: 207.72
# Episode: 1107, Average Score: 207.91
# Environment solved in 1007 episodes! Average Score: 207.91
# Episode: 1108, Average Score: 208.37
# Environment solved in 1008 episodes! Average Score: 208.37
# Episode: 1109, Average Score: 207.32
# Environment solved in 1009 episodes! Average Score: 207.32
# Episode: 1110, Average Score: 206.46
# Environment solved in 1010 episodes! Average Score: 206.46
# Episode: 1111, Average Score: 205.94
# Environment solved in 1011 episodes! Average Score: 205.94
# Episode: 1112, Average Score: 206.53
# Environment solved in 1012 episodes! Average Score: 206.53
# Episode: 1113, Average Score: 205.79
# Environment solved in 1013 episodes! Average Score: 205.79
# Episode: 1114, Average Score: 208.53
# Environment solved in 1014 episodes! Average Score: 208.53
# Episode: 1115, Average Score: 210.28
# Environment solved in 1015 episodes! Average Score: 210.28
# Episode: 1116, Average Score: 212.43
# Environment solved in 1016 episodes! Average Score: 212.43
# Episode: 1117, Average Score: 213.39
# Environment solved in 1017 episodes! Average Score: 213.39
# Episode: 1118, Average Score: 211.20
# Environment solved in 1018 episodes! Average Score: 211.20
# Episode: 1119, Average Score: 211.31
# Environment solved in 1019 episodes! Average Score: 211.31
# Episode: 1120, Average Score: 211.32
# Environment solved in 1020 episodes! Average Score: 211.32
# Episode: 1121, Average Score: 211.63
# Environment solved in 1021 episodes! Average Score: 211.63
# Episode: 1122, Average Score: 211.51
# Environment solved in 1022 episodes! Average Score: 211.51
# Episode: 1123, Average Score: 214.18
# Environment solved in 1023 episodes! Average Score: 214.18
# Episode: 1124, Average Score: 214.79
# Environment solved in 1024 episodes! Average Score: 214.79
# Episode: 1125, Average Score: 214.76
# Environment solved in 1025 episodes! Average Score: 214.76
# Episode: 1126, Average Score: 216.04
# Environment solved in 1026 episodes! Average Score: 216.04
# Episode: 1127, Average Score: 213.72
# Environment solved in 1027 episodes! Average Score: 213.72
# Episode: 1128, Average Score: 213.67
# Environment solved in 1028 episodes! Average Score: 213.67
# Episode: 1129, Average Score: 213.92
# Environment solved in 1029 episodes! Average Score: 213.92
# Episode: 1130, Average Score: 213.69
# Environment solved in 1030 episodes! Average Score: 213.69
# Episode: 1131, Average Score: 213.44
# Environment solved in 1031 episodes! Average Score: 213.44
# Episode: 1132, Average Score: 213.61
# Environment solved in 1032 episodes! Average Score: 213.61
# Episode: 1133, Average Score: 213.79
# Environment solved in 1033 episodes! Average Score: 213.79
# Episode: 1134, Average Score: 213.44
# Environment solved in 1034 episodes! Average Score: 213.44
# Episode: 1135, Average Score: 212.87
# Environment solved in 1035 episodes! Average Score: 212.87
# Episode: 1136, Average Score: 212.34
# Environment solved in 1036 episodes! Average Score: 212.34
# Episode: 1137, Average Score: 212.81
# Environment solved in 1037 episodes! Average Score: 212.81
# Episode: 1138, Average Score: 212.41
# Environment solved in 1038 episodes! Average Score: 212.41
# Episode: 1139, Average Score: 215.40
# Environment solved in 1039 episodes! Average Score: 215.40
# Episode: 1140, Average Score: 215.48
# Environment solved in 1040 episodes! Average Score: 215.48
# Episode: 1141, Average Score: 217.62
# Environment solved in 1041 episodes! Average Score: 217.62
# Episode: 1142, Average Score: 217.81
# Environment solved in 1042 episodes! Average Score: 217.81
# Episode: 1143, Average Score: 217.58
# Environment solved in 1043 episodes! Average Score: 217.58
# Episode: 1144, Average Score: 217.46
# Environment solved in 1044 episodes! Average Score: 217.46
# Episode: 1145, Average Score: 217.80
# Environment solved in 1045 episodes! Average Score: 217.80
# Episode: 1146, Average Score: 217.69
# Environment solved in 1046 episodes! Average Score: 217.69
# Episode: 1147, Average Score: 217.02
# Environment solved in 1047 episodes! Average Score: 217.02
# Episode: 1148, Average Score: 216.47
# Environment solved in 1048 episodes! Average Score: 216.47
# Episode: 1149, Average Score: 216.20
# Environment solved in 1049 episodes! Average Score: 216.20
# Episode: 1150, Average Score: 215.83
# Environment solved in 1050 episodes! Average Score: 215.83
# Episode: 1151, Average Score: 215.59
# Environment solved in 1051 episodes! Average Score: 215.59
# Episode: 1152, Average Score: 216.14
# Environment solved in 1052 episodes! Average Score: 216.14
# Episode: 1153, Average Score: 216.40
# Environment solved in 1053 episodes! Average Score: 216.40
# Episode: 1154, Average Score: 215.28
# Environment solved in 1054 episodes! Average Score: 215.28
# Episode: 1155, Average Score: 213.29
# Environment solved in 1055 episodes! Average Score: 213.29
# Episode: 1156, Average Score: 213.04
# Environment solved in 1056 episodes! Average Score: 213.04
# Episode: 1157, Average Score: 213.17
# Environment solved in 1057 episodes! Average Score: 213.17
# Episode: 1158, Average Score: 213.40
# Environment solved in 1058 episodes! Average Score: 213.40
# Episode: 1159, Average Score: 213.71
# Environment solved in 1059 episodes! Average Score: 213.71
# Episode: 1160, Average Score: 214.02
# Environment solved in 1060 episodes! Average Score: 214.02
# Episode: 1161, Average Score: 214.08
# Environment solved in 1061 episodes! Average Score: 214.08
# Episode: 1162, Average Score: 214.74
# Environment solved in 1062 episodes! Average Score: 214.74
# Episode: 1163, Average Score: 215.35
# Environment solved in 1063 episodes! Average Score: 215.35
# Episode: 1164, Average Score: 214.80
# Environment solved in 1064 episodes! Average Score: 214.80
# Episode: 1165, Average Score: 214.53
# Environment solved in 1065 episodes! Average Score: 214.53
# Episode: 1166, Average Score: 215.74
# Environment solved in 1066 episodes! Average Score: 215.74
# Episode: 1167, Average Score: 218.50
# Environment solved in 1067 episodes! Average Score: 218.50
# Episode: 1168, Average Score: 218.74
# Environment solved in 1068 episodes! Average Score: 218.74
# Episode: 1169, Average Score: 218.61
# Environment solved in 1069 episodes! Average Score: 218.61
# Episode: 1170, Average Score: 218.77
# Environment solved in 1070 episodes! Average Score: 218.77
# Episode: 1171, Average Score: 220.89
# Environment solved in 1071 episodes! Average Score: 220.89
# Episode: 1172, Average Score: 223.06
# Environment solved in 1072 episodes! Average Score: 223.06
# Episode: 1173, Average Score: 223.41
# Environment solved in 1073 episodes! Average Score: 223.41
# Episode: 1174, Average Score: 223.04
# Environment solved in 1074 episodes! Average Score: 223.04
# Episode: 1175, Average Score: 223.16
# Environment solved in 1075 episodes! Average Score: 223.16
# Episode: 1176, Average Score: 222.41
# Environment solved in 1076 episodes! Average Score: 222.41
# Episode: 1177, Average Score: 222.13
# Environment solved in 1077 episodes! Average Score: 222.13
# Episode: 1178, Average Score: 222.77
# Environment solved in 1078 episodes! Average Score: 222.77
# Episode: 1179, Average Score: 222.99
# Environment solved in 1079 episodes! Average Score: 222.99
# Episode: 1180, Average Score: 225.88
# Environment solved in 1080 episodes! Average Score: 225.88
# Episode: 1181, Average Score: 226.48
# Environment solved in 1081 episodes! Average Score: 226.48
# Episode: 1182, Average Score: 226.34
# Environment solved in 1082 episodes! Average Score: 226.34
# Episode: 1183, Average Score: 226.57
# Environment solved in 1083 episodes! Average Score: 226.57
# Episode: 1184, Average Score: 226.37
# Environment solved in 1084 episodes! Average Score: 226.37
# Episode: 1185, Average Score: 226.11
# Environment solved in 1085 episodes! Average Score: 226.11
# Episode: 1186, Average Score: 225.80
# Environment solved in 1086 episodes! Average Score: 225.80
# Episode: 1187, Average Score: 225.11
# Environment solved in 1087 episodes! Average Score: 225.11
# Episode: 1188, Average Score: 227.25
# Environment solved in 1088 episodes! Average Score: 227.25
# Episode: 1189, Average Score: 226.66
# Environment solved in 1089 episodes! Average Score: 226.66
# Episode: 1190, Average Score: 226.48
# Environment solved in 1090 episodes! Average Score: 226.48
# Episode: 1191, Average Score: 226.40
# Environment solved in 1091 episodes! Average Score: 226.40
# Episode: 1192, Average Score: 227.36
# Environment solved in 1092 episodes! Average Score: 227.36
# Episode: 1193, Average Score: 227.43
# Environment solved in 1093 episodes! Average Score: 227.43
# Episode: 1194, Average Score: 226.91
# Environment solved in 1094 episodes! Average Score: 226.91
# Episode: 1195, Average Score: 226.86
# Environment solved in 1095 episodes! Average Score: 226.86
# Episode: 1196, Average Score: 228.95
# Environment solved in 1096 episodes! Average Score: 228.95
# Episode: 1197, Average Score: 229.31
# Environment solved in 1097 episodes! Average Score: 229.31
# Episode: 1198, Average Score: 228.77
# Environment solved in 1098 episodes! Average Score: 228.77
# Episode: 1199, Average Score: 229.33
# Environment solved in 1099 episodes! Average Score: 229.33
# Episode: 1200, Average Score: 230.10
#
# Environment solved in 1100 episodes! Average Score: 230.10
# Episode: 1201, Average Score: 229.55
# Environment solved in 1101 episodes! Average Score: 229.55
# Episode: 1202, Average Score: 227.71
# Environment solved in 1102 episodes! Average Score: 227.71
# Episode: 1203, Average Score: 225.80
# Environment solved in 1103 episodes! Average Score: 225.80
# Episode: 1204, Average Score: 225.04
# Environment solved in 1104 episodes! Average Score: 225.04
# Episode: 1205, Average Score: 225.29
# Environment solved in 1105 episodes! Average Score: 225.29
# Episode: 1206, Average Score: 225.49
# Environment solved in 1106 episodes! Average Score: 225.49
# Episode: 1207, Average Score: 225.07
# Environment solved in 1107 episodes! Average Score: 225.07
# Episode: 1208, Average Score: 222.30
# Environment solved in 1108 episodes! Average Score: 222.30
# Episode: 1209, Average Score: 222.41
# Environment solved in 1109 episodes! Average Score: 222.41
# Episode: 1210, Average Score: 222.52
# Environment solved in 1110 episodes! Average Score: 222.52
# Episode: 1211, Average Score: 221.75
# Environment solved in 1111 episodes! Average Score: 221.75
# Episode: 1212, Average Score: 221.53
# Environment solved in 1112 episodes! Average Score: 221.53
# Episode: 1213, Average Score: 221.71
# Environment solved in 1113 episodes! Average Score: 221.71
# Episode: 1214, Average Score: 219.20
# Environment solved in 1114 episodes! Average Score: 219.20
# Episode: 1215, Average Score: 216.78
# Environment solved in 1115 episodes! Average Score: 216.78
# Episode: 1216, Average Score: 216.63
# Environment solved in 1116 episodes! Average Score: 216.63
# Episode: 1217, Average Score: 216.52
# Environment solved in 1117 episodes! Average Score: 216.52
# Episode: 1218, Average Score: 217.91
# Environment solved in 1118 episodes! Average Score: 217.91
# Episode: 1219, Average Score: 217.94
# Environment solved in 1119 episodes! Average Score: 217.94
# Episode: 1220, Average Score: 215.38
# Environment solved in 1120 episodes! Average Score: 215.38
# Episode: 1221, Average Score: 215.42
# Environment solved in 1121 episodes! Average Score: 215.42
# Episode: 1222, Average Score: 214.87
# Environment solved in 1122 episodes! Average Score: 214.87
# Episode: 1223, Average Score: 214.56
# Environment solved in 1123 episodes! Average Score: 214.56
# Episode: 1224, Average Score: 212.19
# Environment solved in 1124 episodes! Average Score: 212.19
# Episode: 1225, Average Score: 212.14
# Environment solved in 1125 episodes! Average Score: 212.14
# Episode: 1226, Average Score: 212.14
# Environment solved in 1126 episodes! Average Score: 212.14
# Episode: 1227, Average Score: 215.12
# Environment solved in 1127 episodes! Average Score: 215.12
# Episode: 1228, Average Score: 215.56
# Environment solved in 1128 episodes! Average Score: 215.56
# Episode: 1229, Average Score: 215.25
# Environment solved in 1129 episodes! Average Score: 215.25
# Episode: 1230, Average Score: 213.28
# Environment solved in 1130 episodes! Average Score: 213.28
# Episode: 1231, Average Score: 212.98
# Environment solved in 1131 episodes! Average Score: 212.98
# Episode: 1232, Average Score: 212.55
# Environment solved in 1132 episodes! Average Score: 212.55
# Episode: 1233, Average Score: 212.40
# Environment solved in 1133 episodes! Average Score: 212.40
# Episode: 1234, Average Score: 210.24
# Environment solved in 1134 episodes! Average Score: 210.24
# Episode: 1235, Average Score: 211.00
# ...
# Episode: 1835, Average Score: 255.42
# Environment solved in 1735 episodes! Average Score: 255.42
# Episode: 1836, Average Score: 255.93
# Environment solved in 1736 episodes! Average Score: 255.93
# Episode: 1837, Average Score: 255.76
# Environment solved in 1737 episodes! Average Score: 255.76
# Episode: 1838, Average Score: 256.24
# Environment solved in 1738 episodes! Average Score: 256.24
# Episode: 1839, Average Score: 256.70
# Environment solved in 1739 episodes! Average Score: 256.70
# Episode: 1840, Average Score: 256.77
# Environment solved in 1740 episodes! Average Score: 256.77
# Episode: 1841, Average Score: 257.13
# Environment solved in 1741 episodes! Average Score: 257.13
# Episode: 1842, Average Score: 257.58
# Environment solved in 1742 episodes! Average Score: 257.58
# Episode: 1843, Average Score: 256.98
# Environment solved in 1743 episodes! Average Score: 256.98
# Episode: 1844, Average Score: 257.27
# Environment solved in 1744 episodes! Average Score: 257.27
# Episode: 1845, Average Score: 257.70
# Environment solved in 1745 episodes! Average Score: 257.70
# Episode: 1846, Average Score: 258.38
# Environment solved in 1746 episodes! Average Score: 258.38
# Episode: 1847, Average Score: 258.94
# Environment solved in 1747 episodes! Average Score: 258.94
# Episode: 1848, Average Score: 259.28
# Environment solved in 1748 episodes! Average Score: 259.28
# Episode: 1849, Average Score: 259.44
# Environment solved in 1749 episodes! Average Score: 259.44
# Episode: 1850, Average Score: 259.44
# Environment solved in 1750 episodes! Average Score: 259.44
# Episode: 1851, Average Score: 259.37
# Environment solved in 1751 episodes! Average Score: 259.37
# Episode: 1852, Average Score: 259.65
# Environment solved in 1752 episodes! Average Score: 259.65
# Episode: 1853, Average Score: 260.13
# Environment solved in 1753 episodes! Average Score: 260.13
# Episode: 1854, Average Score: 259.93
# Environment solved in 1754 episodes! Average Score: 259.93
# Episode: 1855, Average Score: 260.27
# Environment solved in 1755 episodes! Average Score: 260.27
# Episode: 1856, Average Score: 260.61
# Environment solved in 1756 episodes! Average Score: 260.61
# Episode: 1857, Average Score: 260.59
# Environment solved in 1757 episodes! Average Score: 260.59
# Episode: 1858, Average Score: 260.23
# Environment solved in 1758 episodes! Average Score: 260.23
# Episode: 1859, Average Score: 260.48
# Environment solved in 1759 episodes! Average Score: 260.48
# Episode: 1860, Average Score: 260.33
# Environment solved in 1760 episodes! Average Score: 260.33
# Episode: 1861, Average Score: 260.75
# Environment solved in 1761 episodes! Average Score: 260.75
# Episode: 1862, Average Score: 261.55
# Environment solved in 1762 episodes! Average Score: 261.55
# Episode: 1863, Average Score: 261.52
# Environment solved in 1763 episodes! Average Score: 261.52
# Episode: 1864, Average Score: 261.61
# Environment solved in 1764 episodes! Average Score: 261.61
# Episode: 1865, Average Score: 261.67
# Environment solved in 1765 episodes! Average Score: 261.67
# Episode: 1866, Average Score: 261.37
# Environment solved in 1766 episodes! Average Score: 261.37
# Episode: 1867, Average Score: 262.03
# Environment solved in 1767 episodes! Average Score: 262.03
# Episode: 1868, Average Score: 261.92
# Environment solved in 1768 episodes! Average Score: 261.92
# Episode: 1869, Average Score: 262.16
# Environment solved in 1769 episodes! Average Score: 262.16
# Episode: 1870, Average Score: 261.97
# Environment solved in 1770 episodes! Average Score: 261.97
# Episode: 1871, Average Score: 261.57
# Environment solved in 1771 episodes! Average Score: 261.57
# Episode: 1872, Average Score: 261.61
# Environment solved in 1772 episodes! Average Score: 261.61
# Episode: 1873, Average Score: 261.82
# Environment solved in 1773 episodes! Average Score: 261.82
# Episode: 1874, Average Score: 262.09
# Environment solved in 1774 episodes! Average Score: 262.09
# Episode: 1875, Average Score: 261.67
# Environment solved in 1775 episodes! Average Score: 261.67
# Episode: 1876, Average Score: 261.78
# Environment solved in 1776 episodes! Average Score: 261.78
# Episode: 1877, Average Score: 262.33
# Environment solved in 1777 episodes! Average Score: 262.33
# Episode: 1878, Average Score: 262.26
# Environment solved in 1778 episodes! Average Score: 262.26
# Episode: 1879, Average Score: 262.06
# Environment solved in 1779 episodes! Average Score: 262.06
# Episode: 1880, Average Score: 262.21
# Environment solved in 1780 episodes! Average Score: 262.21
# Episode: 1881, Average Score: 262.37
# Environment solved in 1781 episodes! Average Score: 262.37
# Episode: 1882, Average Score: 262.24
# Environment solved in 1782 episodes! Average Score: 262.24
# Episode: 1883, Average Score: 262.63
# Environment solved in 1783 episodes! Average Score: 262.63
# Episode: 1884, Average Score: 262.43
# Environment solved in 1784 episodes! Average Score: 262.43
# Episode: 1885, Average Score: 262.99
# Environment solved in 1785 episodes! Average Score: 262.99
# Episode: 1886, Average Score: 263.41
# Environment solved in 1786 episodes! Average Score: 263.41
# Episode: 1887, Average Score: 263.47
# Environment solved in 1787 episodes! Average Score: 263.47
# Episode: 1888, Average Score: 263.49
# Environment solved in 1788 episodes! Average Score: 263.49
# Episode: 1889, Average Score: 263.36
# Environment solved in 1789 episodes! Average Score: 263.36
# Episode: 1890, Average Score: 263.49
# Environment solved in 1790 episodes! Average Score: 263.49
# Episode: 1891, Average Score: 263.64
# Environment solved in 1791 episodes! Average Score: 263.64
# Episode: 1892, Average Score: 263.92
# Environment solved in 1792 episodes! Average Score: 263.92
# Episode: 1893, Average Score: 264.12
# Environment solved in 1793 episodes! Average Score: 264.12
# Episode: 1894, Average Score: 264.38
# Environment solved in 1794 episodes! Average Score: 264.38
# Episode: 1895, Average Score: 264.34
# Environment solved in 1795 episodes! Average Score: 264.34
# Episode: 1896, Average Score: 262.66
# Environment solved in 1796 episodes! Average Score: 262.66
# Episode: 1897, Average Score: 262.83
# Environment solved in 1797 episodes! Average Score: 262.83
# Episode: 1898, Average Score: 262.47
# Environment solved in 1798 episodes! Average Score: 262.47
# Episode: 1899, Average Score: 262.50
# Environment solved in 1799 episodes! Average Score: 262.50
# Episode: 1900, Average Score: 262.15
#
# Environment solved in 1800 episodes! Average Score: 262.15
# Episode: 1901, Average Score: 262.15
# Environment solved in 1801 episodes! Average Score: 262.15
# Episode: 1902, Average Score: 261.82
# Environment solved in 1802 episodes! Average Score: 261.82
# Episode: 1903, Average Score: 262.08
# Environment solved in 1803 episodes! Average Score: 262.08
# Episode: 1904, Average Score: 262.29
# Environment solved in 1804 episodes! Average Score: 262.29
# Episode: 1905, Average Score: 262.75
# Environment solved in 1805 episodes! Average Score: 262.75
# Episode: 1906, Average Score: 262.66
# Environment solved in 1806 episodes! Average Score: 262.66
# Episode: 1907, Average Score: 262.52
# Environment solved in 1807 episodes! Average Score: 262.52
# Episode: 1908, Average Score: 262.54
# Environment solved in 1808 episodes! Average Score: 262.54
# Episode: 1909, Average Score: 263.06
# Environment solved in 1809 episodes! Average Score: 263.06
# Episode: 1910, Average Score: 262.73
# Environment solved in 1810 episodes! Average Score: 262.73
# Episode: 1911, Average Score: 262.75
# Environment solved in 1811 episodes! Average Score: 262.75
# Episode: 1912, Average Score: 263.03
# Environment solved in 1812 episodes! Average Score: 263.03
# Episode: 1913, Average Score: 263.11
# Environment solved in 1813 episodes! Average Score: 263.11
# Episode: 1914, Average Score: 263.12
# Environment solved in 1814 episodes! Average Score: 263.12
# Episode: 1915, Average Score: 263.00
# Environment solved in 1815 episodes! Average Score: 263.00
# Episode: 1916, Average Score: 262.59
# Environment solved in 1816 episodes! Average Score: 262.59
# Episode: 1917, Average Score: 262.72
# Environment solved in 1817 episodes! Average Score: 262.72
# Episode: 1918, Average Score: 262.62
# Environment solved in 1818 episodes! Average Score: 262.62
# Episode: 1919, Average Score: 262.54
# Environment solved in 1819 episodes! Average Score: 262.54
# Episode: 1920, Average Score: 262.10
# Environment solved in 1820 episodes! Average Score: 262.10
# Episode: 1921, Average Score: 262.09
# Environment solved in 1821 episodes! Average Score: 262.09
# Episode: 1922, Average Score: 262.51
# Environment solved in 1822 episodes! Average Score: 262.51
# Episode: 1923, Average Score: 262.06
# Environment solved in 1823 episodes! Average Score: 262.06
# Episode: 1924, Average Score: 261.97
# Environment solved in 1824 episodes! Average Score: 261.97
# Episode: 1925, Average Score: 261.96
# Environment solved in 1825 episodes! Average Score: 261.96
# Episode: 1926, Average Score: 261.58
# Environment solved in 1826 episodes! Average Score: 261.58
# Episode: 1927, Average Score: 261.24
# Environment solved in 1827 episodes! Average Score: 261.24
# Episode: 1928, Average Score: 261.42
# Environment solved in 1828 episodes! Average Score: 261.42
# Episode: 1929, Average Score: 261.46
# Environment solved in 1829 episodes! Average Score: 261.46
# Episode: 1930, Average Score: 262.04
# Environment solved in 1830 episodes! Average Score: 262.04
# Episode: 1931, Average Score: 262.27
# Environment solved in 1831 episodes! Average Score: 262.27
# Episode: 1932, Average Score: 261.99
# Environment solved in 1832 episodes! Average Score: 261.99
# Episode: 1933, Average Score: 262.04
# Environment solved in 1833 episodes! Average Score: 262.04
# Episode: 1934, Average Score: 262.06
# Environment solved in 1834 episodes! Average Score: 262.06
# Episode: 1935, Average Score: 262.32
# Environment solved in 1835 episodes! Average Score: 262.32
# Episode: 1936, Average Score: 262.34
# Environment solved in 1836 episodes! Average Score: 262.34
# Episode: 1937, Average Score: 262.36
# Environment solved in 1837 episodes! Average Score: 262.36
# Episode: 1938, Average Score: 261.92
# Environment solved in 1838 episodes! Average Score: 261.92
# Episode: 1939, Average Score: 262.00
# Environment solved in 1839 episodes! Average Score: 262.00
# Episode: 1940, Average Score: 261.98
# Environment solved in 1840 episodes! Average Score: 261.98
# Episode: 1941, Average Score: 261.92
# Environment solved in 1841 episodes! Average Score: 261.92
# Episode: 1942, Average Score: 260.64
# Environment solved in 1842 episodes! Average Score: 260.64
# Episode: 1943, Average Score: 261.21
# Environment solved in 1843 episodes! Average Score: 261.21
# Episode: 1944, Average Score: 261.22
# Environment solved in 1844 episodes! Average Score: 261.22
# Episode: 1945, Average Score: 261.07
# Environment solved in 1845 episodes! Average Score: 261.07
# Episode: 1946, Average Score: 260.70
# Environment solved in 1846 episodes! Average Score: 260.70
# Episode: 1947, Average Score: 260.46
# Environment solved in 1847 episodes! Average Score: 260.46
# Episode: 1948, Average Score: 260.17
# Environment solved in 1848 episodes! Average Score: 260.17
# Episode: 1949, Average Score: 260.07
# Environment solved in 1849 episodes! Average Score: 260.07
# Episode: 1950, Average Score: 259.99
# Environment solved in 1850 episodes! Average Score: 259.99
# Episode: 1951, Average Score: 260.31
# Environment solved in 1851 episodes! Average Score: 260.31
# Episode: 1952, Average Score: 260.07
# Environment solved in 1852 episodes! Average Score: 260.07
# Episode: 1953, Average Score: 259.90
# Environment solved in 1853 episodes! Average Score: 259.90
# Episode: 1954, Average Score: 260.31
# Environment solved in 1854 episodes! Average Score: 260.31
# Episode: 1955, Average Score: 260.18
# Environment solved in 1855 episodes! Average Score: 260.18
# Episode: 1956, Average Score: 259.76
# Environment solved in 1856 episodes! Average Score: 259.76
# Episode: 1957, Average Score: 259.73
# Environment solved in 1857 episodes! Average Score: 259.73
# Episode: 1958, Average Score: 259.86
# Environment solved in 1858 episodes! Average Score: 259.86
# Episode: 1959, Average Score: 259.92
# Environment solved in 1859 episodes! Average Score: 259.92
# Episode: 1960, Average Score: 260.17
# Environment solved in 1860 episodes! Average Score: 260.17
# Episode: 1961, Average Score: 257.79
# Environment solved in 1861 episodes! Average Score: 257.79
# Episode: 1962, Average Score: 257.84
# Environment solved in 1862 episodes! Average Score: 257.84
# Episode: 1963, Average Score: 257.98
# Environment solved in 1863 episodes! Average Score: 257.98
# Episode: 1964, Average Score: 258.11
# Environment solved in 1864 episodes! Average Score: 258.11
# Episode: 1965, Average Score: 258.29
# Environment solved in 1865 episodes! Average Score: 258.29
# Episode: 1966, Average Score: 258.40
# Environment solved in 1866 episodes! Average Score: 258.40
# Episode: 1967, Average Score: 258.23
# Environment solved in 1867 episodes! Average Score: 258.23
# Episode: 1968, Average Score: 258.25
# Environment solved in 1868 episodes! Average Score: 258.25
# Episode: 1969, Average Score: 258.26
# Environment solved in 1869 episodes! Average Score: 258.26
# Episode: 1970, Average Score: 258.31
# Environment solved in 1870 episodes! Average Score: 258.31
# Episode: 1971, Average Score: 258.03
# Environment solved in 1871 episodes! Average Score: 258.03
# Episode: 1972, Average Score: 257.98
# Environment solved in 1872 episodes! Average Score: 257.98
# Episode: 1973, Average Score: 257.92
# Environment solved in 1873 episodes! Average Score: 257.92
# Episode: 1974, Average Score: 257.90
# Environment solved in 1874 episodes! Average Score: 257.90
# Episode: 1975, Average Score: 257.87
# Environment solved in 1875 episodes! Average Score: 257.87
# Episode: 1976, Average Score: 257.48
# Environment solved in 1876 episodes! Average Score: 257.48
# Episode: 1977, Average Score: 256.98
# Environment solved in 1877 episodes! Average Score: 256.98
# Episode: 1978, Average Score: 257.14
# Environment solved in 1878 episodes! Average Score: 257.14
# Episode: 1979, Average Score: 257.39
# Environment solved in 1879 episodes! Average Score: 257.39
# Episode: 1980, Average Score: 256.98
# Environment solved in 1880 episodes! Average Score: 256.98
# Episode: 1981, Average Score: 256.74
# Environment solved in 1881 episodes! Average Score: 256.74
# Episode: 1982, Average Score: 256.90
# Environment solved in 1882 episodes! Average Score: 256.90
# Episode: 1983, Average Score: 256.64
# Environment solved in 1883 episodes! Average Score: 256.64
# Episode: 1984, Average Score: 256.78
# Environment solved in 1884 episodes! Average Score: 256.78
# Episode: 1985, Average Score: 256.80
# Environment solved in 1885 episodes! Average Score: 256.80
# Episode: 1986, Average Score: 256.87
# Environment solved in 1886 episodes! Average Score: 256.87
# Episode: 1987, Average Score: 256.82
# Environment solved in 1887 episodes! Average Score: 256.82
# Episode: 1988, Average Score: 256.99
# Environment solved in 1888 episodes! Average Score: 256.99
# Episode: 1989, Average Score: 257.05
# Environment solved in 1889 episodes! Average Score: 257.05
# Episode: 1990, Average Score: 256.81
# Environment solved in 1890 episodes! Average Score: 256.81
# Episode: 1991, Average Score: 256.95
# Environment solved in 1891 episodes! Average Score: 256.95
# Episode: 1992, Average Score: 256.60
# Environment solved in 1892 episodes! Average Score: 256.60
# Episode: 1993, Average Score: 256.30
# Environment solved in 1893 episodes! Average Score: 256.30
# Episode: 1994, Average Score: 255.69
# Environment solved in 1894 episodes! Average Score: 255.69
# Episode: 1995, Average Score: 255.91
# Environment solved in 1895 episodes! Average Score: 255.91
# Episode: 1996, Average Score: 258.20
# Environment solved in 1896 episodes! Average Score: 258.20
# Episode: 1997, Average Score: 258.11
# Environment solved in 1897 episodes! Average Score: 258.11
# Episode: 1998, Average Score: 258.20
# Environment solved in 1898 episodes! Average Score: 258.20
# Episode: 1999, Average Score: 258.10
# Environment solved in 1899 episodes! Average Score: 258.10
# Episode: 2000, Average Score: 258.42
#
# Environment solved in 1900 episodes! Average Score: 258.42
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_agent_evaluation.png')
plt.show()

# %% [markdown]
# ## 🎬 Watch The Smart Agent

# %%
# load the weights of smart agent
agent.dqn_net.load_state_dict(torch.load(f'./agents/Double_DQN_{ENV_NAME}.pth'));

# %%
num_of_episodes = 20

for i_episode in range(1, num_of_episodes+1):
    
    state = env.reset()
    for time_step in range(200):
        
        # select an action
        action = agent.act(state)
        env.render()
        
        next_state, reward, done, _ = env.step(action)
        state = next_state
        if done:
            break

env.close()

# %% [markdown]
# ---
