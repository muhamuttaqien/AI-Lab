# %% [markdown]
# # Noisy DQN, Deep Q Learning

# %%
import os
import math
import random
import numpy as np
import matplotlib.pyplot as plt

from collections import namedtuple, deque

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.nn.functional as F
import torchvision.transforms as T

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3 # for soft update of target parameters
LR = 5e-4
PRINT_EVERY = 100
UPDATE_EVERY = 4

# %% [markdown]
# ## Set Environment

# %%
ENV_NAME = 'CartPole-v0'
env = gym.make(ENV_NAME).unwrapped; env.seed(90);

# %%
print('Environment Display:')
env.reset() # reset environment to a new, random state
env.render()

print('State space {}'.format(env.observation_space))
print('Action space {}'.format(env.action_space))
# Out:
# Environment Display:
# State space Box(4,)
# Action space Discrete(2)

# %% [markdown]
# ## Build Noisy Network

# %%
class NoisyLinear(nn.Module):
    
    def __init__(self, input_features, output_features, sigma_init=0.4, train_mode=True):
        
        super(NoisyLinear, self).__init__()
        
        self.input_features = input_features
        self.output_features = output_features
        self.sigma_init = sigma_init
        self.train_mode = train_mode
        
        self.mu_weight = nn.Parameter(torch.FloatTensor(output_features, input_features))
        self.sigma_weight = nn.Parameter(torch.FloatTensor(output_features, input_features))
        self.register_buffer('epsilon_weight', torch.FloatTensor(output_features, input_features))
        
        self.mu_bias = nn.Parameter(torch.FloatTensor(output_features))
        self.sigma_bias = nn.Parameter(torch.FloatTensor(output_features))
        self.register_buffer('epsilon_bias', torch.FloatTensor(output_features))
        
        self.reset_parameters()
        self.reset_noise()
        
    def reset_parameters(self):
        
        mu_range = 1 / math.sqrt(self.mu_weight.size(1))
        
        self.mu_weight.data.uniform_(-mu_range, mu_range)
        self.sigma_weight.data.fill_(self.sigma_init / math.sqrt(self.sigma_weight.size(1)))
        
        self.mu_bias.data.uniform_(-mu_range, mu_range)
        self.sigma_bias.data.fill_(self.sigma_init / math.sqrt(self.sigma_bias.size(0)))
    
    def reset_noise(self):
        
        input_size = self.input_features
        epsilon_input = torch.randn(input_size)
        epsilon_input = epsilon_input.sign().mul(epsilon_input.abs().sqrt())
        
        output_size = self.output_features
        epsilon_output = torch.randn(output_size)
        epsilon_output = epsilon_output.sign().mul(epsilon_output.abs().sqrt())
        
        self.epsilon_weight.copy_(epsilon_output.ger(epsilon_input))
        self.epsilon_bias.copy_(epsilon_output)
        
    def forward(self, x):
        
        if self.train_mode:
            weight = self.mu_weight + self.sigma_weight.mul(autograd.Variable(self.epsilon_weight))
            bias = self.mu_bias + self.sigma_bias.mul(autograd.Variable(self.epsilon_bias))
        else:
            weight = self.mu_weight
            bias = self.mu_bias
            
        return F.linear(x, weight, bias)

# %% [markdown]
# ## Build DQN Architecture

# %%
class DQN(nn.Module):
    """Define DQN architecture."""
    
    def __init__(self, state_size, action_size, seed, fcl_units=64, fc2_units=64):
        """Initialize parameters and build model."""
        
        super(DQN, self).__init__()
        
        self.seed = torch.manual_seed(seed)
        
        self.fc1_layer = nn.Linear(state_size, fcl_units)
        self.noisy1_layer = NoisyLinear(fcl_units, fc2_units)
        self.noisy2_layer = NoisyLinear(fc2_units, action_size)
        
    def reset_noise(self):
        self.noisy1_layer.reset_noise()
        self.noisy2_layer.reset_noise()
        
    def forward(self, state):
        """Build a network that maps state into action values."""
        
        state = F.relu(self.fc1_layer(state))
        state = F.relu(self.noisy1_layer(state))
        Qsa = self.noisy2_layer(state)
        
        return Qsa

# %% [markdown]
# ## Set Replay Buffer

# %%
class ReplayBuffer(object):
    """Fixed-size buffer to store experience tuples."""
    
    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayMemory object."""
        
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to buffer."""
        
        self.memory.append(self.experience(state, action, reward, next_state, done))
        
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)
        
        states = torch.from_numpy(np.vstack([exp.state for exp in experiences if exp is not None])).float()
        states = states.to(device)
        
        actions = torch.from_numpy(np.vstack([exp.action for exp in experiences if exp is not None])).long()
        actions = actions.to(device)
        
        rewards = torch.from_numpy(np.vstack([exp.reward for exp in experiences if exp is not None])).float()
        rewards = rewards.to(device)
        
        next_states = torch.from_numpy(np.vstack([exp.next_state for exp in experiences if exp is not None])).float()
        next_states = next_states.to(device)
        
        dones = torch.from_numpy(np.vstack([exp.done for exp in experiences if exp is not None]).astype(np.uint8)).float()
        dones = dones.to(device)
        
        return (states, actions, rewards, next_states, dones)
        
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Define Noisy DQN Agent

# %%
class Noisy_DQNAgent():
    """The agent interacting with and learning from the environment."""
    
    def __init__(self, state_size, action_size, seed):
        """Initialize an agent object."""
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        
        # Q-Network
        self.dqn_net = DQN(state_size, action_size, seed).to(device)
        self.target_net = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.dqn_net.parameters(), lr=LR)
        
        # Replay Buffer
        self.buffer = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        self.time_step = 0
        
    def memorize(self, state, action, reward, next_state, done):
        """Save experience in replay buffer."""
        
        self.buffer.add(state, action, reward, next_state, done)
    
        self.time_step = (self.time_step + 1) % UPDATE_EVERY
        if self.time_step == 0:
            # if enough samples are available in memory, get random subset and learn
            if len(self.buffer) > BATCH_SIZE:
                experiences = self.buffer.sample()
                self.learn(experiences, GAMMA)
            
    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.dqn_net.eval()
        with torch.no_grad():
            action_values = self.dqn_net(state)
        self.dqn_net.train()
        
        # epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
    
    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples."""
    
        states, actions, rewards, next_states, dones = experiences
        
        self.optimizer.zero_grad()
        
        # get index of maximum value for next state
        Qsa_next = self.dqn_net(next_states).detach()
        _, action_max = Qsa_next.max(1)

        # get max predicted Q values (for next states) from target network
        Q_target_next = self.target_net(next_states).detach().gather(1, action_max.unsqueeze(1))
        
        # compute Q target
        Q_target = rewards + (gamma * Q_target_next * (1 - dones))
        
        # get expected Q values from dqn network
        Q_expected = self.dqn_net(states).gather(1, actions)
        
        # compute loss
        loss = F.mse_loss(Q_expected, Q_target)
        
        # minimize the loss
        loss.backward()
        self.optimizer.step()
        
        # update target network
        self.soft_update(self.dqn_net, self.target_net, TAU)
        
    def soft_update(self, dqn_net, target_net, tau):
        """Soft update target network parameters."""
        
        for dqn_param, target_param in zip(dqn_net.parameters(), target_net.parameters()):
            target_param.data.copy_(tau*dqn_param.data + (1.0-tau) * target_param.data)

# %%
agent = Noisy_DQNAgent(state_size=env.observation_space.shape[0], action_size=env.action_space.n, seed=90)

# %%
# watch an untrained agent
state = env.reset()
for time_step in range(200):
    
    # select an action
    action = agent.act(state)
    env.render()
    
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes, max_time=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Train DQN agent."""
    
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    
    for i_episode in range(1, num_episodes+1):
        state = env.reset()
        score = 0
        for time_step in range(max_time):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
                
        scores_window.append(score)
        scores.append(score)
        eps = max(eps_end, eps_decay*eps)
        
        print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}', end='')
        
        if i_episode % PRINT_EVERY == 0:
            print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}')
        if np.mean(scores_window) >= 100.0:
            print(f'\nEnvironment solved in {i_episode-100:d} episodes! Average Score: {np.mean(scores_window):.2f}')
            if not os.path.exists('./agents/'): os.makedirs('./agents/')
            torch.save(agent.dqn_net.state_dict(), f'./agents/Noisy_DQN_with_EGP_{ENV_NAME}.pth')
            
    print('Training completed.')
    return scores

# %%
scores = train_agent(num_episodes=1000, max_time=1000)
# Out:
# Episode: 100, Average Score: 20.81
# Episode: 200, Average Score: 15.63
# Episode: 300, Average Score: 12.76
# Episode: 400, Average Score: 11.65
# Episode: 500, Average Score: 11.11
# Episode: 600, Average Score: 14.33
# Episode: 700, Average Score: 15.25
# Episode: 800, Average Score: 44.39
# Episode: 838, Average Score: 100.17
# Environment solved in 738 episodes! Average Score: 100.17
# Episode: 839, Average Score: 101.98
# Environment solved in 739 episodes! Average Score: 101.98
# Episode: 840, Average Score: 103.42
# Environment solved in 740 episodes! Average Score: 103.42
# Episode: 841, Average Score: 104.81
# Environment solved in 741 episodes! Average Score: 104.81
# Episode: 842, Average Score: 106.50
# Environment solved in 742 episodes! Average Score: 106.50
# Episode: 843, Average Score: 108.91
# Environment solved in 743 episodes! Average Score: 108.91
# Episode: 844, Average Score: 110.56
# Environment solved in 744 episodes! Average Score: 110.56
# Episode: 845, Average Score: 112.06
# Environment solved in 745 episodes! Average Score: 112.06
# Episode: 846, Average Score: 113.65
# Environment solved in 746 episodes! Average Score: 113.65
# Episode: 847, Average Score: 115.15
# Environment solved in 747 episodes! Average Score: 115.15
# Episode: 848, Average Score: 116.62
# Environment solved in 748 episodes! Average Score: 116.62
# Episode: 849, Average Score: 118.86
# Environment solved in 749 episodes! Average Score: 118.86
# Episode: 850, Average Score: 120.60
# Environment solved in 750 episodes! Average Score: 120.60
# Episode: 851, Average Score: 121.90
# Environment solved in 751 episodes! Average Score: 121.90
# Episode: 852, Average Score: 123.22
# Environment solved in 752 episodes! Average Score: 123.22
# Episode: 853, Average Score: 123.91
# Environment solved in 753 episodes! Average Score: 123.91
# Episode: 854, Average Score: 125.97
# Environment solved in 754 episodes! Average Score: 125.97
# Episode: 855, Average Score: 127.48
# Environment solved in 755 episodes! Average Score: 127.48
# Episode: 856, Average Score: 128.66
# Environment solved in 756 episodes! Average Score: 128.66
# Episode: 857, Average Score: 129.94
# Environment solved in 757 episodes! Average Score: 129.94
# Episode: 858, Average Score: 131.37
# Environment solved in 758 episodes! Average Score: 131.37
# Episode: 859, Average Score: 132.95
# Environment solved in 759 episodes! Average Score: 132.95
# Episode: 860, Average Score: 134.45
# Environment solved in 760 episodes! Average Score: 134.45
# Episode: 861, Average Score: 136.00
# Environment solved in 761 episodes! Average Score: 136.00
# Episode: 862, Average Score: 136.97
# Environment solved in 762 episodes! Average Score: 136.97
# Episode: 863, Average Score: 138.27
# Environment solved in 763 episodes! Average Score: 138.27
# Episode: 864, Average Score: 139.10
# Environment solved in 764 episodes! Average Score: 139.10
# Episode: 865, Average Score: 140.15
# Environment solved in 765 episodes! Average Score: 140.15
# Episode: 866, Average Score: 141.75
# Environment solved in 766 episodes! Average Score: 141.75
# Episode: 867, Average Score: 143.79
# Environment solved in 767 episodes! Average Score: 143.79
# Episode: 868, Average Score: 144.88
# Environment solved in 768 episodes! Average Score: 144.88
# Episode: 869, Average Score: 146.77
# Environment solved in 769 episodes! Average Score: 146.77
# Episode: 870, Average Score: 148.76
# Environment solved in 770 episodes! Average Score: 148.76
# Episode: 871, Average Score: 150.96
# Environment solved in 771 episodes! Average Score: 150.96
# Episode: 872, Average Score: 152.31
# Environment solved in 772 episodes! Average Score: 152.31
# Episode: 873, Average Score: 153.99
# Environment solved in 773 episodes! Average Score: 153.99
# Episode: 874, Average Score: 155.55
# Environment solved in 774 episodes! Average Score: 155.55
# Episode: 875, Average Score: 157.12
# Environment solved in 775 episodes! Average Score: 157.12
# Episode: 876, Average Score: 158.34
# Environment solved in 776 episodes! Average Score: 158.34
# Episode: 877, Average Score: 159.33
# Environment solved in 777 episodes! Average Score: 159.33
# Episode: 878, Average Score: 161.27
# Environment solved in 778 episodes! Average Score: 161.27
# Episode: 879, Average Score: 162.40
# Environment solved in 779 episodes! Average Score: 162.40
# Episode: 880, Average Score: 163.80
# Environment solved in 780 episodes! Average Score: 163.80
# Episode: 881, Average Score: 165.53
# Environment solved in 781 episodes! Average Score: 165.53
# Episode: 882, Average Score: 165.03
# Environment solved in 782 episodes! Average Score: 165.03
# Episode: 883, Average Score: 167.66
# Environment solved in 783 episodes! Average Score: 167.66
# Episode: 884, Average Score: 168.71
# Environment solved in 784 episodes! Average Score: 168.71
# Episode: 885, Average Score: 170.50
# Environment solved in 785 episodes! Average Score: 170.50
# Episode: 886, Average Score: 172.08
# Environment solved in 786 episodes! Average Score: 172.08
# Episode: 887, Average Score: 174.19
# Environment solved in 787 episodes! Average Score: 174.19
# Episode: 888, Average Score: 175.83
# Environment solved in 788 episodes! Average Score: 175.83
# Episode: 889, Average Score: 177.29
# Environment solved in 789 episodes! Average Score: 177.29
# Episode: 890, Average Score: 177.80
# Environment solved in 790 episodes! Average Score: 177.80
# Episode: 891, Average Score: 179.22
# Environment solved in 791 episodes! Average Score: 179.22
# Episode: 892, Average Score: 180.27
# Environment solved in 792 episodes! Average Score: 180.27
# Episode: 893, Average Score: 181.41
# Environment solved in 793 episodes! Average Score: 181.41
# Episode: 894, Average Score: 183.21
# Environment solved in 794 episodes! Average Score: 183.21
# Episode: 895, Average Score: 184.98
# Environment solved in 795 episodes! Average Score: 184.98
# Episode: 896, Average Score: 185.96
# Environment solved in 796 episodes! Average Score: 185.96
# Episode: 897, Average Score: 187.76
# Environment solved in 797 episodes! Average Score: 187.76
# Episode: 898, Average Score: 189.00
# Environment solved in 798 episodes! Average Score: 189.00
# Episode: 899, Average Score: 192.56
# Environment solved in 799 episodes! Average Score: 192.56
# Episode: 900, Average Score: 193.85
#
# Environment solved in 800 episodes! Average Score: 193.85
# Episode: 901, Average Score: 194.94
# Environment solved in 801 episodes! Average Score: 194.94
# Episode: 902, Average Score: 196.85
# Environment solved in 802 episodes! Average Score: 196.85
# Episode: 903, Average Score: 197.54
# Environment solved in 803 episodes! Average Score: 197.54
# Episode: 904, Average Score: 198.12
# Environment solved in 804 episodes! Average Score: 198.12
# Episode: 905, Average Score: 199.33
# Environment solved in 805 episodes! Average Score: 199.33
# Episode: 906, Average Score: 201.22
# Environment solved in 806 episodes! Average Score: 201.22
# Episode: 907, Average Score: 201.29
# Environment solved in 807 episodes! Average Score: 201.29
# Episode: 908, Average Score: 202.81
# Environment solved in 808 episodes! Average Score: 202.81
# Episode: 909, Average Score: 202.98
# Environment solved in 809 episodes! Average Score: 202.98
# Episode: 910, Average Score: 203.85
# Environment solved in 810 episodes! Average Score: 203.85
# Episode: 911, Average Score: 206.36
# Environment solved in 811 episodes! Average Score: 206.36
# Episode: 912, Average Score: 207.49
# Environment solved in 812 episodes! Average Score: 207.49
# Episode: 913, Average Score: 209.33
# Environment solved in 813 episodes! Average Score: 209.33
# Episode: 914, Average Score: 208.82
# Environment solved in 814 episodes! Average Score: 208.82
# Episode: 915, Average Score: 210.71
# Environment solved in 815 episodes! Average Score: 210.71
# Episode: 916, Average Score: 210.89
# Environment solved in 816 episodes! Average Score: 210.89
# Episode: 917, Average Score: 211.26
# Environment solved in 817 episodes! Average Score: 211.26
# Episode: 918, Average Score: 212.85
# Environment solved in 818 episodes! Average Score: 212.85
# Episode: 919, Average Score: 213.62
# Environment solved in 819 episodes! Average Score: 213.62
# Episode: 920, Average Score: 215.08
# Environment solved in 820 episodes! Average Score: 215.08
# Episode: 921, Average Score: 215.72
# Environment solved in 821 episodes! Average Score: 215.72
# Episode: 922, Average Score: 215.66
# Environment solved in 822 episodes! Average Score: 215.66
# Episode: 923, Average Score: 215.65
# Environment solved in 823 episodes! Average Score: 215.65
# Episode: 924, Average Score: 215.62
# Environment solved in 824 episodes! Average Score: 215.62
# Episode: 925, Average Score: 216.44
# Environment solved in 825 episodes! Average Score: 216.44
# Episode: 926, Average Score: 217.52
# Environment solved in 826 episodes! Average Score: 217.52
# Episode: 927, Average Score: 217.81
# Environment solved in 827 episodes! Average Score: 217.81
# Episode: 928, Average Score: 218.39
# Environment solved in 828 episodes! Average Score: 218.39
# Episode: 929, Average Score: 219.12
# Environment solved in 829 episodes! Average Score: 219.12
# Episode: 930, Average Score: 222.11
# Environment solved in 830 episodes! Average Score: 222.11
# Episode: 931, Average Score: 222.06
# Environment solved in 831 episodes! Average Score: 222.06
# Episode: 932, Average Score: 222.84
# Environment solved in 832 episodes! Average Score: 222.84
# Episode: 933, Average Score: 222.75
# Environment solved in 833 episodes! Average Score: 222.75
# Episode: 934, Average Score: 222.94
# Environment solved in 834 episodes! Average Score: 222.94
# Episode: 935, Average Score: 223.22
# Environment solved in 835 episodes! Average Score: 223.22
# Episode: 936, Average Score: 223.88
# Environment solved in 836 episodes! Average Score: 223.88
# Episode: 937, Average Score: 224.68
# Environment solved in 837 episodes! Average Score: 224.68
# Episode: 938, Average Score: 224.24
# Environment solved in 838 episodes! Average Score: 224.24
# Episode: 939, Average Score: 224.80
# Environment solved in 839 episodes! Average Score: 224.80
# Episode: 940, Average Score: 225.33
# Environment solved in 840 episodes! Average Score: 225.33
# Episode: 941, Average Score: 228.16
# Environment solved in 841 episodes! Average Score: 228.16
# Episode: 942, Average Score: 229.79
# Environment solved in 842 episodes! Average Score: 229.79
# Episode: 943, Average Score: 229.73
# Environment solved in 843 episodes! Average Score: 229.73
# Episode: 944, Average Score: 229.80
# Environment solved in 844 episodes! Average Score: 229.80
# Episode: 945, Average Score: 231.93
# Environment solved in 845 episodes! Average Score: 231.93
# Episode: 946, Average Score: 233.66
# Environment solved in 846 episodes! Average Score: 233.66
# Episode: 947, Average Score: 236.19
# Environment solved in 847 episodes! Average Score: 236.19
# Episode: 948, Average Score: 237.06
# Environment solved in 848 episodes! Average Score: 237.06
# Episode: 949, Average Score: 237.98
# Environment solved in 849 episodes! Average Score: 237.98
# Episode: 950, Average Score: 238.75
# Environment solved in 850 episodes! Average Score: 238.75
# Episode: 951, Average Score: 239.25
# Environment solved in 851 episodes! Average Score: 239.25
# Episode: 952, Average Score: 240.28
# Environment solved in 852 episodes! Average Score: 240.28
# Episode: 953, Average Score: 241.17
# Environment solved in 853 episodes! Average Score: 241.17
# Episode: 954, Average Score: 241.01
# Environment solved in 854 episodes! Average Score: 241.01
# Episode: 955, Average Score: 242.42
# Environment solved in 855 episodes! Average Score: 242.42
# Episode: 956, Average Score: 242.41
# Environment solved in 856 episodes! Average Score: 242.41
# Episode: 957, Average Score: 243.34
# Environment solved in 857 episodes! Average Score: 243.34
# Episode: 958, Average Score: 244.65
# Environment solved in 858 episodes! Average Score: 244.65
# Episode: 959, Average Score: 245.16
# Environment solved in 859 episodes! Average Score: 245.16
# Episode: 960, Average Score: 245.70
# Environment solved in 860 episodes! Average Score: 245.70
# Episode: 961, Average Score: 246.06
# Environment solved in 861 episodes! Average Score: 246.06
# Episode: 962, Average Score: 246.07
# Environment solved in 862 episodes! Average Score: 246.07
# Episode: 963, Average Score: 246.02
# Environment solved in 863 episodes! Average Score: 246.02
# Episode: 964, Average Score: 246.65
# Environment solved in 864 episodes! Average Score: 246.65
# Episode: 965, Average Score: 246.76
# Environment solved in 865 episodes! Average Score: 246.76
# Episode: 966, Average Score: 246.86
# Environment solved in 866 episodes! Average Score: 246.86
# Episode: 967, Average Score: 246.61
# Environment solved in 867 episodes! Average Score: 246.61
# Episode: 968, Average Score: 247.62
# Environment solved in 868 episodes! Average Score: 247.62
# Episode: 969, Average Score: 247.58
# Environment solved in 869 episodes! Average Score: 247.58
# Episode: 970, Average Score: 247.34
# Environment solved in 870 episodes! Average Score: 247.34
# Episode: 971, Average Score: 246.54
# Environment solved in 871 episodes! Average Score: 246.54
# Episode: 972, Average Score: 247.55
# Environment solved in 872 episodes! Average Score: 247.55
# Episode: 973, Average Score: 247.37
# Environment solved in 873 episodes! Average Score: 247.37
# Episode: 974, Average Score: 247.72
# Environment solved in 874 episodes! Average Score: 247.72
# Episode: 975, Average Score: 248.64
# Environment solved in 875 episodes! Average Score: 248.64
# Episode: 976, Average Score: 248.21
# Environment solved in 876 episodes! Average Score: 248.21
# Episode: 977, Average Score: 248.20
# Environment solved in 877 episodes! Average Score: 248.20
# Episode: 978, Average Score: 247.89
# Environment solved in 878 episodes! Average Score: 247.89
# Episode: 979, Average Score: 247.74
# Environment solved in 879 episodes! Average Score: 247.74
# Episode: 980, Average Score: 247.65
# Environment solved in 880 episodes! Average Score: 247.65
# Episode: 981, Average Score: 247.45
# Environment solved in 881 episodes! Average Score: 247.45
# Episode: 982, Average Score: 247.84
# Environment solved in 882 episodes! Average Score: 247.84
# Episode: 983, Average Score: 246.21
# Environment solved in 883 episodes! Average Score: 246.21
# Episode: 984, Average Score: 246.90
# Environment solved in 884 episodes! Average Score: 246.90
# Episode: 985, Average Score: 247.27
# Environment solved in 885 episodes! Average Score: 247.27
# Episode: 986, Average Score: 247.60
# Environment solved in 886 episodes! Average Score: 247.60
# Episode: 987, Average Score: 247.01
# Environment solved in 887 episodes! Average Score: 247.01
# Episode: 988, Average Score: 246.79
# Environment solved in 888 episodes! Average Score: 246.79
# Episode: 989, Average Score: 246.83
# Environment solved in 889 episodes! Average Score: 246.83
# Episode: 990, Average Score: 248.15
# Environment solved in 890 episodes! Average Score: 248.15
# Episode: 991, Average Score: 248.71
# Environment solved in 891 episodes! Average Score: 248.71
# Episode: 992, Average Score: 249.90
# Environment solved in 892 episodes! Average Score: 249.90
# Episode: 993, Average Score: 249.84
# Environment solved in 893 episodes! Average Score: 249.84
# Episode: 994, Average Score: 249.60
# Environment solved in 894 episodes! Average Score: 249.60
# Episode: 995, Average Score: 249.22
# Environment solved in 895 episodes! Average Score: 249.22
# Episode: 996, Average Score: 249.40
# Environment solved in 896 episodes! Average Score: 249.40
# Episode: 997, Average Score: 248.61
# Environment solved in 897 episodes! Average Score: 248.61
# Episode: 998, Average Score: 248.59
# Environment solved in 898 episodes! Average Score: 248.59
# Episode: 999, Average Score: 246.09
# Environment solved in 899 episodes! Average Score: 246.09
# Episode: 1000, Average Score: 246.15
#
# Environment solved in 900 episodes! Average Score: 246.15
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_agent_evaluation.png')
plt.show()

# %% [markdown]
# ## Watch The Smart Agent

# %%
# load the weights of smart agent
agent.dqn_net.load_state_dict(torch.load(f'./agents/Noisy_DQN_with_EGP_{ENV_NAME}.pth'));

# %%
num_of_episodes = 20

for i_episode in range(1, num_of_episodes+1):
    
    state = env.reset()
    for time_step in range(200):
        
        # select an action
        action = agent.act(state)
        env.render()
        
        next_state, reward, done, _ = env.step(action)
        state = next_state
        if done:
            break

env.close()

# %% [markdown]
# ---
