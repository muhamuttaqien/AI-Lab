# %% [markdown]
# # Prioritized Experience Replay DQN, Deep Q Learning

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

from collections import namedtuple, deque

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

# %%
BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64
GAMMA = 0.99
TAU = 1e-3 # for soft update of target parameters
LR = 5e-4
PRINT_EVERY = 100
UPDATE_EVERY = 4

# %% [markdown]
# ## Set Environment

# %%
ENV_NAME = 'CartPole-v0'
env = gym.make(ENV_NAME).unwrapped; env.seed(90);

# %%
print('Environment Display:')
env.reset() # reset environment to a new, random state
env.render()

print('State space {}'.format(env.observation_space))
print('Action space {}'.format(env.action_space))
# Out:
# Environment Display:
# State space Box(4,)
# Action space Discrete(2)

# %% [markdown]
# ## Build DQN Architecture

# %%
class DQN(nn.Module):
    """Define DQN architecture."""
    
    def __init__(self, state_size, action_size, seed, fcl_units=64, fc2_units=64):
        """Initialize parameters and build model."""
        
        super(DQN, self).__init__()
        
        self.seed = torch.manual_seed(seed)
        
        self.fc1_layer = nn.Linear(state_size, fcl_units)
        self.fc2_layer = nn.Linear(fcl_units, fc2_units)
        self.fc3_layer = nn.Linear(fc2_units, action_size)
        
    def forward(self, state):
        """Build a network that maps state into action values."""
        
        state = F.relu(self.fc1_layer(state))
        state = F.relu(self.fc2_layer(state))
        Qsa = self.fc3_layer(state)
        
        return Qsa

# %% [markdown]
# ## Set Prioritized Replay Buffer

# %%
class PrioritizedReplayBuffer(object):
    """Fixed-size buffer to store experience tuples."""
    
    def __init__(self, capacity):
        """Initialize a PrioritizedReplayMemory object."""
        
        self.PER_e = 0.01
        self.PER_a = 0.6
        self.PER_b = 0.4
        
        self.capacity = capacity
        self.memory = []
        self.data_pointer = 0
        self.priorities = np.zeros((capacity,), dtype=np.float32)
        
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        
        state = np.expand_dims(state, axis=0)
        next_state = np.expand_dims(next_state, axis=0)
        
        max_priority = self.priorities.max() if self.memory else 1.0
        
        if len(self.memory) < self.capacity:
            self.memory.append((state, action, reward, next_state, done))
        else:
            self.memory[self.data_pointer] = (state, action, reward, next_state, done)
            
        self.priorities[self.data_pointer] = max_priority
        self.data_pointer = (self.data_pointer + 1) % self.capacity
        
    def sample(self):
        """Sample a batch of prioritized experiences from memory."""
        
        if len(self.memory) == self.capacity:
            priorities = self.priorities
        else:
            priorities = self.priorities[:self.data_pointer]
            
        probs = priorities ** self.PER_a
        probs/= probs.sum() 
        
        indices = np.random.choice(len(self.memory), BATCH_SIZE, p=probs)
        samples = [self.memory[index] for index in indices]
        
        total = len(self.memory)
        weights = (total * probs[indices]) ** (-self.PER_b)
        weights/= weights.max()
        weights = np.array(weights, dtype=np.float32)
        
        experiences = list(zip(*samples))
        
        states = torch.from_numpy(np.vstack([np.concatenate(experiences[0])])).float()
        states = states.to(device)
        
        actions = torch.from_numpy(np.vstack([np.expand_dims(experiences[1], axis=1)])).long()
        actions = actions.to(device)
        
        rewards = torch.from_numpy(np.vstack([np.expand_dims(experiences[2], axis=1)])).float()
        rewards = rewards.to(device)
        
        next_states = torch.from_numpy(np.vstack([np.concatenate(experiences[3])])).float()
        next_states = next_states.to(device)
        
        dones = torch.from_numpy(np.vstack([np.expand_dims(experiences[4], axis=1)]).astype(np.uint8)).float()
        dones = dones.to(device)
        
        weights = torch.from_numpy(np.expand_dims(weights, axis=1)).float()
        weights = weights.to(device)
        
        return indices, (states, actions, rewards, next_states, dones), weights
    
    def update_priorities(self, batch_indices, batch_priorities):
        """Update current priorities of internal memory."""
        
        for batch_id, priority in zip(batch_indices, batch_priorities):
            self.priorities[batch_id] = priority
            
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Define PER DQN Agent

# %%
class PER_DQNAgent():
    """The agent interacting with and learning from the environment."""
    
    def __init__(self, state_size, action_size, seed):
        """Initialize an agent object."""
        
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        
        # Q-Network
        self.dqn_net = DQN(state_size, action_size, seed).to(device)
        self.target_net = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.dqn_net.parameters(), lr=LR)
        
        # Replay Buffer
        self.buffer = PrioritizedReplayBuffer(BUFFER_SIZE)
        self.time_step = 0
        
    def memorize(self, state, action, reward, next_state, done):
        """Save experience in replay buffer."""
        
        self.buffer.add(state, action, reward, next_state, done)
    
        self.time_step = (self.time_step + 1) % UPDATE_EVERY
        if self.time_step == 0:
            # if enough samples are available in memory, get random subset and learn
            if len(self.buffer) > BATCH_SIZE:
                batch_indices, experiences, weights = self.buffer.sample()
                self.learn(batch_indices, experiences, weights, GAMMA)
            
    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        
        self.dqn_net.eval()
        with torch.no_grad():
            action_values = self.dqn_net(state)
            
        self.dqn_net.train()
        
        # epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
    
    def learn(self, batch_indices, experiences, weights, gamma):
        """Update value parameters using given batch of experience tuples."""
    
        states, actions, rewards, next_states, dones = experiences
        
        self.optimizer.zero_grad()
        
        # get index of maximum value for next state
        Qsa_next = self.dqn_net(next_states).detach()
        _, action_max = Qsa_next.max(1)

        # get max predicted Q values (for next states) from target network
        Q_target_next = self.target_net(next_states).detach().gather(1, action_max.unsqueeze(1))
        
        # compute Q target
        Q_target = rewards + (gamma * Q_target_next * (1 - dones))
        
        # get expected Q values from dqn network
        Q_expected = self.dqn_net(states).gather(1, actions)
        
        # compute loss using PER concept
        loss  = torch.pow((Q_expected - Q_target), 2) * weights        
        priorities = loss + self.buffer.PER_e
        
        loss  = torch.mean(loss)
        
        # minimize the loss
        loss.backward()
        self.optimizer.step()
        
        self.buffer.update_priorities(batch_indices, priorities.data.cpu().numpy())
        
        # update target network
        self.soft_update(self.dqn_net, self.target_net, TAU)
        
    def soft_update(self, dqn_net, target_net, tau):
        """Soft update target network parameters."""
        
        for dqn_param, target_param in zip(dqn_net.parameters(), target_net.parameters()):
            target_param.data.copy_(tau*dqn_param.data + (1.0-tau) * target_param.data)

# %%
agent = PER_DQNAgent(state_size=env.observation_space.shape[0], action_size=env.action_space.n, seed=90)

# %%
# watch an untrained agent
state = env.reset()
for time_step in range(200):
    
    # select an action
    action = agent.act(state)
    env.render()
    
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()

# %% [markdown]
# ## Train The Agent

# %%
def train_agent(num_episodes, max_time=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Train DQN agent."""
    
    scores = []
    scores_window = deque(maxlen=100)
    eps = eps_start
    
    for i_episode in range(1, num_episodes+1):
        state = env.reset()
        score = 0
        for time_step in range(max_time):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            
            agent.memorize(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
                
        scores_window.append(score)
        scores.append(score)
        eps = max(eps_end, eps_decay*eps)
        
        print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}', end='')
        
        if i_episode % PRINT_EVERY == 0:
            print(f'\rEpisode: {i_episode}, Average Score: {np.mean(scores_window):.2f}')
        if np.mean(scores_window) >= 100.0:
            print(f'\nEnvironment solved in {i_episode-100:d} episodes! Average Score: {np.mean(scores_window):.2f}')
            if not os.path.exists('./agents/'): os.makedirs('./agents/')
            torch.save(agent.dqn_net.state_dict(), f'./agents/PER_DQN_{ENV_NAME}.pth')
            
    print('Training completed.')
    return scores

# %%
scores = train_agent(num_episodes=1000, max_time=1000)
# Out:
# Episode: 100, Average Score: 19.74
# Episode: 200, Average Score: 12.30
# Episode: 300, Average Score: 11.64
# Episode: 400, Average Score: 10.46
# Episode: 500, Average Score: 11.27
# Episode: 600, Average Score: 13.75
# Episode: 700, Average Score: 21.95
# Episode: 761, Average Score: 101.49
# Environment solved in 661 episodes! Average Score: 101.49
# Episode: 762, Average Score: 104.54
# Environment solved in 662 episodes! Average Score: 104.54
# Episode: 763, Average Score: 108.01
# Environment solved in 663 episodes! Average Score: 108.01
# Episode: 764, Average Score: 110.96
# Environment solved in 664 episodes! Average Score: 110.96
# Episode: 765, Average Score: 113.90
# Environment solved in 665 episodes! Average Score: 113.90
# Episode: 766, Average Score: 117.76
# Environment solved in 666 episodes! Average Score: 117.76
# Episode: 767, Average Score: 121.20
# Environment solved in 667 episodes! Average Score: 121.20
# Episode: 768, Average Score: 124.49
# Environment solved in 668 episodes! Average Score: 124.49
# Episode: 769, Average Score: 127.57
# Environment solved in 669 episodes! Average Score: 127.57
# Episode: 770, Average Score: 130.61
# Environment solved in 670 episodes! Average Score: 130.61
# Episode: 771, Average Score: 135.47
# Environment solved in 671 episodes! Average Score: 135.47
# Episode: 772, Average Score: 138.87
# Environment solved in 672 episodes! Average Score: 138.87
# Episode: 773, Average Score: 141.08
# Environment solved in 673 episodes! Average Score: 141.08
# Episode: 774, Average Score: 142.83
# Environment solved in 674 episodes! Average Score: 142.83
# Episode: 775, Average Score: 145.40
# Environment solved in 675 episodes! Average Score: 145.40
# Episode: 776, Average Score: 148.05
# Environment solved in 676 episodes! Average Score: 148.05
# Episode: 777, Average Score: 151.13
# Environment solved in 677 episodes! Average Score: 151.13
# Episode: 778, Average Score: 154.30
# Environment solved in 678 episodes! Average Score: 154.30
# Episode: 779, Average Score: 157.36
# Environment solved in 679 episodes! Average Score: 157.36
# Episode: 780, Average Score: 160.50
# Environment solved in 680 episodes! Average Score: 160.50
# Episode: 781, Average Score: 162.93
# Environment solved in 681 episodes! Average Score: 162.93
# Episode: 782, Average Score: 165.29
# Environment solved in 682 episodes! Average Score: 165.29
# Episode: 783, Average Score: 167.84
# Environment solved in 683 episodes! Average Score: 167.84
# Episode: 784, Average Score: 169.05
# Environment solved in 684 episodes! Average Score: 169.05
# Episode: 785, Average Score: 171.40
# Environment solved in 685 episodes! Average Score: 171.40
# Episode: 786, Average Score: 173.47
# Environment solved in 686 episodes! Average Score: 173.47
# Episode: 787, Average Score: 175.88
# Environment solved in 687 episodes! Average Score: 175.88
# Episode: 788, Average Score: 183.99
# Environment solved in 688 episodes! Average Score: 183.99
# Episode: 789, Average Score: 186.60
# Environment solved in 689 episodes! Average Score: 186.60
# Episode: 790, Average Score: 189.02
# Environment solved in 690 episodes! Average Score: 189.02
# Episode: 791, Average Score: 192.13
# Environment solved in 691 episodes! Average Score: 192.13
# Episode: 792, Average Score: 195.02
# Environment solved in 692 episodes! Average Score: 195.02
# Episode: 793, Average Score: 197.18
# Environment solved in 693 episodes! Average Score: 197.18
# Episode: 794, Average Score: 199.81
# Environment solved in 694 episodes! Average Score: 199.81
# Episode: 795, Average Score: 202.06
# Environment solved in 695 episodes! Average Score: 202.06
# Episode: 796, Average Score: 204.48
# Environment solved in 696 episodes! Average Score: 204.48
# Episode: 797, Average Score: 206.86
# Environment solved in 697 episodes! Average Score: 206.86
# Episode: 798, Average Score: 208.88
# Environment solved in 698 episodes! Average Score: 208.88
# Episode: 799, Average Score: 211.32
# Environment solved in 699 episodes! Average Score: 211.32
# Episode: 800, Average Score: 213.23
#
# Environment solved in 700 episodes! Average Score: 213.23
# Episode: 801, Average Score: 215.36
# Environment solved in 701 episodes! Average Score: 215.36
# Episode: 802, Average Score: 218.24
# Environment solved in 702 episodes! Average Score: 218.24
# Episode: 803, Average Score: 220.46
# Environment solved in 703 episodes! Average Score: 220.46
# Episode: 804, Average Score: 222.60
# Environment solved in 704 episodes! Average Score: 222.60
# Episode: 805, Average Score: 225.02
# Environment solved in 705 episodes! Average Score: 225.02
# Episode: 806, Average Score: 226.29
# Environment solved in 706 episodes! Average Score: 226.29
# Episode: 807, Average Score: 228.31
# Environment solved in 707 episodes! Average Score: 228.31
# Episode: 808, Average Score: 231.43
# Environment solved in 708 episodes! Average Score: 231.43
# Episode: 809, Average Score: 233.35
# Environment solved in 709 episodes! Average Score: 233.35
# Episode: 810, Average Score: 235.40
# Environment solved in 710 episodes! Average Score: 235.40
# Episode: 811, Average Score: 237.56
# Environment solved in 711 episodes! Average Score: 237.56
# Episode: 812, Average Score: 240.01
# Environment solved in 712 episodes! Average Score: 240.01
# Episode: 813, Average Score: 242.31
# Environment solved in 713 episodes! Average Score: 242.31
# Episode: 814, Average Score: 244.39
# Environment solved in 714 episodes! Average Score: 244.39
# Episode: 815, Average Score: 246.49
# Environment solved in 715 episodes! Average Score: 246.49
# Episode: 816, Average Score: 247.78
# Environment solved in 716 episodes! Average Score: 247.78
# Episode: 817, Average Score: 250.20
# Environment solved in 717 episodes! Average Score: 250.20
# Episode: 818, Average Score: 252.56
# Environment solved in 718 episodes! Average Score: 252.56
# Episode: 819, Average Score: 255.42
# Environment solved in 719 episodes! Average Score: 255.42
# Episode: 820, Average Score: 257.33
# Environment solved in 720 episodes! Average Score: 257.33
# Episode: 821, Average Score: 259.41
# Environment solved in 721 episodes! Average Score: 259.41
# Episode: 822, Average Score: 259.85
# Environment solved in 722 episodes! Average Score: 259.85
# Episode: 823, Average Score: 259.45
# Environment solved in 723 episodes! Average Score: 259.45
# Episode: 824, Average Score: 260.18
# Environment solved in 724 episodes! Average Score: 260.18
# Episode: 825, Average Score: 260.82
# Environment solved in 725 episodes! Average Score: 260.82
# Episode: 826, Average Score: 263.11
# Environment solved in 726 episodes! Average Score: 263.11
# Episode: 827, Average Score: 263.62
# Environment solved in 727 episodes! Average Score: 263.62
# Episode: 828, Average Score: 263.43
# Environment solved in 728 episodes! Average Score: 263.43
# Episode: 829, Average Score: 265.16
# Environment solved in 729 episodes! Average Score: 265.16
# Episode: 830, Average Score: 266.44
# Environment solved in 730 episodes! Average Score: 266.44
# Episode: 831, Average Score: 268.21
# Environment solved in 731 episodes! Average Score: 268.21
# Episode: 832, Average Score: 269.32
# Environment solved in 732 episodes! Average Score: 269.32
# Episode: 833, Average Score: 269.51
# Environment solved in 733 episodes! Average Score: 269.51
# Episode: 834, Average Score: 271.85
# Environment solved in 734 episodes! Average Score: 271.85
# Episode: 835, Average Score: 273.94
# Environment solved in 735 episodes! Average Score: 273.94
# Episode: 836, Average Score: 274.54
# Environment solved in 736 episodes! Average Score: 274.54
# Episode: 837, Average Score: 274.06
# Environment solved in 737 episodes! Average Score: 274.06
# Episode: 838, Average Score: 273.88
# Environment solved in 738 episodes! Average Score: 273.88
# Episode: 839, Average Score: 275.41
# Environment solved in 739 episodes! Average Score: 275.41
# Episode: 840, Average Score: 277.09
# Environment solved in 740 episodes! Average Score: 277.09
# Episode: 841, Average Score: 276.18
# Environment solved in 741 episodes! Average Score: 276.18
# Episode: 842, Average Score: 276.51
# Environment solved in 742 episodes! Average Score: 276.51
# Episode: 843, Average Score: 276.42
# Environment solved in 743 episodes! Average Score: 276.42
# Episode: 844, Average Score: 275.88
# Environment solved in 744 episodes! Average Score: 275.88
# Episode: 845, Average Score: 275.66
# Environment solved in 745 episodes! Average Score: 275.66
# Episode: 846, Average Score: 275.15
# Environment solved in 746 episodes! Average Score: 275.15
# Episode: 847, Average Score: 274.12
# Environment solved in 747 episodes! Average Score: 274.12
# Episode: 848, Average Score: 274.42
# Environment solved in 748 episodes! Average Score: 274.42
# Episode: 849, Average Score: 273.86
# Environment solved in 749 episodes! Average Score: 273.86
# Episode: 850, Average Score: 272.60
# Environment solved in 750 episodes! Average Score: 272.60
# Episode: 851, Average Score: 271.94
# Environment solved in 751 episodes! Average Score: 271.94
# Episode: 852, Average Score: 270.89
# Environment solved in 752 episodes! Average Score: 270.89
# Episode: 853, Average Score: 270.10
# Environment solved in 753 episodes! Average Score: 270.10
# Episode: 854, Average Score: 269.22
# Environment solved in 754 episodes! Average Score: 269.22
# Episode: 855, Average Score: 268.92
# Environment solved in 755 episodes! Average Score: 268.92
# Episode: 856, Average Score: 268.50
# Environment solved in 756 episodes! Average Score: 268.50
# Episode: 857, Average Score: 267.64
# Environment solved in 757 episodes! Average Score: 267.64
# Episode: 858, Average Score: 267.22
# Environment solved in 758 episodes! Average Score: 267.22
# Episode: 859, Average Score: 266.18
# Environment solved in 759 episodes! Average Score: 266.18
# Episode: 860, Average Score: 265.20
# Environment solved in 760 episodes! Average Score: 265.20
# Episode: 861, Average Score: 264.27
# Environment solved in 761 episodes! Average Score: 264.27
# Episode: 862, Average Score: 263.36
# Environment solved in 762 episodes! Average Score: 263.36
# Episode: 863, Average Score: 261.72
# Environment solved in 763 episodes! Average Score: 261.72
# Episode: 864, Average Score: 260.51
# Environment solved in 764 episodes! Average Score: 260.51
# Episode: 865, Average Score: 259.21
# Environment solved in 765 episodes! Average Score: 259.21
# Episode: 866, Average Score: 256.99
# Environment solved in 766 episodes! Average Score: 256.99
# Episode: 867, Average Score: 255.42
# Environment solved in 767 episodes! Average Score: 255.42
# Episode: 868, Average Score: 253.97
# Environment solved in 768 episodes! Average Score: 253.97
# Episode: 869, Average Score: 252.76
# Environment solved in 769 episodes! Average Score: 252.76
# Episode: 870, Average Score: 251.50
# Environment solved in 770 episodes! Average Score: 251.50
# Episode: 871, Average Score: 248.30
# Environment solved in 771 episodes! Average Score: 248.30
# Episode: 872, Average Score: 246.57
# Environment solved in 772 episodes! Average Score: 246.57
# Episode: 873, Average Score: 245.94
# Environment solved in 773 episodes! Average Score: 245.94
# Episode: 874, Average Score: 245.37
# Environment solved in 774 episodes! Average Score: 245.37
# Episode: 875, Average Score: 244.26
# Environment solved in 775 episodes! Average Score: 244.26
# Episode: 876, Average Score: 243.07
# Environment solved in 776 episodes! Average Score: 243.07
# Episode: 877, Average Score: 241.78
# Environment solved in 777 episodes! Average Score: 241.78
# Episode: 878, Average Score: 240.41
# Environment solved in 778 episodes! Average Score: 240.41
# Episode: 879, Average Score: 238.89
# Environment solved in 779 episodes! Average Score: 238.89
# Episode: 880, Average Score: 237.17
# Environment solved in 780 episodes! Average Score: 237.17
# Episode: 881, Average Score: 236.37
# Environment solved in 781 episodes! Average Score: 236.37
# Episode: 882, Average Score: 235.36
# Environment solved in 782 episodes! Average Score: 235.36
# Episode: 883, Average Score: 234.44
# Environment solved in 783 episodes! Average Score: 234.44
# Episode: 884, Average Score: 233.22
# Environment solved in 784 episodes! Average Score: 233.22
# Episode: 885, Average Score: 232.18
# Environment solved in 785 episodes! Average Score: 232.18
# Episode: 886, Average Score: 231.75
# Environment solved in 786 episodes! Average Score: 231.75
# Episode: 887, Average Score: 231.18
# Environment solved in 787 episodes! Average Score: 231.18
# Episode: 888, Average Score: 224.43
# Environment solved in 788 episodes! Average Score: 224.43
# Episode: 889, Average Score: 223.52
# Environment solved in 789 episodes! Average Score: 223.52
# Episode: 890, Average Score: 222.93
# Environment solved in 790 episodes! Average Score: 222.93
# Episode: 891, Average Score: 221.32
# Environment solved in 791 episodes! Average Score: 221.32
# Episode: 892, Average Score: 220.13
# Environment solved in 792 episodes! Average Score: 220.13
# Episode: 893, Average Score: 219.17
# Environment solved in 793 episodes! Average Score: 219.17
# Episode: 894, Average Score: 217.83
# Environment solved in 794 episodes! Average Score: 217.83
# Episode: 895, Average Score: 217.14
# Environment solved in 795 episodes! Average Score: 217.14
# Episode: 896, Average Score: 216.64
# Environment solved in 796 episodes! Average Score: 216.64
# Episode: 897, Average Score: 215.72
# Environment solved in 797 episodes! Average Score: 215.72
# Episode: 898, Average Score: 215.31
# Environment solved in 798 episodes! Average Score: 215.31
# Episode: 899, Average Score: 214.37
# Environment solved in 799 episodes! Average Score: 214.37
# Episode: 900, Average Score: 213.85
#
# Environment solved in 800 episodes! Average Score: 213.85
# Episode: 901, Average Score: 213.18
# Environment solved in 801 episodes! Average Score: 213.18
# Episode: 902, Average Score: 211.85
# Environment solved in 802 episodes! Average Score: 211.85
# Episode: 903, Average Score: 211.16
# Environment solved in 803 episodes! Average Score: 211.16
# Episode: 904, Average Score: 210.41
# Environment solved in 804 episodes! Average Score: 210.41
# Episode: 905, Average Score: 209.47
# Environment solved in 805 episodes! Average Score: 209.47
# Episode: 906, Average Score: 208.75
# Environment solved in 806 episodes! Average Score: 208.75
# Episode: 907, Average Score: 207.83
# Environment solved in 807 episodes! Average Score: 207.83
# Episode: 908, Average Score: 206.04
# Environment solved in 808 episodes! Average Score: 206.04
# Episode: 909, Average Score: 205.51
# Environment solved in 809 episodes! Average Score: 205.51
# Episode: 910, Average Score: 204.76
# Environment solved in 810 episodes! Average Score: 204.76
# Episode: 911, Average Score: 204.13
# Environment solved in 811 episodes! Average Score: 204.13
# Episode: 912, Average Score: 203.15
# Environment solved in 812 episodes! Average Score: 203.15
# Episode: 913, Average Score: 202.34
# Environment solved in 813 episodes! Average Score: 202.34
# Episode: 914, Average Score: 201.78
# Environment solved in 814 episodes! Average Score: 201.78
# Episode: 915, Average Score: 201.08
# Environment solved in 815 episodes! Average Score: 201.08
# Episode: 916, Average Score: 200.39
# Environment solved in 816 episodes! Average Score: 200.39
# Episode: 917, Average Score: 199.25
# Environment solved in 817 episodes! Average Score: 199.25
# Episode: 918, Average Score: 198.13
# Environment solved in 818 episodes! Average Score: 198.13
# Episode: 919, Average Score: 196.81
# Environment solved in 819 episodes! Average Score: 196.81
# Episode: 920, Average Score: 196.32
# Environment solved in 820 episodes! Average Score: 196.32
# Episode: 921, Average Score: 195.61
# Environment solved in 821 episodes! Average Score: 195.61
# Episode: 922, Average Score: 194.72
# Environment solved in 822 episodes! Average Score: 194.72
# Episode: 923, Average Score: 194.11
# Environment solved in 823 episodes! Average Score: 194.11
# Episode: 924, Average Score: 193.19
# Environment solved in 824 episodes! Average Score: 193.19
# Episode: 925, Average Score: 192.77
# Environment solved in 825 episodes! Average Score: 192.77
# Episode: 926, Average Score: 191.87
# Environment solved in 826 episodes! Average Score: 191.87
# Episode: 927, Average Score: 191.32
# Environment solved in 827 episodes! Average Score: 191.32
# Episode: 928, Average Score: 190.76
# Environment solved in 828 episodes! Average Score: 190.76
# Episode: 929, Average Score: 190.10
# Environment solved in 829 episodes! Average Score: 190.10
# Episode: 930, Average Score: 188.08
# Environment solved in 830 episodes! Average Score: 188.08
# Episode: 931, Average Score: 187.36
# Environment solved in 831 episodes! Average Score: 187.36
# Episode: 932, Average Score: 186.36
# Environment solved in 832 episodes! Average Score: 186.36
# Episode: 933, Average Score: 185.47
# Environment solved in 833 episodes! Average Score: 185.47
# Episode: 934, Average Score: 184.77
# Environment solved in 834 episodes! Average Score: 184.77
# Episode: 935, Average Score: 183.98
# Environment solved in 835 episodes! Average Score: 183.98
# Episode: 936, Average Score: 183.33
# Environment solved in 836 episodes! Average Score: 183.33
# Episode: 937, Average Score: 182.54
# Environment solved in 837 episodes! Average Score: 182.54
# Episode: 938, Average Score: 181.57
# Environment solved in 838 episodes! Average Score: 181.57
# Episode: 939, Average Score: 181.05
# Environment solved in 839 episodes! Average Score: 181.05
# Episode: 940, Average Score: 180.53
# Environment solved in 840 episodes! Average Score: 180.53
# Episode: 941, Average Score: 179.64
# Environment solved in 841 episodes! Average Score: 179.64
# Episode: 942, Average Score: 178.85
# Environment solved in 842 episodes! Average Score: 178.85
# Episode: 943, Average Score: 177.95
# Environment solved in 843 episodes! Average Score: 177.95
# Episode: 944, Average Score: 177.51
# Environment solved in 844 episodes! Average Score: 177.51
# Episode: 945, Average Score: 176.93
# Environment solved in 845 episodes! Average Score: 176.93
# Episode: 946, Average Score: 176.40
# Environment solved in 846 episodes! Average Score: 176.40
# Episode: 947, Average Score: 175.74
# Environment solved in 847 episodes! Average Score: 175.74
# Episode: 948, Average Score: 174.36
# Environment solved in 848 episodes! Average Score: 174.36
# Episode: 949, Average Score: 174.14
# Environment solved in 849 episodes! Average Score: 174.14
# Episode: 950, Average Score: 173.39
# Environment solved in 850 episodes! Average Score: 173.39
# Episode: 951, Average Score: 172.83
# Environment solved in 851 episodes! Average Score: 172.83
# Episode: 952, Average Score: 172.39
# Environment solved in 852 episodes! Average Score: 172.39
# Episode: 953, Average Score: 171.78
# Environment solved in 853 episodes! Average Score: 171.78
# Episode: 954, Average Score: 171.49
# Environment solved in 854 episodes! Average Score: 171.49
# Episode: 955, Average Score: 171.01
# Environment solved in 855 episodes! Average Score: 171.01
# Episode: 956, Average Score: 170.48
# Environment solved in 856 episodes! Average Score: 170.48
# Episode: 957, Average Score: 169.93
# Environment solved in 857 episodes! Average Score: 169.93
# Episode: 958, Average Score: 168.90
# Environment solved in 858 episodes! Average Score: 168.90
# Episode: 959, Average Score: 168.39
# Environment solved in 859 episodes! Average Score: 168.39
# Episode: 960, Average Score: 168.09
# Environment solved in 860 episodes! Average Score: 168.09
# Episode: 961, Average Score: 167.65
# Environment solved in 861 episodes! Average Score: 167.65
# Episode: 962, Average Score: 166.85
# Environment solved in 862 episodes! Average Score: 166.85
# Episode: 963, Average Score: 166.36
# Environment solved in 863 episodes! Average Score: 166.36
# Episode: 964, Average Score: 165.95
# Environment solved in 864 episodes! Average Score: 165.95
# Episode: 965, Average Score: 165.75
# Environment solved in 865 episodes! Average Score: 165.75
# Episode: 966, Average Score: 165.48
# Environment solved in 866 episodes! Average Score: 165.48
# Episode: 967, Average Score: 164.99
# Environment solved in 867 episodes! Average Score: 164.99
# Episode: 968, Average Score: 164.56
# Environment solved in 868 episodes! Average Score: 164.56
# Episode: 969, Average Score: 164.15
# Environment solved in 869 episodes! Average Score: 164.15
# Episode: 970, Average Score: 163.83
# Environment solved in 870 episodes! Average Score: 163.83
# Episode: 971, Average Score: 163.55
# Environment solved in 871 episodes! Average Score: 163.55
# Episode: 972, Average Score: 163.37
# Environment solved in 872 episodes! Average Score: 163.37
# Episode: 973, Average Score: 163.04
# Environment solved in 873 episodes! Average Score: 163.04
# Episode: 974, Average Score: 162.68
# Environment solved in 874 episodes! Average Score: 162.68
# Episode: 975, Average Score: 162.39
# Environment solved in 875 episodes! Average Score: 162.39
# Episode: 976, Average Score: 162.00
# Environment solved in 876 episodes! Average Score: 162.00
# Episode: 977, Average Score: 161.63
# Environment solved in 877 episodes! Average Score: 161.63
# Episode: 978, Average Score: 161.24
# Environment solved in 878 episodes! Average Score: 161.24
# Episode: 979, Average Score: 160.93
# Environment solved in 879 episodes! Average Score: 160.93
# Episode: 980, Average Score: 160.54
# Environment solved in 880 episodes! Average Score: 160.54
# Episode: 981, Average Score: 160.16
# Environment solved in 881 episodes! Average Score: 160.16
# Episode: 982, Average Score: 160.03
# Environment solved in 882 episodes! Average Score: 160.03
# Episode: 983, Average Score: 159.59
# Environment solved in 883 episodes! Average Score: 159.59
# Episode: 984, Average Score: 159.37
# Environment solved in 884 episodes! Average Score: 159.37
# Episode: 985, Average Score: 159.10
# Environment solved in 885 episodes! Average Score: 159.10
# Episode: 986, Average Score: 158.64
# Environment solved in 886 episodes! Average Score: 158.64
# Episode: 987, Average Score: 158.18
# Environment solved in 887 episodes! Average Score: 158.18
# Episode: 988, Average Score: 158.17
# Environment solved in 888 episodes! Average Score: 158.17
# Episode: 989, Average Score: 157.83
# Environment solved in 889 episodes! Average Score: 157.83
# Episode: 990, Average Score: 157.38
# Environment solved in 890 episodes! Average Score: 157.38
# Episode: 991, Average Score: 157.26
# Environment solved in 891 episodes! Average Score: 157.26
# Episode: 992, Average Score: 156.90
# Environment solved in 892 episodes! Average Score: 156.90
# Episode: 993, Average Score: 156.64
# Environment solved in 893 episodes! Average Score: 156.64
# Episode: 994, Average Score: 156.42
# Environment solved in 894 episodes! Average Score: 156.42
# Episode: 995, Average Score: 156.10
# Environment solved in 895 episodes! Average Score: 156.10
# Episode: 996, Average Score: 155.40
# Environment solved in 896 episodes! Average Score: 155.40
# Episode: 997, Average Score: 155.43
# Environment solved in 897 episodes! Average Score: 155.43
# Episode: 998, Average Score: 155.20
# Environment solved in 898 episodes! Average Score: 155.20
# Episode: 999, Average Score: 155.01
# Environment solved in 899 episodes! Average Score: 155.01
# Episode: 1000, Average Score: 154.60
#
# Environment solved in 900 episodes! Average Score: 154.60
# Training completed.

# %% [markdown]
# ## Evaluate The Agent

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(scores)), scores, color='green')
plt.xlabel('Num of episodes')
plt.ylabel('Score')
if not os.path.exists('./images/'): os.makedirs('./images/')
plt.savefig('./images/plot_of_agent_evaluation.png')
plt.show()

# %% [markdown]
# ## Watch The Smart Agent

# %%
# load the weights of smart agent
agent.dqn_net.load_state_dict(torch.load(f'./agents/PER_DQN_{ENV_NAME}.pth'));

# %%
num_of_episodes = 20

for i_episode in range(1, num_of_episodes+1):
    
    state = env.reset()
    for time_step in range(200):
        
        # select an action
        action = agent.act(state)
        env.render()
        
        next_state, reward, done, _ = env.step(action)
        state = next_state
        if done:
            break

env.close()

# %% [markdown]
# ---
